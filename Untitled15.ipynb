# %% [markdown]
# <a href="https://colab.research.google.com/github/q4m4gs9b25/supreme-umbrella/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

html_content = """
<!DOCTYPE html>
<html lang="th">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
    <style>
        body { font-family: Arial, sans-serif; margin: 20px; }
        h1, h2 { text-align: center; }
        section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
        form { margin: 0 auto; max-width: 800px; }
        label { display: block; margin: 10px 0; }
        input[type="radio"] { margin-right: 10px; }
        button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
        button:hover { background-color: #45a049; }
        .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
        nav { text-align: center; margin-bottom: 30px; }
        nav a { margin: 10px; text-decoration: none; color: #007BFF; }
        nav a:hover { text-decoration: underline; }
        select { margin: 10px 0; }
    </style>
</head>
<body>
    <h1>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</h1>
    <p style="text-align: center;">ยินดีต้อนรับสู่แพลตฟอร์มประเมินสุขภาพจิตเบื้องต้น กรุณาเลือกแบบประเมินที่ต้องการจากเมนูด้านล่าง โปรดตอบตามความรู้สึกจริงเพื่อผลลัพธ์ที่แม่นยำที่สุด ผลลัพธ์นี้ไม่ใช่การวินิจฉัยทางการแพทย์ ควรปรึกษาแพทย์หากมีอาการรุนแรง</p>

    <nav>
        <a href="#st5">ST-5 (ความเครียด)</a> |
        <a href="#2q9q8q">2Q-9Q-8Q (ซึมเศร้า/ฆ่าตัวตาย)</a> |
        <a href="#2qplus">2Q Plus</a> |
        <a href="#phqa">PHQ-A (ซึมเศร้าในวัยรุ่น)</a> |
        <a href="#tmhi15">TMHI-15 (สุขภาพจิตคนไทย)</a> |
        <a href="#rq">RQ (พลังสุขภาพจิต)</a> |
        <a href="#assist">ASSIST (สารเสพติด)</a>
    </nav>

    <!-- ST-5 -->
    <section id="st5">
        <h2>แบบประเมินความเครียด (ST-5)</h2>
        <form id="st5Form">
            <p>ในช่วง 2-4 สัปดาห์ที่ผ่านมา รวมวันนี้ อาการเหล่านี้รบกวนท่านมากน้อยเพียงใด</p>
            <label>1. ท่านรู้สึกปวดศีรษะหรือปวดต้นคอ</label>
            <input type="radio" name="q1" value="0"> แทบไม่มี (0)
            <input type="radio" name="q1" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q1" value="3"> เกือบตลอด (3)<br>

            <label>2. ท่านรู้สึกหงุดหงิด โมโหง่าย</label>
            <input type="radio" name="q2" value="0"> แทบไม่มี (0)
            <input type="radio" name="q2" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q2" value="3"> เกือบตลอด (3)<br>

            <label>3. ท่านรู้สึกเบื่อ เซ็ง</label>
            <input type="radio" name="q3" value="0"> แทบไม่มี (0)
            <input type="radio" name="q3" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q3" value="3"> เกือบตลอด (3)<br>

            <label>4. ท่านรู้สึกเครียด กลุ้มใจ</label>
            <input type="radio" name="q4" value="0"> แทบไม่มี (0)
            <input type="radio" name="q4" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q4" value="3"> เกือบตลอด (3)<br>

            <label>5. ท่านรู้สึกท้อแท้ หมดหวัง</label>
            <input type="radio" name="q5" value="0"> แทบไม่มี (0)
            <input type="radio" name="q5" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q5" value="3"> เกือบตลอด (3)<br>

            <button type="button" onclick="calculateST5()">คำนวณผล</button>
            <button type="button" onclick="clearForm('st5Form', 'st5Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="st5Result" class="result"></div>
    </section>

    <!-- 2Q-9Q-8Q -->
    <section id="2q9q8q">
        <h2>แบบประเมินซึมเศร้า / ฆ่าตัวตาย (2Q-9Q-8Q)</h2>
        <form id="2q9q8qForm">
            <h3>2Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านรู้สึก...</h3>
            <label>1. หดหู่ เศร้า หรือท้อแท้สิ้นหวัง</label>
            <input type="radio" name="2q1" value="0"> ไม่มี
            <input type="radio" name="2q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="2q2" value="0"> ไม่มี
            <input type="radio" name="2q2" value="1"> มี<br>

            <h3>9Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้บ่อยแค่ไหน</h3>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="9q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q1" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q1" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q1" value="3"> เป็นทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="9q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q2" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q2" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q2" value="3"> เป็นทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="9q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q3" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q3" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q3" value="3"> เป็นทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="9q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q4" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q4" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q4" value="3"> เป็นทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="9q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q5" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q5" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q5" value="3"> เป็นทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="9q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q6" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q6" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q6" value="3"> เป็นทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือพิมพ์หรือดูโทรทัศน์</label>
            <input type="radio" name="9q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q7" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q7" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q7" value="3"> เป็นทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="9q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q8" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q8" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q8" value="3"> เป็นทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="9q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q9" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q9" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q9" value="3"> เป็นทุกวัน (3)<br>

            <h3>8Q: ใน 1 เดือนที่ผ่านมา รวมวันนี้ ท่านมี...</h3>
            <label>1. ความคิดอยากตาย หรือคิดว่าตายเสียจะดีกว่า</label>
            <input type="radio" name="8q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q1" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q1" value="3"> เกือบทุกวัน (3)<br>

            <label>2. อยากทำร้ายตัวเอง หรือทำให้ตัวเองบาดเจ็บ</label>
            <input type="radio" name="8q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q2" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q2" value="3"> เกือบทุกวัน (3)<br>

            <label>3. คิดเกี่ยวกับความตาย</label>
            <input type="radio" name="8q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q3" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q3" value="3"> เกือบทุกวัน (3)<br>

            <label>4. มีแผนการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q4" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q4" value="3"> เกือบทุกวัน (3)<br>

            <label>5. มีแผนการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q5" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q5" value="3"> เกือบทุกวัน (3)<br>

            <label>6. เตรียมการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q6" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q6" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q6" value="3"> เกือบทุกวัน (3)<br>

            <label>7. เตรียมการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q7" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q7" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q7" value="3"> เกือบทุกวัน (3)<br>

            <label>8. ท่านเคยพยายามฆ่าตัวตาย</label>
            <input type="radio" name="8q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q8" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q8" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q8" value="3"> เกือบทุกวัน (3)<br>

            <button type="button" onclick="calculate2Q9Q8Q()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2q9q8qForm', '2q9q8qResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2q9q8qResult" class="result"></div>
    </section>

    <!-- 2Q Plus -->
    <section id="2qplus">
        <h2>แบบประเมิน 2Q Plus (ฉบับปรับปรุง)</h2>
        <form id="2qplusForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้หรือไม่</p>
            <label>1. ไม่สบายใจ เซ็ง ทุกข์ใจ เศร้า ท้อแท้ ซึม หงอย</label>
            <input type="radio" name="q1" value="0"> ไม่มี
            <input type="radio" name="q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่อยากพูดไม่อยากทำอะไร หรือทำอะไรก็ไม่สนุกเพลิดเพลินเหมือนเดิม</label>
            <input type="radio" name="q2" value="0"> ไม่มี
            <input type="radio" name="q2" value="1"> มี<br>

            <p>ใน 1 เดือนที่ผ่านมา รวมวันนี้</p>
            <label>ท่านมีความรู้สึกทุกข์ใจจนไม่อยากมีชีวิตอยู่หรือไม่</label>
            <input type="radio" name="plus" value="0"> ไม่มี
            <input type="radio" name="plus" value="1"> มี<br>

            <button type="button" onclick="calculate2QPlus()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2qplusForm', '2qplusResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2qplusResult" class="result"></div>
    </section>

    <!-- PHQ-A -->
    <section id="phqa">
        <h2>แบบประเมินภาวะซึมเศร้าในวัยรุ่น (PHQ-A)</h2>
        <form id="phqaForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา ท่านมีอาการเหล่านี้บ่อยแค่ไหน (สำหรับวัยรุ่นอายุ 11-20 ปี)</p>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q1" value="1"> มีบางวัน (1)
            <input type="radio" name="q1" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q1" value="3"> แทบทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q2" value="1"> มีบางวัน (1)
            <input type="radio" name="q2" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q2" value="3"> แทบทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q3" value="1"> มีบางวัน (1)
            <input type="radio" name="q3" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q3" value="3"> แทบทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q4" value="1"> มีบางวัน (1)
            <input type="radio" name="q4" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q4" value="3"> แทบทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q5" value="1"> มีบางวัน (1)
            <input type="radio" name="q5" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q5" value="3"> แทบทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q6" value="1"> มีบางวัน (1)
            <input type="radio" name="q6" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q6" value="3"> แทบทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือหรือดูโทรทัศน์</label>
            <input type="radio" name="q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q7" value="1"> มีบางวัน (1)
            <input type="radio" name="q7" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q7" value="3"> แทบทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q8" value="1"> มีบางวัน (1)
            <input type="radio" name="q8" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q8" value="3"> แทบทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q9" value="1"> มีบางวัน (1)
            <input type="radio" name="q9" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q9" value="3"> แทบทุกวัน (3)<br>

            <p>คำถามเพิ่มเติม (ไม่คิดคะแนน):</p>
            <label>ในปีที่ผ่านมา ท่านเคยพยายามทำร้ายตัวเองหรือไม่?</label>
            <input type="radio" name="extra1" value="0"> ไม่มี
            <input type="radio" name="extra1" value="1"> มี<br>

            <label>ในปีที่ผ่านมา ท่านเคยคิดอยากตายหรือไม่?</label>
            <input type="radio" name="extra2" value="0"> ไม่มี
            <input type="radio" name="extra2" value="1"> มี<br>

            <button type="button" onclick="calculatePHQA()">คำนวณผล</button>
            <button type="button" onclick="clearForm('phqaForm', 'phqaResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="phqaResult" class="result"></div>
    </section>

    <!-- TMHI-15 -->
    <section id="tmhi15">
        <h2>ดัชนีชี้วัดสุขภาพจิตของคนไทย (TMHI-15)</h2>
        <form id="tmhi15Form">
            <p>กรุณาเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด สำหรับประสบการณ์ในช่วง 1 เดือนที่ผ่านมา</p>
            <label>1. ท่านรู้สึกพึงพอใจในชีวิต</label>
            <input type="radio" name="q1" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q1" value="1"> เล็กน้อย (1)
            <input type="radio" name="q1" value="2"> มาก (2)
            <input type="radio" name="q1" value="3"> มากที่สุด (3)<br>

            <label>2. ท่านรู้สึกสบายใจ</label>
            <input type="radio" name="q2" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q2" value="1"> เล็กน้อย (1)
            <input type="radio" name="q2" value="2"> มาก (2)
            <input type="radio" name="q2" value="3"> มากที่สุด (3)<br>

            <label>3. ท่านรู้สึกเบื่อหน่ายท้อแท้กับการดำเนินชีวิตประจำวัน</label>
            <input type="radio" name="q3" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q3" value="2"> เล็กน้อย (2)
            <input type="radio" name="q3" value="1"> มาก (1)
            <input type="radio" name="q3" value="0"> มากที่สุด (0)<br>

            <label>4. ท่านรู้สึกผิดหวังในตัวเอง</label>
            <input type="radio" name="q4" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q4" value="2"> เล็กน้อย (2)
            <input type="radio" name="q4" value="1"> มาก (1)
            <input type="radio" name="q4" value="0"> มากที่สุด (0)<br>

            <label>5. ท่านรู้สึกว่าชีวิตของท่านมีแต่ความทุกข์</label>
            <input type="radio" name="q5" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q5" value="2"> เล็กน้อย (2)
            <input type="radio" name="q5" value="1"> มาก (1)
            <input type="radio" name="q5" value="0"> มากที่สุด (0)<br>

            <label>6. ท่านสามารถทำใจยอมรับได้สำหรับปัญหาที่ยากจะแก้ไข (เมื่อมีปัญหา)</label>
            <input type="radio" name="q6" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q6" value="1"> เล็กน้อย (1)
            <input type="radio" name="q6" value="2"> มาก (2)
            <input type="radio" name="q6" value="3"> มากที่สุด (3)<br>

            <label>7. ท่านมั่นใจว่าจะสามารถควบคุมอารมณ์ได้เมื่อมีเหตุการณ์คับขันหรือร้ายแรงเกิดขึ้น</label>
            <input type="radio" name="q7" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q7" value="1"> เล็กน้อย (1)
            <input type="radio" name="q7" value="2"> มาก (2)
            <input type="radio" name="q7" value="3"> มากที่สุด (3)<br>

            <label>8. ท่านมั่นใจที่จะเผชิญกับเหตุการณ์ร้ายแรงที่เกิดขึ้นในชีวิต</label>
            <input type="radio" name="q8" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q8" value="1"> เล็กน้อย (1)
            <input type="radio" name="q8" value="2"> มาก (2)
            <input type="radio" name="q8" value="3"> มากที่สุด (3)<br>

            <label>9. ท่านรู้สึกเห็นอกเห็นใจเมื่อผู้อื่นมีทุกข์</label>
            <input type="radio" name="q9" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q9" value="1"> เล็กน้อย (1)
            <input type="radio" name="q9" value="2"> มาก (2)
            <input type="radio" name="q9" value="3"> มากที่สุด (3)<br>

            <label>10. ท่านรู้สึกเป็นสุขในการช่วยเหลือผู้อื่นที่มีปัญหา</label>
            <input type="radio" name="q10" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q10" value="1"> เล็กน้อย (1)
            <input type="radio" name="q10" value="2"> มาก (2)
            <input type="radio" name="q10" value="3"> มากที่สุด (3)<br>

            <label>11. ท่านให้ความช่วยเหลือแก่ผู้อื่นเมื่อมีโอกาส</label>
            <input type="radio" name="q11" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q11" value="1"> เล็กน้อย (1)
            <input type="radio" name="q11" value="2"> มาก (2)
            <input type="radio" name="q11" value="3"> มากที่สุด (3)<br>

            <label>12. ท่านรู้สึกภูมิใจในตนเอง</label>
            <input type="radio" name="q12" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q12" value="1"> เล็กน้อย (1)
            <input type="radio" name="q12" value="2"> มาก (2)
            <input type="radio" name="q12" value="3"> มากที่สุด (3)<br>

            <label>13. ท่านรู้สึกมั่นคง ปลอดภัย เมื่ออยู่ในครอบครัว</label>
            <input type="radio" name="q13" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q13" value="1"> เล็กน้อย (1)
            <input type="radio" name="q13" value="2"> มาก (2)
            <input type="radio" name="q13" value="3"> มากที่สุด (3)<br>

            <label>14. หากท่านป่วยหนัก ท่านเชื่อว่าครอบครัวจะดูแลท่านเป็นอย่างดี</label>
            <input type="radio" name="q14" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q14" value="1"> เล็กน้อย (1)
            <input type="radio" name="q14" value="2"> มาก (2)
            <input type="radio" name="q14" value="3"> มากที่สุด (3)<br>

            <label>15. สมาชิกในครอบครัวมีความรักและผูกพันต่อกัน</label>
            <input type="radio" name="q15" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q15" value="1"> เล็กน้อย (1)
            <input type="radio" name="q15" value="2"> มาก (2)
            <input type="radio" name="q15" value="3"> มากที่สุด (3)<br>

            <button type="button" onclick="calculateTMHI15()">คำนวณผล</button>
            <button type="button" onclick="clearForm('tmhi15Form', 'tmhi15Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="tmhi15Result" class="result"></div>
    </section>

    <!-- RQ -->
    <section id="rq">
        <h2>แบบประเมินพลังสุขภาพจิต (RQ) ฉบับ 20 ข้อ</h2>
        <form id="rqForm">
            <p>โปรดเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด (1=ไม่จริงเลย, 2=ไม่จริง, 3=ค่อนข้างจริง, 4=จริงมาก)</p>
            <label>1. ฉันสามารถทนต่อแรงกดดันได้ดี</label>
            <input type="radio" name="q1" value="1"> 1
            <input type="radio" name="q1" value="2"> 2
            <input type="radio" name="q1" value="3"> 3
            <input type="radio" name="q1" value="4"> 4<br>

            <label>2. ฉันมักจะยอมแพ้เมื่อเจอปัญหายากๆ</label>
            <input type="radio" name="q2" value="4"> 1 (reverse)
            <input type="radio" name="q2" value="3"> 2
            <input type="radio" name="q2" value="2"> 3
            <input type="radio" name="q2" value="1"> 4<br>

            <label>3. ฉันสามารถปรับตัวเข้ากับการเปลี่ยนแปลงได้</label>
            <input type="radio" name="q3" value="1"> 1
            <input type="radio" name="q3" value="2"> 2
            <input type="radio" name="q3" value="3"> 3
            <input type="radio" name="q3" value="4"> 4<br>

            <label>4. ฉันรู้สึกสิ้นหวังเมื่อล้มเหลว</label>
            <input type="radio" name="q4" value="4"> 1 (reverse)
            <input type="radio" name="q4" value="3"> 2
            <input type="radio" name="q4" value="2"> 3
            <input type="radio" name="q4" value="1"> 4<br>

            <label>5. ฉันมีกำลังใจที่จะต่อสู้กับอุปสรรค</label>
            <input type="radio" name="q5" value="1"> 1
            <input type="radio" name="q5" value="2"> 2
            <input type="radio" name="q5" value="3"> 3
            <input type="radio" name="q5" value="4"> 4<br>

            <label>6. ฉันมักจะหงุดหงิดง่ายเมื่อมีปัญหา</label>
            <input type="radio" name="q6" value="4"> 1 (reverse)
            <input type="radio" name="q6" value="3"> 2
            <input type="radio" name="q6" value="2"> 3
            <input type="radio" name="q6" value="1"> 4<br>

            <label>7. ฉันสามารถหาทางแก้ปัญหาได้เสมอ</label>
            <input type="radio" name="q7" value="1"> 1
            <input type="radio" name="q7" value="2"> 2
            <input type="radio" name="q7" value="3"> 3
            <input type="radio" name="q7" value="4"> 4<br>

            <label>8. ฉันรู้สึกว่าชีวิตไร้ค่าเมื่อเจอวิกฤต</label>
            <input type="radio" name="q8" value="4"> 1 (reverse)
            <input type="radio" name="q8" value="3"> 2
            <input type="radio" name="q8" value="2"> 3
            <input type="radio" name="q8" value="1"> 4<br>

            <label>9. ฉันสามารถเรียนรู้จากความผิดพลาด</label>
            <input type="radio" name="q9" value="1"> 1
            <input type="radio" name="q9" value="2"> 2
            <input type="radio" name="q9" value="3"> 3
            <input type="radio" name="q9" value="4"> 4<br>

            <label>10. ฉันมักจะโทษตัวเองเมื่อสิ่งต่างๆผิดพลาด</label>
            <input type="radio" name="q10" value="4"> 1 (reverse)
            <input type="radio" name="q10" value="3"> 2
            <input type="radio" name="q10" value="2"> 3
            <input type="radio" name="q10" value="1"> 4<br>

            <label>11. ฉันมีแรงบันดาลใจจากเป้าหมายในชีวิต</label>
            <input type="radio" name="q11" value="1"> 1
            <input type="radio" name="q11" value="2"> 2
            <input type="radio" name="q11" value="3"> 3
            <input type="radio" name="q11" value="4"> 4<br>

            <label>12. ฉันรู้สึกหมดหวังง่าย</label>
            <input type="radio" name="q12" value="4"> 1 (reverse)
            <input type="radio" name="q12" value="3"> 2
            <input type="radio" name="q12" value="2"> 3
            <input type="radio" name="q12" value="1"> 4<br>

            <label>13. ฉันสามารถขอความช่วยเหลือจากผู้อื่นได้</label>
            <input type="radio" name="q13" value="1"> 1
            <input type="radio" name="q13" value="2"> 2
            <input type="radio" name="q13" value="3"> 3
            <input type="radio" name="q13" value="4"> 4<br>

            <label>14. ฉันมักจะรู้สึกโดดเดี่ยวเมื่อมีปัญหา</label>
            <input type="radio" name="q14" value="4"> 1 (reverse)
            <input type="radio" name="q14" value="3"> 2
            <input type="radio" name="q14" value="2"> 3
            <input type="radio" name="q14" value="1"> 4<br>

            <label>15. ฉันสามารถควบคุมอารมณ์ได้ดี</label>
            <input type="radio" name="q15" value="1"> 1
            <input type="radio" name="q15" value="2"> 2
            <input type="radio" name="q15" value="3"> 3
            <input type="radio" name="q15" value="4"> 4<br>

            <label>16. ฉันมักจะตื่นตระหนกเมื่อเจอสถานการณ์ยากลำบาก</label>
            <input type="radio" name="q16" value="4"> 1 (reverse)
            <input type="radio" name="q16" value="3"> 2
            <input type="radio" name="q16" value="2"> 3
            <input type="radio" name="q16" value="1"> 4<br>

            <label>17. ฉันเชื่อว่าทุกปัญหามีทางออก</label>
            <input type="radio" name="q17" value="1"> 1
            <input type="radio" name="q17" value="2"> 2
            <input type="radio" name="q17" value="3"> 3
            <input type="radio" name="q17" value="4"> 4<br>

            <label>18. ฉันรู้สึกว่าตนเองอ่อนแอ</label>
            <input type="radio" name="q18" value="4"> 1 (reverse)
            <input type="radio" name="q18" value="3"> 2
            <input type="radio" name="q18" value="2"> 3
            <input type="radio" name="q18" value="1"> 4<br>

            <label>19. ฉันสามารถฟื้นตัวจากความล้มเหลวได้</label>
            <input type="radio" name="q19" value="1"> 1
            <input type="radio" name="q19" value="2"> 2
            <input type="radio" name="q19" value="3"> 3
            <input type="radio" name="q19" value="4"> 4<br>

            <label>20. ฉันมักจะยอมแพ้ก่อนที่จะพยายาม</label>
            <input type="radio" name="q20" value="4"> 1 (reverse)
            <input type="radio" name="q20" value="3"> 2
            <input type="radio" name="q20" value="2"> 3
            <input type="radio" name="q20" value="1"> 4<br>

            <button type="button" onclick="calculateRQ()">คำนวณผล</button>
            <button type="button" onclick="clearForm('rqForm', 'rqResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="rqResult" class="result"></div>
    </section>

    <!-- ASSIST -->
    <section id="assist">
        <h2>แบบประเมินความเสี่ยงต่อการใช้สารเสพติด (ASSIST)</h2>
        <form id="assistForm">
            <p>เลือกสารที่ต้องการประเมิน (สามารถเลือกหลายสารได้ แต่คำนวณทีละสารเพื่อความง่าย)</p>
            <select id="substance">
                <option value="tobacco">ยาสูบ</option>
                <option value="alcohol">สุรา</option>
                <option value="cannabis">กัญชา</option>
                <option value="cocaine">โคเคน</option>
                <option value="amphetamine">ยาบ้า/แอมเฟตามีน</option>
                <option value="inhalants">สารระเหย</option>
                <option value="sedatives">ยานอนหลับ</option>
                <option value="hallucinogens">ยาหลอนประสาท</option>
                <option value="opioids">ฝิ่น</option>
                <option value="other">อื่นๆ</option>
            </select><br>

            <label>Q1: ในชีวิตท่านเคยใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q1" value="0"> ไม่เคย
            <input type="radio" name="q1" value="1"> เคย (หากไม่เคย ข้ามไป)<br>

            <label>Q2: ใน 3 เดือนที่ผ่านมา ท่านใช้สารนี้บ่อยเพียงใด?</label>
            <input type="radio" name="q2" value="0"> ไม่เคย (0)
            <input type="radio" name="q2" value="2"> 1-2 ครั้ง (2)
            <input type="radio" name="q2" value="3"> ทุกเดือน (3)
            <input type="radio" name="q2" value="4"> ทุกสัปดาห์ (4)
            <input type="radio" name="q2" value="6"> เกือบทุกวัน (6)<br>

            <label>Q3: ใน 3 เดือนที่ผ่านมา ท่านรู้สึกอยากใช้สารนี้อย่างรุนแรงบ่อยเพียงใด?</label>
            <input type="radio" name="q3" value="0"> ไม่เคย (0)
            <input type="radio" name="q3" value="3"> 1-2 ครั้ง (3)
            <input type="radio" name="q3" value="4"> ทุกเดือน (4)
            <input type="radio" name="q3" value="5"> ทุกสัปดาห์ (5)
            <input type="radio" name="q3" value="6"> เกือบทุกวัน (6)<br>

            <label>Q4: ใน 3 เดือนที่ผ่านมา การใช้สารนี้ทำให้เกิดปัญหาสุขภาพ สังคม กฎหมาย การเงิน ต่อท่านบ่อยเพียงใด?</label>
            <input type="radio" name="q4" value="0"> ไม่เคย (0)
            <input type="radio" name="q4" value="4"> 1-2 ครั้ง (4)
            <input type="radio" name="q4" value="5"> ทุกเดือน (5)
            <input type="radio" name="q4" value="6"> ทุกสัปดาห์ (6)
            <input type="radio" name="q4" value="7"> เกือบทุกวัน (7)<br>

            <label>Q5: ใน 3 เดือนที่ผ่านมา ท่านไม่สามารถทำกิจกรรมปกติเพราะใช้สารนี้บ่อยเพียงใด? (ยกเว้นยาสูบ)</label>
            <input type="radio" name="q5" value="0"> ไม่เคย (0)
            <input type="radio" name="q5" value="5"> 1-2 ครั้ง (5)
            <input type="radio" name="q5" value="6"> ทุกเดือน (6)
            <input type="radio" name="q5" value="7"> ทุกสัปดาño="7"> เกือบทุกวัน (8)<br>

            <label>Q6: เพื่อน ญาติ หรือคนอื่นเคยแสดงความห่วงใยหรือตักเตือนท่านเกี่ยวกับการใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q6" value="0"> ไม่เคย (0)
            <input type="radio" name="q6" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q6" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q7: ท่านเคยพยายามหยุดหรือลดการใช้สารนี้แต่ไม่สำเร็จหรือไม่?</label>
            <input type="radio" name="q7" value="0"> ไม่เคย (0)
            <input type="radio" name="q7" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q7" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q8: ท่านเคยใช้สารนี้โดยการฉีดหรือไม่?</label>
            <input type="radio" name="q8" value="0"> ไม่เคย (0)
            <input type="radio" name="q8" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q8" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <button type="button" onclick="calculateASSIST()">คำนวณผล</button>
            <button type="button" onclick="clearForm('assistForm', 'assistResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="assistResult" class="result"></div>
    </section>

    <script>
        function validateForm(formId) {
            const form = document.getElementById(formId);
            const radioGroups = {};
            form.querySelectorAll('input[type="radio"]').forEach(radio => {
                if (!radioGroups[radio.name]) {
                    radioGroups[radio.name] = [];
                }
                radioGroups[radio.name].push(radio);
            });

            for (const groupName in radioGroups) {
                const group = radioGroups[groupName];
                const isChecked = group.some(radio => radio.checked);
                if (!isChecked) {
                    alert('กรุณาตอบคำถามทุกข้อในแบบประเมินนี้');
                    return false;
                }
            }
            return true;
        }

        function clearForm(formId, resultId) {
            document.getElementById(formId).reset();
            document.getElementById(resultId).innerHTML = '';
            document.getElementById(resultId).style.display = 'none';
        }

        function calculateST5() {
            if (!validateForm('st5Form')) return;
            let form = document.getElementById('st5Form');
            let score = 0;
            for (let i = 1; i <= 5; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            let result = '';
            if (score <= 4) result = 'ความเครียดระดับปกติ';
            else if (score <= 7) result = 'ความเครียดระดับน้อย';
            else if (score <= 9) result = 'ความเครียดระดับปานกลาง';
            else result = 'ความเครียดระดับรุนแรง';
            document.getElementById('st5Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('st5Result').style.display = 'block';
        }

        function calculate2Q9Q8Q() {
            if (!validateForm('2q9q8qForm')) return;
            let form = document.getElementById('2q9q8qForm');
            let score2Q = 0, score9Q = 0, score8Q = 0;
            let result2Q = '', result9Q = '', result8Q = '';

            // 2Q
            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="2q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            // 9Q
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="9q${i}"]:checked`);
                if (q) score9Q += parseInt(q.value);
            }
            if (score9Q <= 6) result9Q = 'ไม่เป็นโรคซึมเศร้า';
            else if (score9Q <= 12) result9Q = 'ซึมเศร้าระดับน้อย';
            else if (score9Q <= 18) result9Q = 'ซึมเศร้าระดับปานกลาง';
            else result9Q = 'ซึมเศร้าระดับรุนแรง';

            // 8Q
            for (let i = 1; i <= 8; i++) {
                let q = form.querySelector(`input[name="8q${i}"]:checked`);
                if (q) score8Q += parseInt(q.value);
            }
            if (score8Q === 0) result8Q = 'ไม่มีความเสี่ยง';
            else if (score8Q <= 8) result8Q = 'เสี่ยงต่ำ';
            else if (score8Q <= 16) result8Q = 'เสี่ยงปานกลาง';
            else result8Q = 'เสี่ยงสูง';

            document.getElementById('2q9q8qResult').innerHTML = `2Q: คะแนน ${score2Q} - ${result2Q}<br>9Q: คะแนน ${score9Q} - ${result9Q}<br>8Q: คะแนน ${score8Q} - ${result8Q}`;
            document.getElementById('2q9q8qResult').style.display = 'block';
        }

        function calculate2QPlus() {
            if (!validateForm('2qplusForm')) return;
            let form = document.getElementById('2qplusForm');
            let score2Q = 0, plus = 0;
            let result2Q = '', resultPlus = '';

            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            let p = form.querySelector(`input[name="plus"]:checked`);
            if (p) plus = parseInt(p.value);
            if (plus === 1) resultPlus = 'เสี่ยงฆ่าตัวตาย';
            else resultPlus = 'ไม่เสี่ยงฆ่าตัวตาย';

            document.getElementById('2qplusResult').innerHTML = `2Q: ${result2Q}<br>Plus: ${resultPlus}`;
            document.getElementById('2qplusResult').style.display = 'block';
        }

        function calculatePHQA() {
            if (!validateForm('phqaForm')) return;
            let form = document.getElementById('phqaForm');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score <= 4) result = 'ไม่มีภาวะซึมเศร้า';
            else if (score <= 9) result = 'ซึมเศร้าเล็กน้อย';
            else if (score <= 14) result = 'ซึมเศร้าปานกลาง';
            else if (score <= 19) result = 'ซึมเศร้ามาก';
            else result = 'ซึมเศร้ารุนแรง';

            let extra1 = form.querySelector(`input[name="extra1"]:checked`) ? form.querySelector(`input[name="extra1"]:checked`).value : 'ไม่ตอบ';
            let extra2 = form.querySelector(`input[name="extra2"]:checked`) ? form.querySelector(`input[name="extra2"]:checked`).value : 'ไม่ตอบ';

            document.getElementById('phqaResult').innerHTML = `คะแนนรวม: ${score} - ${result}<br>เคยพยายามทำร้ายตัวเอง: ${extra1 === '1' ? 'มี' : 'ไม่มี'}<br>เคยคิดอยากตาย: ${extra2 === '1' ? 'มี' : 'ไม่มี'}`;
            document.getElementById('phqaResult').style.display = 'block';
        }

        function calculateTMHI15() {
            if (!validateForm('tmhi15Form')) return;
            let form = document.getElementById('tmhi15Form');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 15; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score >= 33) result = 'สุขภาพจิตดีกว่าคนทั่วไป';
            else if (score >= 27) result = 'สุขภาพจิตเท่าคนทั่วไป';
            else result = 'สุขภาพจิตต่ำกว่าคนทั่วไป';
            document.getElementById('tmhi15Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('tmhi15Result').style.display = 'block';
        }

        function calculateRQ() {
            if (!validateForm('rqForm')) return;
            let form = document.getElementById('rqForm');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 20; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score < 60) result = 'พลังใจต่ำ (แนะนำพัฒนา)';
            else result = 'พลังใจดี';
            document.getElementById('rqResult').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('rqResult').style.display = 'block';
        }

        function calculateASSIST() {
            if (!validateForm('assistForm')) return;
            let form = document.getElementById('assistForm');
            let substance = document.getElementById('substance').value;
            let score = 0;
            let result = '';
            let isTobacco = substance === 'tobacco';

            let q1 = form.querySelector(`input[name="q1"]:checked`) ? parseInt(form.querySelector(`input[name="q1"]:checked`).value) : 0;
            if (q1 === 0) {
                result = 'ไม่เคยใช้สารนี้';
            } else {
                for (let i = 2; i <= 7; i++) {
                    let q = form.querySelector(`input[name="q${i}"]:checked`);
                    if (q && !(isTobacco && i === 5)) score += parseInt(q.value);
                }
                let q8 = form.querySelector(`input[name="q8"]:checked`) ? parseInt(form.querySelector(`input[name="q8"]:checked`).value) : 0;

                if (substance === 'alcohol') {
                    if (score <= 10) result = 'เสี่ยงต่ำ';
                    else if (score <= 26) result = 'เสี่ยงปานกลาง';
                    else result = 'เสี่ยงสูง';
                } else {
                    if (score <= 3) result = 'เสี่ยงต่ำ';
                    else if (score <= 26) result = 'เสี่ยงปานกลาง';
                    else result = 'เสี่ยงสูง';
                }
                if (q8 === 6) result += ' (มีการฉีดใน 3 เดือนที่แล้ว - เสี่ยงสูง)';
            }
            document.getElementById('assistResult').innerHTML = `สาร: ${substance}<br>คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('assistResult').style.display = 'block';
        }
    </script>
</body>
</html>
"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="th">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
#     <style>
#         body { font-family: Arial, sans-serif; margin: 20px; }
#         h1, h2 { text-align: center; }
#         section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
#         form { margin: 0 auto; max-width: 800px; }
#         label { display: block; margin: 10px 0; }
#         input[type="radio"] { margin-right: 10px; }
#         button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
#         button:hover { background-color: #45a049; }
#         .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
#         nav { text-align: center; margin-bottom: 30px; }
# ...

# %%
from IPython.display import HTML

html_content = """
<!DOCTYPE html>
<html lang="th">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
    <style>
        body { font-family: Arial, sans-serif; margin: 20px; }
        h1, h2 { text-align: center; }
        section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
        form { margin: 0 auto; max-width: 800px; }
        label { display: block; margin: 10px 0; }
        input[type="radio"] { margin-right: 10px; }
        button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
        button:hover { background-color: #45a049; }
        .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
        nav { text-align: center; margin-bottom: 30px; }
        nav a { margin: 10px; text-decoration: none; color: #007BFF; }
        nav a:hover { text-decoration: underline; }
        select { margin: 10px 0; }
    </style>
</head>
<body>
    <h1>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</h1>
    <p style="text-align: center;">ยินดีต้อนรับสู่แพลตฟอร์มประเมินสุขภาพจิตเบื้องต้น กรุณาเลือกแบบประเมินที่ต้องการจากเมนูด้านล่าง โปรดตอบตามความรู้สึกจริงเพื่อผลลัพธ์ที่แม่นยำที่สุด ผลลัพธ์นี้ไม่ใช่การวินิจฉัยทางการแพทย์ ควรปรึกษาแพทย์หากมีอาการรุนแรง</p>

    <nav>
        <a href="#st5">ST-5 (ความเครียด)</a> |
        <a href="#2q9q8q">2Q-9Q-8Q (ซึมเศร้า/ฆ่าตัวตาย)</a> |
        <a href="#2qplus">2Q Plus</a> |
        <a href="#phqa">PHQ-A (ซึมเศร้าในวัยรุ่น)</a> |
        <a href="#tmhi15">TMHI-15 (สุขภาพจิตคนไทย)</a> |
        <a href="#rq">RQ (พลังสุขภาพจิต)</a> |
        <a href="#assist">ASSIST (สารเสพติด)</a>
    </nav>

    <div style="text-align: center; margin-top: 20px;">
        <button type="button" onclick="saveAllAssessmentResults()">บันทึกผลลัพธ์ทั้งหมด</button>
    </div>
    <div id="allResultsSummary" class="result"></div>

    <!-- ST-5 -->
    <section id="st5">
        <h2>แบบประเมินความเครียด (ST-5)</h2>
        <form id="st5Form">
            <p>ในช่วง 2-4 สัปดาห์ที่ผ่านมา รวมวันนี้ อาการเหล่านี้รบกวนท่านมากน้อยเพียงใด</p>
            <label>1. ท่านรู้สึกปวดศีรษะหรือปวดต้นคอ</label>
            <input type="radio" name="q1" value="0"> แทบไม่มี (0)
            <input type="radio" name="q1" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q1" value="3"> เกือบตลอด (3)<br>

            <label>2. ท่านรู้สึกหงุดหงิด โมโหง่าย</label>
            <input type="radio" name="q2" value="0"> แทบไม่มี (0)
            <input type="radio" name="q2" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q2" value="3"> เกือบตลอด (3)<br>

            <label>3. ท่านรู้สึกเบื่อ เซ็ง</label>
            <input type="radio" name="q3" value="0"> แทบไม่มี (0)
            <input type="radio" name="q3" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q3" value="3"> เกือบตลอด (3)<br>

            <label>4. ท่านรู้สึกเครียด กลุ้มใจ</label>
            <input type="radio" name="q4" value="0"> แทบไม่มี (0)
            <input type="radio" name="q4" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q4" value="3"> เกือบตลอด (3)<br>

            <label>5. ท่านรู้สึกท้อแท้ หมดหวัง</label>
            <input type="radio" name="q5" value="0"> แทบไม่มี (0)
            <input type="radio" name="q5" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q5" value="3"> เกือบตลอด (3)<br>

            <button type="button" onclick="calculateST5()">คำนวณผล</button>
            <button type="button" onclick="clearForm('st5Form', 'st5Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="st5Result" class="result"></div>
    </section>

    <!-- 2Q-9Q-8Q -->
    <section id="2q9q8q">
        <h2>แบบประเมินซึมเศร้า / ฆ่าตัวตาย (2Q-9Q-8Q)</h2>
        <form id="2q9q8qForm">
            <h3>2Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านรู้สึก...</h3>
            <label>1. หดหู่ เศร้า หรือท้อแท้สิ้นหวัง</label>
            <input type="radio" name="2q1" value="0"> ไม่มี
            <input type="radio" name="2q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="2q2" value="0"> ไม่มี
            <input type="radio" name="2q2" value="1"> มี<br>

            <h3>9Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้บ่อยแค่ไหน</h3>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="9q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q1" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q1" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q1" value="3"> เป็นทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="9q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q2" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q2" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q2" value="3"> เป็นทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="9q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q3" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q3" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q3" value="3"> เป็นทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="9q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q4" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q4" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q4" value="3"> เป็นทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="9q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q5" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q5" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q5" value="3"> เป็นทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="9q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q6" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q6" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q6" value="3"> เป็นทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือพิมพ์หรือดูโทรทัศน์</label>
            <input type="radio" name="9q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q7" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q7" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q7" value="3"> เป็นทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="9q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q8" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q8" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q8" value="3"> เป็นทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="9q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q9" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q9" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q9" value="3"> เป็นทุกวัน (3)<br>

            <h3>8Q: ใน 1 เดือนที่ผ่านมา รวมวันนี้ ท่านมี...</h3>
            <label>1. ความคิดอยากตาย หรือคิดว่าตายเสียจะดีกว่า</label>
            <input type="radio" name="8q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q1" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q1" value="3"> เกือบทุกวัน (3)<br>

            <label>2. อยากทำร้ายตัวเอง หรือทำให้ตัวเองบาดเจ็บ</label>
            <input type="radio" name="8q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q2" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q2" value="3"> เกือบทุกวัน (3)<br>

            <label>3. คิดเกี่ยวกับความตาย</label>
            <input type="radio" name="8q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q3" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q3" value="3"> เกือบทุกวัน (3)<br>

            <label>4. มีแผนการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q4" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q4" value="3"> เกือบทุกวัน (3)<br>

            <label>5. มีแผนการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q5" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q5" value="3"> เกือบทุกวัน (3)<br>

            <label>6. เตรียมการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q6" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q6" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q6" value="3"> เกือบทุกวัน (3)<br>

            <label>7. เตรียมการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q7" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q7" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q7" value="3"> เกือบทุกวัน (3)<br>

            <label>8. ท่านเคยพยายามฆ่าตัวตาย</label>
            <input type="radio" name="8q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q8" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q8" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q8" value="3"> เกือบทุกวัน (3)<br>

            <button type="button" onclick="calculate2Q9Q8Q()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2q9q8qForm', '2q9q8qResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2q9q8qResult" class="result"></div>
    </section>

    <!-- 2Q Plus -->
    <section id="2qplus">
        <h2>แบบประเมิน 2Q Plus (ฉบับปรับปรุง)</h2>
        <form id="2qplusForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้หรือไม่</p>
            <label>1. ไม่สบายใจ เซ็ง ทุกข์ใจ เศร้า ท้อแท้ ซึม หงอย</label>
            <input type="radio" name="q1" value="0"> ไม่มี
            <input type="radio" name="q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่อยากพูดไม่อยากทำอะไร หรือทำอะไรก็ไม่สนุกเพลิดเพลินเหมือนเดิม</label>
            <input type="radio" name="q2" value="0"> ไม่มี
            <input type="radio" name="q2" value="1"> มี<br>

            <p>ใน 1 เดือนที่ผ่านมา รวมวันนี้</p>
            <label>ท่านมีความรู้สึกทุกข์ใจจนไม่อยากมีชีวิตอยู่หรือไม่</label>
            <input type="radio" name="plus" value="0"> ไม่มี
            <input type="radio" name="plus" value="1"> มี<br>

            <button type="button" onclick="calculate2QPlus()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2qplusForm', '2qplusResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2qplusResult" class="result"></div>
    </section>

    <!-- PHQ-A -->
    <section id="phqa">
        <h2>แบบประเมินภาวะซึมเศร้าในวัยรุ่น (PHQ-A)</h2>
        <form id="phqaForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา ท่านมีอาการเหล่านี้บ่อยแค่ไหน (สำหรับวัยรุ่นอายุ 11-20 ปี)</p>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q1" value="1"> มีบางวัน (1)
            <input type="radio" name="q1" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q1" value="3"> แทบทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q2" value="1"> มีบางวัน (1)
            <input type="radio" name="q2" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q2" value="3"> แทบทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q3" value="1"> มีบางวัน (1)
            <input type="radio" name="q3" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q3" value="3"> แทบทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q4" value="1"> มีบางวัน (1)
            <input type="radio" name="q4" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q4" value="3"> แทบทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q5" value="1"> มีบางวัน (1)
            <input type="radio" name="q5" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q5" value="3"> แทบทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q6" value="1"> มีบางวัน (1)
            <input type="radio" name="q6" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q6" value="3"> แทบทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือหรือดูโทรทัศน์</label>
            <input type="radio" name="q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q7" value="1"> มีบางวัน (1)
            <input type="radio" name="q7" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q7" value="3"> แทบทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q8" value="1"> มีบางวัน (1)
            <input type="radio" name="q8" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q8" value="3"> แทบทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q9" value="1"> มีบางวัน (1)
            <input type="radio" name="q9" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q9" value="3"> แทบทุกวัน (3)<br>

            <p>คำถามเพิ่มเติม (ไม่คิดคะแนน):</p>
            <label>ในปีที่ผ่านมา ท่านเคยพยายามทำร้ายตัวเองหรือไม่?</label>
            <input type="radio" name="extra1" value="0"> ไม่มี
            <input type="radio" name="extra1" value="1"> มี<br>

            <label>ในปีที่ผ่านมา ท่านเคยคิดอยากตายหรือไม่?</label>
            <input type="radio" name="extra2" value="0"> ไม่มี
            <input type="radio" name="extra2" value="1"> มี<br>

            <button type="button" onclick="calculatePHQA()">คำนวณผล</button>
            <button type="button" onclick="clearForm('phqaForm', 'phqaResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="phqaResult" class="result"></div>
    </section>

    <!-- TMHI-15 -->
    <section id="tmhi15">
        <h2>ดัชนีชี้วัดสุขภาพจิตของคนไทย (TMHI-15)</h2>
        <form id="tmhi15Form">
            <p>กรุณาเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด สำหรับประสบการณ์ในช่วง 1 เดือนที่ผ่านมา</p>
            <label>1. ท่านรู้สึกพึงพอใจในชีวิต</label>
            <input type="radio" name="q1" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q1" value="1"> เล็กน้อย (1)
            <input type="radio" name="q1" value="2"> มาก (2)
            <input type="radio" name="q1" value="3"> มากที่สุด (3)<br>

            <label>2. ท่านรู้สึกสบายใจ</label>
            <input type="radio" name="q2" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q2" value="1"> เล็กน้อย (1)
            <input type="radio" name="q2" value="2"> มาก (2)
            <input type="radio" name="q2" value="3"> มากที่สุด (3)<br>

            <label>3. ท่านรู้สึกเบื่อหน่ายท้อแท้กับการดำเนินชีวิตประจำวัน</label>
            <input type="radio" name="q3" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q3" value="2"> เล็กน้อย (2)
            <input type="radio" name="q3" value="1"> มาก (1)
            <input type="radio" name="q3" value="0"> มากที่สุด (0)<br>

            <label>4. ท่านรู้สึกผิดหวังในตัวเอง</label>
            <input type="radio" name="q4" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q4" value="2"> เล็กน้อย (2)
            <input type="radio" name="q4" value="1"> มาก (1)
            <input type="radio" name="q4" value="0"> มากที่สุด (0)<br>

            <label>5. ท่านรู้สึกว่าชีวิตของท่านมีแต่ความทุกข์</label>
            <input type="radio" name="q5" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q5" value="2"> เล็กน้อย (2)
            <input type="radio" name="q5" value="1"> มาก (1)
            <input type="radio" name="q5" value="0"> มากที่สุด (0)<br>

            <label>6. ท่านสามารถทำใจยอมรับได้สำหรับปัญหาที่ยากจะแก้ไข (เมื่อมีปัญหา)</label>
            <input type="radio" name="q6" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q6" value="1"> เล็กน้อย (1)
            <input type="radio" name="q6" value="2"> มาก (2)
            <input type="radio" name="q6" value="3"> มากที่สุด (3)<br>

            <label>7. ท่านมั่นใจว่าจะสามารถควบคุมอารมณ์ได้เมื่อมีเหตุการณ์คับขันหรือร้ายแรงเกิดขึ้น</label>
            <input type="radio" name="q7" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q7" value="1"> เล็กน้อย (1)
            <input type="radio" name="q7" value="2"> มาก (2)
            <input type="radio" name="q7" value="3"> มากที่สุด (3)<br>

            <label>8. ท่านมั่นใจที่จะเผชิญกับเหตุการณ์ร้ายแรงที่เกิดขึ้นในชีวิต</label>
            <input type="radio" name="q8" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q8" value="1"> เล็กน้อย (1)
            <input type="radio" name="q8" value="2"> มาก (2)
            <input type="radio" name="q8" value="3"> มากที่สุด (3)<br>

            <label>9. ท่านรู้สึกเห็นอกเห็นใจเมื่อผู้อื่นมีทุกข์</label>
            <input type="radio" name="q9" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q9" value="1"> เล็กน้อย (1)
            <input type="radio" name="q9" value="2"> มาก (2)
            <input type="radio" name="q9" value="3"> มากที่สุด (3)<br>

            <label>10. ท่านรู้สึกเป็นสุขในการช่วยเหลือผู้อื่นที่มีปัญหา</label>
            <input type="radio" name="q10" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q10" value="1"> เล็กน้อย (1)
            <input type="radio" name="q10" value="2"> มาก (2)
            <input type="radio" name="q10" value="3"> มากที่สุด (3)<br>

            <label>11. ท่านให้ความช่วยเหลือแก่ผู้อื่นเมื่อมีโอกาส</label>
            <input type="radio" name="q11" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q11" value="1"> เล็กน้อย (1)
            <input type="radio" name="q11" value="2"> มาก (2)
            <input type="radio" name="q11" value="3"> มากที่สุด (3)<br>

            <label>12. ท่านรู้สึกภูมิใจในตนเอง</label>
            <input type="radio" name="q12" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q12" value="1"> เล็กน้อย (1)
            <input type="radio" name="q12" value="2"> มาก (2)
            <input type="radio" name="q12" value="3"> มากที่สุด (3)<br>

            <label>13. ท่านรู้สึกมั่นคง ปลอดภัย เมื่ออยู่ในครอบครัว</label>
            <input type="radio" name="q13" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q13" value="1"> เล็กน้อย (1)
            <input type="radio" name="q13" value="2"> มาก (2)
            <input type="radio" name="q13" value="3"> มากที่สุด (3)<br>

            <label>14. หากท่านป่วยหนัก ท่านเชื่อว่าครอบครัวจะดูแลท่านเป็นอย่างดี</label>
            <input type="radio" name="q14" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q14" value="1"> เล็กน้อย (1)
            <input type="radio" name="q14" value="2"> มาก (2)
            <input type="radio" name="q14" value="3"> มากที่สุด (3)<br>

            <label>15. สมาชิกในครอบครัวมีความรักและผูกพันต่อกัน</label>
            <input type="radio" name="q15" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q15" value="1"> เล็กน้อย (1)
            <input type="radio" name="q15" value="2"> มาก (2)
            <input type="radio" name="q15" value="3"> มากที่สุด (3)<br>

            <button type="button" onclick="calculateTMHI15()">คำนวณผล</button>
            <button type="button" onclick="clearForm('tmhi15Form', 'tmhi15Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="tmhi15Result" class="result"></div>
    </section>

    <!-- RQ -->
    <section id="rq">
        <h2>แบบประเมินพลังสุขภาพจิต (RQ) ฉบับ 20 ข้อ</h2>
        <form id="rqForm">
            <p>โปรดเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด (1=ไม่จริงเลย, 2=ไม่จริง, 3=ค่อนข้างจริง, 4=จริงมาก)</p>
            <label>1. ฉันสามารถทนต่อแรงกดดันได้ดี</label>
            <input type="radio" name="q1" value="1"> 1
            <input type="radio" name="q1" value="2"> 2
            <input type="radio" name="q1" value="3"> 3
            <input type="radio" name="q1" value="4"> 4<br>

            <label>2. ฉันมักจะยอมแพ้เมื่อเจอปัญหายากๆ</label>
            <input type="radio" name="q2" value="4"> 1 (reverse)
            <input type="radio" name="q2" value="3"> 2
            <input type="radio" name="q2" value="2"> 3
            <input type="radio" name="q2" value="1"> 4<br>

            <label>3. ฉันสามารถปรับตัวเข้ากับการเปลี่ยนแปลงได้</label>
            <input type="radio" name="q3" value="1"> 1
            <input type="radio" name="q3" value="2"> 2
            <input type="radio" name="q3" value="3"> 3
            <input type="radio" name="q3" value="4"> 4<br>

            <label>4. ฉันรู้สึกสิ้นหวังเมื่อล้มเหลว</label>
            <input type="radio" name="q4" value="4"> 1 (reverse)
            <input type="radio" name="q4" value="3"> 2
            <input type="radio" name="q4" value="2"> 3
            <input type="radio" name="q4" value="1"> 4<br>

            <label>5. ฉันมีกำลังใจที่จะต่อสู้กับอุปสรรค</label>
            <input type="radio" name="q5" value="1"> 1
            <input type="radio" name="q5" value="2"> 2
            <input type="radio" name="q5" value="3"> 3
            <input type="radio" name="q5" value="4"> 4<br>

            <label>6. ฉันมักจะหงุดหงิดง่ายเมื่อมีปัญหา</label>
            <input type="radio" name="q6" value="4"> 1 (reverse)
            <input type="radio" name="q6" value="3"> 2
            <input type="radio" name="q6" value="2"> 3
            <input type="radio" name="q6" value="1"> 4<br>

            <label>7. ฉันสามารถหาทางแก้ปัญหาได้เสมอ</label>
            <input type="radio" name="q7" value="1"> 1
            <input type="radio" name="q7" value="2"> 2
            <input type="radio" name="q7" value="3"> 3
            <input type="radio" name="q7" value="4"> 4<br>

            <label>8. ฉันรู้สึกว่าชีวิตไร้ค่าเมื่อเจอวิกฤต</label>
            <input type="radio" name="q8" value="4"> 1 (reverse)
            <input type="radio" name="q8" value="3"> 2
            <input type="radio" name="q8" value="2"> 3
            <input type="radio" name="q8" value="1"> 4<br>

            <label>9. ฉันสามารถเรียนรู้จากความผิดพลาด</label>
            <input type="radio" name="q9" value="1"> 1
            <input type="radio" name="q9" value="2"> 2
            <input type="radio" name="q9" value="3"> 3
            <input type="radio" name="q9" value="4"> 4<br>

            <label>10. ฉันมักจะโทษตัวเองเมื่อสิ่งต่างๆผิดพลาด</label>
            <input type="radio" name="q10" value="4"> 1 (reverse)
            <input type="radio" name="q10" value="3"> 2
            <input type="radio" name="q10" value="2"> 3
            <input type="radio" name="q10" value="1"> 4<br>

            <label>11. ฉันมีแรงบันดาลใจจากเป้าหมายในชีวิต</label>
            <input type="radio" name="q11" value="1"> 1
            <input type="radio" name="q11" value="2"> 2
            <input type="radio" name="q11" value="3"> 3
            <input type="radio" name="q11" value="4"> 4<br>

            <label>12. ฉันรู้สึกหมดหวังง่าย</label>
            <input type="radio" name="q12" value="4"> 1 (reverse)
            <input type="radio" name="q12" value="3"> 2
            <input type="radio" name="q12" value="2"> 3
            <input type="radio" name="q12" value="1"> 4<br>

            <label>13. ฉันสามารถขอความช่วยเหลือจากผู้อื่นได้</label>
            <input type="radio" name="q13" value="1"> 1
            <input type="radio" name="q13" value="2"> 2
            <input type="radio" name="q13" value="3"> 3
            <input type="radio" name="q13" value="4"> 4<br>

            <label>14. ฉันมักจะรู้สึกโดดเดี่ยวเมื่อมีปัญหา</label>
            <input type="radio" name="q14" value="4"> 1 (reverse)
            <input type="radio" name="q14" value="3"> 2
            <input type="radio" name="q14" value="2"> 3
            <input type="radio" name="q14" value="1"> 4<br>

            <label>15. ฉันสามารถควบคุมอารมณ์ได้ดี</label>
            <input type="radio" name="q15" value="1"> 1
            <input type="radio" name="q15" value="2"> 2
            <input type="radio" name="q15" value="3"> 3
            <input type="radio" name="q15" value="4"> 4<br>

            <label>16. ฉันมักจะตื่นตระหนกเมื่อเจอสถานการณ์ยากลำบาก</label>
            <input type="radio" name="q16" value="4"> 1 (reverse)
            <input type="radio" name="q16" value="3"> 2
            <input type="radio" name="q16" value="2"> 3
            <input type="radio" name="q16" value="1"> 4<br>

            <label>17. ฉันเชื่อว่าทุกปัญหามีทางออก</label>
            <input type="radio" name="q17" value="1"> 1
            <input type="radio" name="q17" value="2"> 2
            <input type="radio" name="q17" value="3"> 3
            <input type="radio" name="q17" value="4"> 4<br>

            <label>18. ฉันรู้สึกว่าตนเองอ่อนแอ</label>
            <input type="radio" name="q18" value="4"> 1 (reverse)
            <input type="radio" name="q18" value="3"> 2
            <input type="radio" name="q18" value="2"> 3
            <input type="radio" name="q18" value="1"> 4<br>

            <label>19. ฉันสามารถฟื้นตัวจากความล้มเหลวได้</label>
            <input type="radio" name="q19" value="1"> 1
            <input type="radio" name="q19" value="2"> 2
            <input type="radio" name="q19" value="3"> 3
            <input type="radio" name="q19" value="4"> 4<br>

            <label>20. ฉันมักจะยอมแพ้ก่อนที่จะพยายาม</label>
            <input type="radio" name="q20" value="4"> 1 (reverse)
            <input type="radio" name="q20" value="3"> 2
            <input type="radio" name="q20" value="2"> 3
            <input type="radio" name="q20" value="1"> 4<br>

            <button type="button" onclick="calculateRQ()">คำนวณผล</button>
            <button type="button" onclick="clearForm('rqForm', 'rqResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="rqResult" class="result"></div>
    </section>

    <!-- ASSIST -->
    <section id="assist">
        <h2>แบบประเมินความเสี่ยงต่อการใช้สารเสพติด (ASSIST)</h2>
        <form id="assistForm">
            <p>เลือกสารที่ต้องการประเมิน (สามารถเลือกหลายสารได้ แต่คำนวณทีละสารเพื่อความง่าย)</p>
            <select id="substance">
                <option value="tobacco">ยาสูบ</option>
                <option value="alcohol">สุรา</option>
                <option value="cannabis">กัญชา</option>
                <option value="cocaine">โคเคน</option>
                <option value="amphetamine">ยาบ้า/แอมเฟตามีน</option>
                <option value="inhalants">สารระเหย</option>
                <option value="sedatives">ยานอนหลับ</option>
                <option value="hallucinogens">ยาหลอนประสาท</option>
                <option value="opioids">ฝิ่น</option>
                <option value="other">อื่นๆ</option>
            </select><br>

            <label>Q1: ในชีวิตท่านเคยใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q1" value="0"> ไม่เคย
            <input type="radio" name="q1" value="1"> เคย (หากไม่เคย ข้ามไป)<br>

            <label>Q2: ใน 3 เดือนที่ผ่านมา ท่านใช้สารนี้บ่อยเพียงใด?</label>
            <input type="radio" name="q2" value="0"> ไม่เคย (0)
            <input type="radio" name="q2" value="2"> 1-2 ครั้ง (2)
            <input type="radio" name="q2" value="3"> ทุกเดือน (3)
            <input type="radio" name="q2" value="4"> ทุกสัปดาห์ (4)
            <input type="radio" name="q2" value="6"> เกือบทุกวัน (6)<br>

            <label>Q3: ใน 3 เดือนที่ผ่านมา ท่านรู้สึกอยากใช้สารนี้อย่างรุนแรงบ่อยเพียงใด?</label>
            <input type="radio" name="q3" value="0"> ไม่เคย (0)
            <input type="radio" name="q3" value="3"> 1-2 ครั้ง (3)
            <input type="radio" name="q3" value="4"> ทุกเดือน (4)
            <input type="radio" name="q3" value="5"> ทุกสัปดาห์ (5)
            <input type="radio" name="q3" value="6"> เกือบทุกวัน (6)<br>

            <label>Q4: ใน 3 เดือนที่ผ่านมา การใช้สารนี้ทำให้เกิดปัญหาสุขภาพ สังคม กฎหมาย การเงิน ต่อท่านบ่อยเพียงใด?</label>
            <input type="radio" name="q4" value="0"> ไม่เคย (0)
            <input type="radio" name="q4" value="4"> 1-2 ครั้ง (4)
            <input type="radio" name="q4" value="5"> ทุกเดือน (5)
            <input type="radio" name="q4" value="6"> ทุกสัปดาห์ (6)
            <input type="radio" name="q4" value="7"> เกือบทุกวัน (7)<br>

            <label>Q5: ใน 3 เดือนที่ผ่านมา ท่านไม่สามารถทำกิจกรรมปกติเพราะใช้สารนี้บ่อยเพียงใด? (ยกเว้นยาสูบ)</label>
            <input type="radio" name="q5" value="0"> ไม่เคย (0)
            <input type="radio" name="q5" value="5"> 1-2 ครั้ง (5)
            <input type="radio" name="q5" value="6"> ทุกเดือน (6)
            <input type="radio" name="q5" value="7"> ทุกสัปดาห์ (7)
            <input type="radio" name="q5" value="8"> เกือบทุกวัน (8)<br>

            <label>Q6: เพื่อน ญาติ หรือคนอื่นเคยแสดงความห่วงใยหรือตักเตือนท่านเกี่ยวกับการใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q6" value="0"> ไม่เคย (0)
            <input type="radio" name="q6" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q6" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q7: ท่านเคยพยายามหยุดหรือลดการใช้สารนี้แต่ไม่สำเร็จหรือไม่?</label>
            <input type="radio" name="q7" value="0"> ไม่เคย (0)
            <input type="radio" name="q7" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q7" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q8: ท่านเคยใช้สารนี้โดยการฉีดหรือไม่?</label>
            <input type="radio" name="q8" value="0"> ไม่เคย (0)
            <input type="radio" name="q8" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q8" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <button type="button" onclick="calculateASSIST()">คำนวณผล</button>
            <button type="button" onclick="clearForm('assistForm', 'assistResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="assistResult" class="result"></div>
    </section>

    <script>
        function validateForm(formId) {
            const form = document.getElementById(formId);
            const radioGroups = {};
            form.querySelectorAll('input[type="radio"]').forEach(radio => {
                if (!radioGroups[radio.name]) {
                    radioGroups[radio.name] = [];
                }
                radioGroups[radio.name].push(radio);
            });

            for (const groupName in radioGroups) {
                const group = radioGroups[groupName];
                const isChecked = group.some(radio => radio.checked);
                if (!isChecked) {
                    alert('กรุณาตอบคำถามทุกข้อในแบบประเมินนี้');
                    return false;
                }
            }
            return true;
        }

        function clearForm(formId, resultId) {
            document.getElementById(formId).reset();
            document.getElementById(resultId).innerHTML = '';
            document.getElementById(resultId).style.display = 'none';
        }

        const substanceMapping = {
            'tobacco': 'ยาสูบ',
            'alcohol': 'สุรา',
            'cannabis': 'กัญชา',
            'cocaine': 'โคเคน',
            'amphetamine': 'ยาบ้า/แอมเฟตามีน',
            'inhalants': 'สารระเหย',
            'sedatives': 'ยานอนหลับ',
            'hallucinogens': 'ยาหลอนประสาท',
            'opioids': 'ฝิ่น',
            'other': 'อื่นๆ'
        };

        function calculateST5() {
            if (!validateForm('st5Form')) return;
            let form = document.getElementById('st5Form');
            let score = 0;
            for (let i = 1; i <= 5; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            let result = '';
            if (score <= 4) result = 'ความเครียดระดับปกติ';
            else if (score <= 7) result = 'ความเครียดระดับน้อย';
            else if (score <= 9) result = 'ความเครียดระดับปานกลาง';
            else result = 'ความเครียดระดับรุนแรง';
            document.getElementById('st5Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('st5Result').style.display = 'block';
        }

        function calculate2Q9Q8Q() {
            if (!validateForm('2q9q8qForm')) return;
            let form = document.getElementById('2q9q8qForm');
            let score2Q = 0, score9Q = 0, score8Q = 0;
            let result2Q = '', result9Q = '', result8Q = '';

            // 2Q
            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="2q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            // 9Q
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="9q${i}"]:checked`);
                if (q) score9Q += parseInt(q.value);
            }
            if (score9Q <= 6) result9Q = 'ไม่เป็นโรคซึมเศร้า';
            else if (score9Q <= 12) result9Q = 'ซึมเศร้าระดับน้อย';
            else if (score9Q <= 18) result9Q = 'ซึมเศร้าระดับปานกลาง';
            else result9Q = 'ซึมเศร้าระดับรุนแรง';

            // 8Q
            for (let i = 1; i <= 8; i++) {
                let q = form.querySelector(`input[name="8q${i}"]:checked`);
                if (q) score8Q += parseInt(q.value);
            }
            if (score8Q === 0) result8Q = 'ไม่มีความเสี่ยง';
            else if (score8Q <= 8) result8Q = 'เสี่ยงต่ำ';
            else if (score8Q <= 16) result8Q = 'เสี่ยงปานกลาง';
            else result8Q = 'เสี่ยงสูง';

            document.getElementById('2q9q8qResult').innerHTML = `2Q: คะแนน ${score2Q} - ${result2Q}<br>9Q: คะแนน ${score9Q} - ${result9Q}<br>8Q: คะแนน ${score8Q} - ${result8Q}`;
            document.getElementById('2q9q8qResult').style.display = 'block';
        }

        function calculate2QPlus() {
            if (!validateForm('2qplusForm')) return;
            let form = document.getElementById('2qplusForm');
            let score2Q = 0, plus = 0;
            let result2Q = '', resultPlus = '';

            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            let p = form.querySelector(`input[name="plus"]:checked`);
            if (p) plus = parseInt(p.value);
            if (plus === 1) resultPlus = 'เสี่ยงฆ่าตัวตาย';
            else resultPlus = 'ไม่เสี่ยงฆ่าตัวตาย';

            document.getElementById('2qplusResult').innerHTML = `2Q: ${result2Q}<br>Plus: ${resultPlus}`;
            document.getElementById('2qplusResult').style.display = 'block';
        }

        function calculatePHQA() {
            if (!validateForm('phqaForm')) return;
            let form = document.getElementById('phqaForm');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score <= 4) result = 'ไม่มีภาวะซึมเศร้า';
            else if (score <= 9) result = 'ซึมเศร้าเล็กน้อย';
            else if (score <= 14) result = 'ซึมเศร้าปานกลาง';
            else if (score <= 19) result = 'ซึมเศร้ามาก';
            else result = 'ซึมเศร้ารุนแรง';

            let extra1 = form.querySelector(`input[name="extra1"]:checked`) ? form.querySelector(`input[name="extra1"]:checked`).value : 'ไม่ตอบ';
            let extra2 = form.querySelector(`input[name="extra2"]:checked`) ? form.querySelector(`input[name="extra2"]:checked`).value : 'ไม่ตอบ';

            document.getElementById('phqaResult').innerHTML = `คะแนนรวม: ${score} - ${result}<br>เคยพยายามทำร้ายตัวเอง: ${extra1 === '1' ? 'มี' : 'ไม่มี'}<br>เคยคิดอยากตาย: ${extra2 === '1' ? 'มี' : 'ไม่มี'}`;
            document.getElementById('phqaResult').style.display = 'block';
        }

        function calculateTMHI15() {
            if (!validateForm('tmhi15Form')) return;
            let form = document.getElementById('tmhi15Form');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 15; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score >= 33) result = 'สุขภาพจิตดีกว่าคนทั่วไป';
            else if (score >= 27) result = 'สุขภาพจิตเท่าคนทั่วไป';
            else result = 'สุขภาพจิตต่ำกว่าคนทั่วไป';
            document.getElementById('tmhi15Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('tmhi15Result').style.display = 'block';
        }

        function calculateRQ() {
            if (!validateForm('rqForm')) return;
            let form = document.getElementById('rqForm');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 20; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score < 60) result = 'พลังใจต่ำ (แนะนำพัฒนา)';
            else result = 'พลังใจดี';
            document.getElementById('rqResult').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('rqResult').style.display = 'block';
        }

        function calculateASSIST() {
            if (!validateForm('assistForm')) return;
            let form = document.getElementById('assistForm');
            let substance = document.getElementById('substance').value;
            let score = 0;
            let resultHtml = '';
            let isTobacco = substance === 'tobacco';

            let q1 = form.querySelector(`input[name="q1"]:checked`) ? parseInt(form.querySelector(`input[name="q1"]:checked`).value) : 0;

            resultHtml += `สารที่ประเมิน: **${substanceMapping[substance]}**<br>`;

            if (q1 === 0) {
                resultHtml += 'ผลลัพธ์: **ไม่เคยใช้สารนี้**';
            } else {
                for (let i = 2; i <= 7; i++) {
                    let q = form.querySelector(`input[name="q${i}"]:checked`);
                    if (q && !(isTobacco && i === 5)) score += parseInt(q.value);
                }
                let q8 = form.querySelector(`input[name="q8"]:checked`) ? parseInt(form.querySelector(`input[name="q8"]:checked`).value) : 0;

                resultHtml += `คะแนนรวม: **${score}**<br>`;

                let riskLevel = '';
                if (substance === 'alcohol') {
                    if (score >= 27) riskLevel = 'เสี่ยงสูง';
                    else if (score >= 11) riskLevel = 'เสี่ยงปานกลาง';
                    else riskLevel = 'เสี่ยงต่ำ';
                } else { // All other substances
                    if (score >= 27) riskLevel = 'เสี่ยงสูง';
                    else if (score >= 4) riskLevel = 'เสี่ยงปานกลาง';
                    else riskLevel = 'เสี่ยงต่ำ';
                }
                resultHtml += `ระดับความเสี่ยง: **${riskLevel}**<br>`;

                if (q8 === 6) {
                    resultHtml += '<span style="color: red; font-weight: bold;">ข้อควรระวัง: มีการฉีดสารนี้ใน 3 เดือนที่ผ่านมา ซึ่งมีความเสี่ยงสูงมาก</span>';
                }
            }
            document.getElementById('assistResult').innerHTML = resultHtml;
            document.getElementById('assistResult').style.display = 'block';
        }

        function saveAllAssessmentResults() {
            let allResults = [];
            const resultDivs = {
                'st5Result': 'ST-5 (ความเครียด)',
                '2q9q8qResult': '2Q-9Q-8Q (ซึมเศร้า/ฆ่าตัวตาย)',
                '2qplusResult': '2Q Plus',
                'phqaResult': 'PHQ-A (ซึมเศร้าในวัยรุ่น)',
                'tmhi15Result': 'TMHI-15 (สุขภาพจิตคนไทย)',
                'rqResult': 'RQ (พลังสุขภาพจิต)',
                'assistResult': 'ASSIST (สารเสพติด)'
            };

            let foundResults = false;
            for (const id in resultDivs) {
                const resultDiv = document.getElementById(id);
                if (resultDiv && resultDiv.style.display === 'block' && resultDiv.innerHTML.trim() !== '') {
                    allResults.push(`<h3>${resultDivs[id]}</h3>${resultDiv.innerHTML}`);
                    foundResults = true;
                }
            }

            const allResultsSummaryDiv = document.getElementById('allResultsSummary');
            if (foundResults) {
                allResultsSummaryDiv.innerHTML = `<h2>สรุปผลการประเมินทั้งหมด</h2>${allResults.join('<hr>')}`;
                allResultsSummaryDiv.style.display = 'block';
                alert('ผลลัพธ์ทั้งหมดถูกรวบรวมไว้ด้านล่างแล้ว สามารถคัดลอกได้');
            } else {
                allResultsSummaryDiv.innerHTML = 'ยังไม่มีผลการประเมินใดๆ กรุณาทำแบบประเมินก่อน';
                allResultsSummaryDiv.style.display = 'block';
            }
        }
    </script>
</body>
</html>
"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="th">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
#     <style>
#         body { font-family: Arial, sans-serif; margin: 20px; }
#         h1, h2 { text-align: center; }
#         section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
#         form { margin: 0 auto; max-width: 800px; }
#         label { display: block; margin: 10px 0; }
#         input[type="radio"] { margin-right: 10px; }
#         button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
#         button:hover { background-color: #45a049; }
#         .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
#         nav { text-align: center; margin-bottom: 30px; }
# ...

# %%
from IPython.display import HTML

html_content = """
<!DOCTYPE html>
<html lang="th">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
    <style>
        body { font-family: Arial, sans-serif; margin: 20px; }
        h1, h2 { text-align: center; }
        section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
        form { margin: 0 auto; max-width: 800px; }
        label { display: block; margin: 10px 0; }
        input[type="radio"] { margin-right: 10px; }
        button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
        button:hover { background-color: #45a049; }
        .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
        nav { text-align: center; margin-bottom: 30px; }
        nav a { margin: 10px; text-decoration: none; color: #007BFF; }
        nav a:hover { text-decoration: underline; }
        select { margin: 10px 0; }
    </style>
</head>
<body>
    <h1>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</h1>
    <p style="text-align: center;">ยินดีต้อนรับสู่แพลตฟอร์มประเมินสุขภาพจิตเบื้องต้น กรุณาเลือกแบบประเมินที่ต้องการจากเมนูด้านล่าง โปรดตอบตามความรู้สึกจริงเพื่อผลลัพธ์ที่แม่นยำที่สุด ผลลัพธ์นี้ไม่ใช่การวินิจฉัยทางการแพทย์ ควรปรึกษาแพทย์หากมีอาการรุนแรง</p>

    <nav>
        <a href="#st5">ST-5 (ความเครียด)</a> |
        <a href="#2q9q8q">2Q-9Q-8Q (ซึมเศร้า/ฆ่าตัวตาย)</a> |
        <a href="#2qplus">2Q Plus</a> |
        <a href="#phqa">PHQ-A (ซึมเศร้าในวัยรุ่น)</a> |
        <a href="#tmhi15">TMHI-15 (สุขภาพจิตคนไทย)</a> |
        <a href="#rq">RQ (พลังสุขภาพจิต)</a> |
        <a href="#assist">ASSIST (สารเสพติด)</a>
    </nav>

    <!-- ST-5 -->
    <section id="st5">
        <h2>แบบประเมินความเครียด (ST-5)</h2>
        <form id="st5Form">
            <p>ในช่วง 2-4 สัปดาห์ที่ผ่านมา รวมวันนี้ อาการเหล่านี้รบกวนท่านมากน้อยเพียงใด</p>
            <label>1. ท่านรู้สึกปวดศีรษะหรือปวดต้นคอ</label>
            <input type="radio" name="q1" value="0"> แทบไม่มี (0)
            <input type="radio" name="q1" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q1" value="3"> เกือบตลอด (3)<br>

            <label>2. ท่านรู้สึกหงุดหงิด โมโหง่าย</label>
            <input type="radio" name="q2" value="0"> แทบไม่มี (0)
            <input type="radio" name="q2" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q2" value="3"> เกือบตลอด (3)<br>

            <label>3. ท่านรู้สึกเบื่อ เซ็ง</label>
            <input type="radio" name="q3" value="0"> แทบไม่มี (0)
            <input type="radio" name="q3" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q3" value="3"> เกือบตลอด (3)<br>

            <label>4. ท่านรู้สึกเครียด กลุ้มใจ</label>
            <input type="radio" name="q4" value="0"> แทบไม่มี (0)
            <input type="radio" name="q4" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q4" value="3"> เกือบตลอด (3)<br>

            <label>5. ท่านรู้สึกท้อแท้ หมดหวัง</label>
            <input type="radio" name="q5" value="0"> แทบไม่มี (0)
            <input type="radio" name="q5" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q5" value="3"> เกือบตลอด (3)<br>

            <button type="button" onclick="calculateST5()">คำนวณผล</button>
            <button type="button" onclick="clearForm('st5Form', 'st5Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="st5Result" class="result"></div>
    </section>

    <!-- 2Q-9Q-8Q -->
    <section id="2q9q8q">
        <h2>แบบประเมินซึมเศร้า / ฆ่าตัวตาย (2Q-9Q-8Q)</h2>
        <form id="2q9q8qForm">
            <h3>2Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านรู้สึก...</h3>
            <label>1. หดหู่ เศร้า หรือท้อแท้สิ้นหวัง</label>
            <input type="radio" name="2q1" value="0"> ไม่มี
            <input type="radio" name="2q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="2q2" value="0"> ไม่มี
            <input type="radio" name="2q2" value="1"> มี<br>

            <h3>9Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้บ่อยแค่ไหน</h3>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="9q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q1" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q1" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q1" value="3"> เป็นทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="9q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q2" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q2" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q2" value="3"> เป็นทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="9q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q3" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q3" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q3" value="3"> เป็นทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="9q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q4" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q4" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q4" value="3"> เป็นทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="9q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q5" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q5" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q5" value="3"> เป็นทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="9q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q6" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q6" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q6" value="3"> เป็นทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือพิมพ์หรือดูโทรทัศน์</label>
            <input type="radio" name="9q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q7" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q7" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q7" value="3"> เป็นทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="9q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q8" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q8" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q8" value="3"> เป็นทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="9q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q9" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q9" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q9" value="3"> เป็นทุกวัน (3)<br>

            <h3>8Q: ใน 1 เดือนที่ผ่านมา รวมวันนี้ ท่านมี...</h3>
            <label>1. ความคิดอยากตาย หรือคิดว่าตายเสียจะดีกว่า</label>
            <input type="radio" name="8q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q1" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q1" value="3"> เกือบทุกวัน (3)<br>

            <label>2. อยากทำร้ายตัวเอง หรือทำให้ตัวเองบาดเจ็บ</label>
            <input type="radio" name="8q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q2" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q2" value="3"> เกือบทุกวัน (3)<br>

            <label>3. คิดเกี่ยวกับความตาย</label>
            <input type="radio" name="8q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q3" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q3" value="3"> เกือบทุกวัน (3)<br>

            <label>4. มีแผนการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q4" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q4" value="3"> เกือบทุกวัน (3)<br>

            <label>5. มีแผนการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q5" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q5" value="3"> เกือบทุกวัน (3)<br>

            <label>6. เตรียมการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q6" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q6" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q6" value="3"> เกือบทุกวัน (3)<br>

            <label>7. เตรียมการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q7" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q7" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q7" value="3"> เกือบทุกวัน (3)<br>

            <label>8. ท่านเคยพยายามฆ่าตัวตาย</label>
            <input type="radio" name="8q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q8" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q8" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q8" value="3"> เกือบทุกวัน (3)<br>

            <button type="button" onclick="calculate2Q9Q8Q()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2q9q8qForm', '2q9q8qResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2q9q8qResult" class="result"></div>
    </section>

    <!-- 2Q Plus -->
    <section id="2qplus">
        <h2>แบบประเมิน 2Q Plus (ฉบับปรับปรุง)</h2>
        <form id="2qplusForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้หรือไม่</p>
            <label>1. ไม่สบายใจ เซ็ง ทุกข์ใจ เศร้า ท้อแท้ ซึม หงอย</label>
            <input type="radio" name="q1" value="0"> ไม่มี
            <input type="radio" name="q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่อยากพูดไม่อยากทำอะไร หรือทำอะไรก็ไม่สนุกเพลิดเพลินเหมือนเดิม</label>
            <input type="radio" name="q2" value="0"> ไม่มี
            <input type="radio" name="q2" value="1"> มี<br>

            <p>ใน 1 เดือนที่ผ่านมา รวมวันนี้</p>
            <label>ท่านมีความรู้สึกทุกข์ใจจนไม่อยากมีชีวิตอยู่หรือไม่</label>
            <input type="radio" name="plus" value="0"> ไม่มี
            <input type="radio" name="plus" value="1"> มี<br>

            <button type="button" onclick="calculate2QPlus()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2qplusForm', '2qplusResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2qplusResult" class="result"></div>
    </section>

    <!-- PHQ-A -->
    <section id="phqa">
        <h2>แบบประเมินภาวะซึมเศร้าในวัยรุ่น (PHQ-A)</h2>
        <form id="phqaForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา ท่านมีอาการเหล่านี้บ่อยแค่ไหน (สำหรับวัยรุ่นอายุ 11-20 ปี)</p>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q1" value="1"> มีบางวัน (1)
            <input type="radio" name="q1" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q1" value="3"> แทบทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q2" value="1"> มีบางวัน (1)
            <input type="radio" name="q2" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q2" value="3"> แทบทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q3" value="1"> มีบางวัน (1)
            <input type="radio" name="q3" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q3" value="3"> แทบทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q4" value="1"> มีบางวัน (1)
            <input type="radio" name="q4" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q4" value="3"> แทบทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q5" value="1"> มีบางวัน (1)
            <input type="radio" name="q5" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q5" value="3"> แทบทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q6" value="1"> มีบางวัน (1)
            <input type="radio" name="q6" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q6" value="3"> แทบทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือหรือดูโทรทัศน์</label>
            <input type="radio" name="q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q7" value="1"> มีบางวัน (1)
            <input type="radio" name="q7" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q7" value="3"> แทบทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q8" value="1"> มีบางวัน (1)
            <input type="radio" name="q8" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q8" value="3"> แทบทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q9" value="1"> มีบางวัน (1)
            <input type="radio" name="q9" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q9" value="3"> แทบทุกวัน (3)<br>

            <p>คำถามเพิ่มเติม (ไม่คิดคะแนน):</p>
            <label>ในปีที่ผ่านมา ท่านเคยพยายามทำร้ายตัวเองหรือไม่?</label>
            <input type="radio" name="extra1" value="0"> ไม่มี
            <input type="radio" name="extra1" value="1"> มี<br>

            <label>ในปีที่ผ่านมา ท่านเคยคิดอยากตายหรือไม่?</label>
            <input type="radio" name="extra2" value="0"> ไม่มี
            <input type="radio" name="extra2" value="1"> มี<br>

            <button type="button" onclick="calculatePHQA()">คำนวณผล</button>
            <button type="button" onclick="clearForm('phqaForm', 'phqaResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="phqaResult" class="result"></div>
    </section>

    <!-- TMHI-15 -->
    <section id="tmhi15">
        <h2>ดัชนีชี้วัดสุขภาพจิตของคนไทย (TMHI-15)</h2>
        <form id="tmhi15Form">
            <p>กรุณาเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด สำหรับประสบการณ์ในช่วง 1 เดือนที่ผ่านมา</p>
            <label>1. ท่านรู้สึกพึงพอใจในชีวิต</label>
            <input type="radio" name="q1" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q1" value="1"> เล็กน้อย (1)
            <input type="radio" name="q1" value="2"> มาก (2)
            <input type="radio" name="q1" value="3"> มากที่สุด (3)<br>

            <label>2. ท่านรู้สึกสบายใจ</label>
            <input type="radio" name="q2" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q2" value="1"> เล็กน้อย (1)
            <input type="radio" name="q2" value="2"> มาก (2)
            <input type="radio" name="q2" value="3"> มากที่สุด (3)<br>

            <label>3. ท่านรู้สึกเบื่อหน่ายท้อแท้กับการดำเนินชีวิตประจำวัน</label>
            <input type="radio" name="q3" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q3" value="2"> เล็กน้อย (2)
            <input type="radio" name="q3" value="1"> มาก (1)
            <input type="radio" name="q3" value="0"> มากที่สุด (0)<br>

            <label>4. ท่านรู้สึกผิดหวังในตัวเอง</label>
            <input type="radio" name="q4" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q4" value="2"> เล็กน้อย (2)
            <input type="radio" name="q4" value="1"> มาก (1)
            <input type="radio" name="q4" value="0"> มากที่สุด (0)<br>

            <label>5. ท่านรู้สึกว่าชีวิตของท่านมีแต่ความทุกข์</label>
            <input type="radio" name="q5" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q5" value="2"> เล็กน้อย (2)
            <input type="radio" name="q5" value="1"> มาก (1)
            <input type="radio" name="q5" value="0"> มากที่สุด (0)<br>

            <label>6. ท่านสามารถทำใจยอมรับได้สำหรับปัญหาที่ยากจะแก้ไข (เมื่อมีปัญหา)</label>
            <input type="radio" name="q6" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q6" value="1"> เล็กน้อย (1)
            <input type="radio" name="q6" value="2"> มาก (2)
            <input type="radio" name="q6" value="3"> มากที่สุด (3)<br>

            <label>7. ท่านมั่นใจว่าจะสามารถควบคุมอารมณ์ได้เมื่อมีเหตุการณ์คับขันหรือร้ายแรงเกิดขึ้น</label>
            <input type="radio" name="q7" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q7" value="1"> เล็กน้อย (1)
            <input type="radio" name="q7" value="2"> มาก (2)
            <input type="radio" name="q7" value="3"> มากที่สุด (3)<br>

            <label>8. ท่านมั่นใจที่จะเผชิญกับเหตุการณ์ร้ายแรงที่เกิดขึ้นในชีวิต</label>
            <input type="radio" name="q8" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q8" value="1"> เล็กน้อย (1)
            <input type="radio" name="q8" value="2"> มาก (2)
            <input type="radio" name="q8" value="3"> มากที่สุด (3)<br>

            <label>9. ท่านรู้สึกเห็นอกเห็นใจเมื่อผู้อื่นมีทุกข์</label>
            <input type="radio" name="q9" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q9" value="1"> เล็กน้อย (1)
            <input type="radio" name="q9" value="2"> มาก (2)
            <input type="radio" name="q9" value="3"> มากที่สุด (3)<br>

            <label>10. ท่านรู้สึกเป็นสุขในการช่วยเหลือผู้อื่นที่มีปัญหา</label>
            <input type="radio" name="q10" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q10" value="1"> เล็กน้อย (1)
            <input type="radio" name="q10" value="2"> มาก (2)
            <input type="radio" name="q10" value="3"> มากที่สุด (3)<br>

            <label>11. ท่านให้ความช่วยเหลือแก่ผู้อื่นเมื่อมีโอกาส</label>
            <input type="radio" name="q11" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q11" value="1"> เล็กน้อย (1)
            <input type="radio" name="q11" value="2"> มาก (2)
            <input type="radio" name="q11" value="3"> มากที่สุด (3)<br>

            <label>12. ท่านรู้สึกภูมิใจในตนเอง</label>
            <input type="radio" name="q12" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q12" value="1"> เล็กน้อย (1)
            <input type="radio" name="q12" value="2"> มาก (2)
            <input type="radio" name="q12" value="3"> มากที่สุด (3)<br>

            <label>13. ท่านรู้สึกมั่นคง ปลอดภัย เมื่ออยู่ในครอบครัว</label>
            <input type="radio" name="q13" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q13" value="1"> เล็กน้อย (1)
            <input type="radio" name="q13" value="2"> มาก (2)
            <input type="radio" name="q13" value="3"> มากที่สุด (3)<br>

            <label>14. หากท่านป่วยหนัก ท่านเชื่อว่าครอบครัวจะดูแลท่านเป็นอย่างดี</label>
            <input type="radio" name="q14" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q14" value="1"> เล็กน้อย (1)
            <input type="radio" name="q14" value="2"> มาก (2)
            <input type="radio" name="q14" value="3"> มากที่สุด (3)<br>

            <label>15. สมาชิกในครอบครัวมีความรักและผูกพันต่อกัน</label>
            <input type="radio" name="q15" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q15" value="1"> เล็กน้อย (1)
            <input type="radio" name="q15" value="2"> มาก (2)
            <input type="radio" name="q15" value="3"> มากที่สุด (3)<br>

            <button type="button" onclick="calculateTMHI15()">คำนวณผล</button>
            <button type="button" onclick="clearForm('tmhi15Form', 'tmhi15Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="tmhi15Result" class="result"></div>
    </section>

    <!-- RQ -->
    <section id="rq">
        <h2>แบบประเมินพลังสุขภาพจิต (RQ) ฉบับ 20 ข้อ</h2>
        <form id="rqForm">
            <p>โปรดเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด (1=ไม่จริงเลย, 2=ไม่จริง, 3=ค่อนข้างจริง, 4=จริงมาก)</p>
            <label>1. ฉันสามารถทนต่อแรงกดดันได้ดี</label>
            <input type="radio" name="q1" value="1"> 1
            <input type="radio" name="q1" value="2"> 2
            <input type="radio" name="q1" value="3"> 3
            <input type="radio" name="q1" value="4"> 4<br>

            <label>2. ฉันมักจะยอมแพ้เมื่อเจอปัญหายากๆ</label>
            <input type="radio" name="q2" value="4"> 1 (reverse)
            <input type="radio" name="q2" value="3"> 2
            <input type="radio" name="q2" value="2"> 3
            <input type="radio" name="q2" value="1"> 4<br>

            <label>3. ฉันสามารถปรับตัวเข้ากับการเปลี่ยนแปลงได้</label>
            <input type="radio" name="q3" value="1"> 1
            <input type="radio" name="q3" value="2"> 2
            <input type="radio" name="q3" value="3"> 3
            <input type="radio" name="q3" value="4"> 4<br>

            <label>4. ฉันรู้สึกสิ้นหวังเมื่อล้มเหลว</label>
            <input type="radio" name="q4" value="4"> 1 (reverse)
            <input type="radio" name="q4" value="3"> 2
            <input type="radio" name="q4" value="2"> 3
            <input type="radio" name="q4" value="1"> 4<br>

            <label>5. ฉันมีกำลังใจที่จะต่อสู้กับอุปสรรค</label>
            <input type="radio" name="q5" value="1"> 1
            <input type="radio" name="q5" value="2"> 2
            <input type="radio" name="q5" value="3"> 3
            <input type="radio" name="q5" value="4"> 4<br>

            <label>6. ฉันมักจะหงุดหงิดง่ายเมื่อมีปัญหา</label>
            <input type="radio" name="q6" value="4"> 1 (reverse)
            <input type="radio" name="q6" value="3"> 2
            <input type="radio" name="q6" value="2"> 3
            <input type="radio" name="q6" value="1"> 4<br>

            <label>7. ฉันสามารถหาทางแก้ปัญหาได้เสมอ</label>
            <input type="radio" name="q7" value="1"> 1
            <input type="radio" name="q7" value="2"> 2
            <input type="radio" name="q7" value="3"> 3
            <input type="radio" name="q7" value="4"> 4<br>

            <label>8. ฉันรู้สึกว่าชีวิตไร้ค่าเมื่อเจอวิกฤต</label>
            <input type="radio" name="q8" value="4"> 1 (reverse)
            <input type="radio" name="q8" value="3"> 2
            <input type="radio" name="q8" value="2"> 3
            <input type="radio" name="q8" value="1"> 4<br>

            <label>9. ฉันสามารถเรียนรู้จากความผิดพลาด</label>
            <input type="radio" name="q9" value="1"> 1
            <input type="radio" name="q9" value="2"> 2
            <input type="radio" name="q9" value="3"> 3
            <input type="radio" name="q9" value="4"> 4<br>

            <label>10. ฉันมักจะโทษตัวเองเมื่อสิ่งต่างๆผิดพลาด</label>
            <input type="radio" name="q10" value="4"> 1 (reverse)
            <input type="radio" name="q10" value="3"> 2
            <input type="radio" name="q10" value="2"> 3
            <input type="radio" name="q10" value="1"> 4<br>

            <label>11. ฉันมีแรงบันดาลใจจากเป้าหมายในชีวิต</label>
            <input type="radio" name="q11" value="1"> 1
            <input type="radio" name="q11" value="2"> 2
            <input type="radio" name="q11" value="3"> 3
            <input type="radio" name="q11" value="4"> 4<br>

            <label>12. ฉันรู้สึกหมดหวังง่าย</label>
            <input type="radio" name="q12" value="4"> 1 (reverse)
            <input type="radio" name="q12" value="3"> 2
            <input type="radio" name="q12" value="2"> 3
            <input type="radio" name="q12" value="1"> 4<br>

            <label>13. ฉันสามารถขอความช่วยเหลือจากผู้อื่นได้</label>
            <input type="radio" name="q13" value="1"> 1
            <input type="radio" name="q13" value="2"> 2
            <input type="radio" name="q13" value="3"> 3
            <input type="radio" name="q13" value="4"> 4<br>

            <label>14. ฉันมักจะรู้สึกโดดเดี่ยวเมื่อมีปัญหา</label>
            <input type="radio" name="q14" value="4"> 1 (reverse)
            <input type="radio" name="q14" value="3"> 2
            <input type="radio" name="q14" value="2"> 3
            <input type="radio" name="q14" value="1"> 4<br>

            <label>15. ฉันสามารถควบคุมอารมณ์ได้ดี</label>
            <input type="radio" name="q15" value="1"> 1
            <input type="radio" name="q15" value="2"> 2
            <input type="radio" name="q15" value="3"> 3
            <input type="radio" name="q15" value="4"> 4<br>

            <label>16. ฉันมักจะตื่นตระหนกเมื่อเจอสถานการณ์ยากลำบาก</label>
            <input type="radio" name="q16" value="4"> 1 (reverse)
            <input type="radio" name="q16" value="3"> 2
            <input type="radio" name="q16" value="2"> 3
            <input type="radio" name="q16" value="1"> 4<br>

            <label>17. ฉันเชื่อว่าทุกปัญหามีทางออก</label>
            <input type="radio" name="q17" value="1"> 1
            <input type="radio" name="q17" value="2"> 2
            <input type="radio" name="q17" value="3"> 3
            <input type="radio" name="q17" value="4"> 4<br>

            <label>18. ฉันรู้สึกว่าตนเองอ่อนแอ</label>
            <input type="radio" name="q18" value="4"> 1 (reverse)
            <input type="radio" name="q18" value="3"> 2
            <input type="radio" name="q18" value="2"> 3
            <input type="radio" name="q18" value="1"> 4<br>

            <label>19. ฉันสามารถฟื้นตัวจากความล้มเหลวได้</label>
            <input type="radio" name="q19" value="1"> 1
            <input type="radio" name="q19" value="2"> 2
            <input type="radio" name="q19" value="3"> 3
            <input type="radio" name="q19" value="4"> 4<br>

            <label>20. ฉันมักจะยอมแพ้ก่อนที่จะพยายาม</label>
            <input type="radio" name="q20" value="4"> 1 (reverse)
            <input type="radio" name="q20" value="3"> 2
            <input type="radio" name="q20" value="2"> 3
            <input type="radio" name="q20" value="1"> 4<br>

            <button type="button" onclick="calculateRQ()">คำนวณผล</button>
            <button type="button" onclick="clearForm('rqForm', 'rqResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="rqResult" class="result"></div>
    </section>

    <!-- ASSIST -->
    <section id="assist">
        <h2>แบบประเมินความเสี่ยงต่อการใช้สารเสพติด (ASSIST)</h2>
        <form id="assistForm">
            <p>เลือกสารที่ต้องการประเมิน (สามารถเลือกหลายสารได้ แต่คำนวณทีละสารเพื่อความง่าย)</p>
            <select id="substance">
                <option value="tobacco">ยาสูบ</option>
                <option value="alcohol">สุรา</option>
                <option value="cannabis">กัญชา</option>
                <option value="cocaine">โคเคน</option>
                <option value="amphetamine">ยาบ้า/แอมเฟตามีน</option>
                <option value="inhalants">สารระเหย</option>
                <option value="sedatives">ยานอนหลับ</option>
                <option value="hallucinogens">ยาหลอนประสาท</option>
                <option value="opioids">ฝิ่น</option>
                <option value="other">อื่นๆ</option>
            </select><br>

            <label>Q1: ในชีวิตท่านเคยใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q1" value="0"> ไม่เคย
            <input type="radio" name="q1" value="1"> เคย (หากไม่เคย ข้ามไป)<br>

            <label>Q2: ใน 3 เดือนที่ผ่านมา ท่านใช้สารนี้บ่อยเพียงใด?</label>
            <input type="radio" name="q2" value="0"> ไม่เคย (0)
            <input type="radio" name="q2" value="2"> 1-2 ครั้ง (2)
            <input type="radio" name="q2" value="3"> ทุกเดือน (3)
            <input type="radio" name="q2" value="4"> ทุกสัปดาห์ (4)
            <input type="radio" name="q2" value="6"> เกือบทุกวัน (6)<br>

            <label>Q3: ใน 3 เดือนที่ผ่านมา ท่านรู้สึกอยากใช้สารนี้อย่างรุนแรงบ่อยเพียงใด?</label>
            <input type="radio" name="q3" value="0"> ไม่เคย (0)
            <input type="radio" name="q3" value="3"> 1-2 ครั้ง (3)
            <input type="radio" name="q3" value="4"> ทุกเดือน (4)
            <input type="radio" name="q3" value="5"> ทุกสัปดาห์ (5)
            <input type="radio" name="q3" value="6"> เกือบทุกวัน (6)<br>

            <label>Q4: ใน 3 เดือนที่ผ่านมา การใช้สารนี้ทำให้เกิดปัญหาสุขภาพ สังคม กฎหมาย การเงิน ต่อท่านบ่อยเพียงใด?</label>
            <input type="radio" name="q4" value="0"> ไม่เคย (0)
            <input type="radio" name="q4" value="4"> 1-2 ครั้ง (4)
            <input type="radio" name="q4" value="5"> ทุกเดือน (5)
            <input type="radio" name="q4" value="6"> ทุกสัปดาห์ (6)
            <input type="radio" name="q4" value="7"> เกือบทุกวัน (7)<br>

            <label>Q5: ใน 3 เดือนที่ผ่านมา ท่านไม่สามารถทำกิจกรรมปกติเพราะใช้สารนี้บ่อยเพียงใด? (ยกเว้นยาสูบ)</label>
            <input type="radio" name="q5" value="0"> ไม่เคย (0)
            <input type="radio" name="q5" value="5"> 1-2 ครั้ง (5)
            <input type="radio" name="q5" value="6"> ทุกเดือน (6)
            <input type="radio" name="q5" value="7"> ทุกสัปดาño="7"> เกือบทุกวัน (8)<br>

            <label>Q6: เพื่อน ญาติ หรือคนอื่นเคยแสดงความห่วงใยหรือตักเตือนท่านเกี่ยวกับการใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q6" value="0"> ไม่เคย (0)
            <input type="radio" name="q6" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q6" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q7: ท่านเคยพยายามหยุดหรือลดการใช้สารนี้แต่ไม่สำเร็จหรือไม่?</label>
            <input type="radio" name="q7" value="0"> ไม่เคย (0)
            <input type="radio" name="q7" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q7" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q8: ท่านเคยใช้สารนี้โดยการฉีดหรือไม่?</label>
            <input type="radio" name="q8" value="0"> ไม่เคย (0)
            <input type="radio" name="q8" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q8" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <button type="button" onclick="calculateASSIST()">คำนวณผล</button>
            <button type="button" onclick="clearForm('assistForm', 'assistResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="assistResult" class="result"></div>
    </section>

    <script>
        function validateForm(formId) {
            const form = document.getElementById(formId);
            const radioGroups = {};
            form.querySelectorAll('input[type="radio"]').forEach(radio => {
                if (!radioGroups[radio.name]) {
                    radioGroups[radio.name] = [];
                }
                radioGroups[radio.name].push(radio);
            });

            for (const groupName in radioGroups) {
                const group = radioGroups[groupName];
                const isChecked = group.some(radio => radio.checked);
                if (!isChecked) {
                    alert('กรุณาตอบคำถามทุกข้อในแบบประเมินนี้');
                    return false;
                }
            }
            return true;
        }

        function clearForm(formId, resultId) {
            document.getElementById(formId).reset();
            document.getElementById(resultId).innerHTML = '';
            document.getElementById(resultId).style.display = 'none';
        }

        function calculateST5() {
            if (!validateForm('st5Form')) return;
            let form = document.getElementById('st5Form');
            let score = 0;
            for (let i = 1; i <= 5; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            let result = '';
            if (score <= 4) result = 'ความเครียดระดับปกติ';
            else if (score <= 7) result = 'ความเครียดระดับน้อย';
            else if (score <= 9) result = 'ความเครียดระดับปานกลาง';
            else result = 'ความเครียดระดับรุนแรง';
            document.getElementById('st5Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('st5Result').style.display = 'block';
        }

        function calculate2Q9Q8Q() {
            if (!validateForm('2q9q8qForm')) return;
            let form = document.getElementById('2q9q8qForm');
            let score2Q = 0, score9Q = 0, score8Q = 0;
            let result2Q = '', result9Q = '', result8Q = '';

            // 2Q
            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="2q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            // 9Q
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="9q${i}"]:checked`);
                if (q) score9Q += parseInt(q.value);
            }
            if (score9Q <= 6) result9Q = 'ไม่เป็นโรคซึมเศร้า';
            else if (score9Q <= 12) result9Q = 'ซึมเศร้าระดับน้อย';
            else if (score9Q <= 18) result9Q = 'ซึมเศร้าระดับปานกลาง';
            else result9Q = 'ซึมเศร้าระดับรุนแรง';

            // 8Q
            for (let i = 1; i <= 8; i++) {
                let q = form.querySelector(`input[name="8q${i}"]:checked`);
                if (q) score8Q += parseInt(q.value);
            }
            if (score8Q === 0) result8Q = 'ไม่มีความเสี่ยง';
            else if (score8Q <= 8) result8Q = 'เสี่ยงต่ำ';
            else if (score8Q <= 16) result8Q = 'เสี่ยงปานกลาง';
            else result8Q = 'เสี่ยงสูง';

            document.getElementById('2q9q8qResult').innerHTML = `2Q: คะแนน ${score2Q} - ${result2Q}<br>9Q: คะแนน ${score9Q} - ${result9Q}<br>8Q: คะแนน ${score8Q} - ${result8Q}`;
            document.getElementById('2q9q8qResult').style.display = 'block';
        }

        function calculate2QPlus() {
            if (!validateForm('2qplusForm')) return;
            let form = document.getElementById('2qplusForm');
            let score2Q = 0, plus = 0;
            let result2Q = '', resultPlus = '';

            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            let p = form.querySelector(`input[name="plus"]:checked`);
            if (p) plus = parseInt(p.value);
            if (plus === 1) resultPlus = 'เสี่ยงฆ่าตัวตาย';
            else resultPlus = 'ไม่เสี่ยงฆ่าตัวตาย';

            document.getElementById('2qplusResult').innerHTML = `2Q: ${result2Q}<br>Plus: ${resultPlus}`;
            document.getElementById('2qplusResult').style.display = 'block';
        }

        function calculatePHQA() {
            if (!validateForm('phqaForm')) return;
            let form = document.getElementById('phqaForm');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score <= 4) result = 'ไม่มีภาวะซึมเศร้า';
            else if (score <= 9) result = 'ซึมเศร้าเล็กน้อย';
            else if (score <= 14) result = 'ซึมเศร้าปานกลาง';
            else if (score <= 19) result = 'ซึมเศร้ามาก';
            else result = 'ซึมเศร้ารุนแรง';

            let extra1 = form.querySelector(`input[name="extra1"]:checked`) ? form.querySelector(`input[name="extra1"]:checked`).value : 'ไม่ตอบ';
            let extra2 = form.querySelector(`input[name="extra2"]:checked`) ? form.querySelector(`input[name="extra2"]:checked`).value : 'ไม่ตอบ';

            document.getElementById('phqaResult').innerHTML = `คะแนนรวม: ${score} - ${result}<br>เคยพยายามทำร้ายตัวเอง: ${extra1 === '1' ? 'มี' : 'ไม่มี'}<br>เคยคิดอยากตาย: ${extra2 === '1' ? 'มี' : 'ไม่มี'}`;
            document.getElementById('phqaResult').style.display = 'block';
        }

        function calculateTMHI15() {
            if (!validateForm('tmhi15Form')) return;
            let form = document.getElementById('tmhi15Form');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 15; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score >= 33) result = 'สุขภาพจิตดีกว่าคนทั่วไป';
            else if (score >= 27) result = 'สุขภาพจิตเท่าคนทั่วไป';
            else result = 'สุขภาพจิตต่ำกว่าคนทั่วไป';
            document.getElementById('tmhi15Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('tmhi15Result').style.display = 'block';
        }

        function calculateRQ() {
            if (!validateForm('rqForm')) return;
            let form = document.getElementById('rqForm');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 20; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score < 60) result = 'พลังใจต่ำ (แนะนำพัฒนา)';
            else result = 'พลังใจดี';
            document.getElementById('rqResult').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('rqResult').style.display = 'block';
        }

        function calculateASSIST() {
            if (!validateForm('assistForm')) return;
            let form = document.getElementById('assistForm');
            let substance = document.getElementById('substance').value;
            let score = 0;
            let result = '';
            let isTobacco = substance === 'tobacco';

            let q1 = form.querySelector(`input[name="q1"]:checked`) ? parseInt(form.querySelector(`input[name="q1"]:checked`).value) : 0;
            if (q1 === 0) {
                result = 'ไม่เคยใช้สารนี้';
            } else {
                for (let i = 2; i <= 7; i++) {
                    let q = form.querySelector(`input[name="q${i}"]:checked`);
                    if (q && !(isTobacco && i === 5)) score += parseInt(q.value);
                }
                let q8 = form.querySelector(`input[name="q8"]:checked`) ? parseInt(form.querySelector(`input[name="q8"]:checked`).value) : 0;

                if (substance === 'alcohol') {
                    if (score <= 10) result = 'เสี่ยงต่ำ';
                    else if (score <= 26) result = 'เสี่ยงปานกลาง';
                    else result = 'เสี่ยงสูง';
                } else {
                    if (score <= 3) result = 'เสี่ยงต่ำ';
                    else if (score <= 26) result = 'เสี่ยงปานกลาง';
                    else result = 'เสี่ยงสูง';
                }
                if (q8 === 6) result += ' (มีการฉีดใน 3 เดือนที่แล้ว - เสี่ยงสูง)';
            }
            document.getElementById('assistResult').innerHTML = `สาร: ${substance}<br>คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('assistResult').style.display = 'block';
        }
    </script>
</body>
</html>
"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="th">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
#     <style>
#         body { font-family: Arial, sans-serif; margin: 20px; }
#         h1, h2 { text-align: center; }
#         section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
#         form { margin: 0 auto; max-width: 800px; }
#         label { display: block; margin: 10px 0; }
#         input[type="radio"] { margin-right: 10px; }
#         button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
#         button:hover { background-color: #45a049; }
#         .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
#         nav { text-align: center; margin-bottom: 30px; }
# ...

# %% [markdown]
# # Task
# Fix the HTML for ASSIST question 5 (Q5) by correcting the radio button for 'ทุกสัปดาห์' to have `value="7"` and ensuring the 'เกือบทุกวัน' option is correctly defined with `value="8"`. Implement conditional validation for the ASSIST form so that questions 2-8 are only required if question 1 indicates prior substance use. Update the `calculateASSIST()` function to explicitly state that question 8 (Q8) is a separate high-risk indicator and not part of the numerical score. Additionally, embed emergency contact numbers (1669 and 1323) prominently within the HTML, especially near relevant assessment sections, to provide immediate support.

# %% [markdown]
# ## Fix ASSIST Q5 HTML
#
# ### Subtask:
# Correct the HTML structure for Q5 in the ASSIST form to ensure all radio buttons are properly defined and the 'เกือบทุกวัน' option has the correct value of '8'.

# %% [markdown]
# **Reasoning**:
# The subtask requires correcting specific radio button values and HTML structure within the `assistForm` for question Q5. I need to update the `html_content` string to reflect these changes and then display the corrected HTML.

# %%
from IPython.display import HTML

html_content = '''
<!DOCTYPE html>
<html lang="th">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
    <style>
        body { font-family: Arial, sans-serif; margin: 20px; }
        h1, h2 { text-align: center; }
        section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
        form { margin: 0 auto; max-width: 800px; }
        label { display: block; margin: 10px 0; }
        input[type="radio"] { margin-right: 10px; }
        button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
        button:hover { background-color: #45a049; }
        .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
        nav { text-align: center; margin-bottom: 30px; }
        nav a { margin: 10px; text-decoration: none; color: #007BFF; }
        nav a:hover { text-decoration: underline; }
        select { margin: 10px 0; }
    </style>
</head>
<body>
    <h1>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</h1>
    <p style="text-align: center;">ยินดีต้อนรับสู่แพลตฟอร์มประเมินสุขภาพจิตเบื้องต้น กรุณาเลือกแบบประเมินที่ต้องการจากเมนูด้านล่าง โปรดตอบตามความรู้สึกจริงเพื่อผลลัพธ์ที่แม่นยำที่สุด ผลลัพธ์นี้ไม่ใช่การวินิจฉัยทางการแพทย์ ควรปรึกษาแพทย์หากมีอาการรุนแรง</p>

    <nav>
        <a href="#st5">ST-5 (ความเครียด)</a> |
        <a href="#2q9q8q">2Q-9Q-8Q (ซึมเศร้า/ฆ่าตัวตาย)</a> |
        <a href="#2qplus">2Q Plus</a> |
        <a href="#phqa">PHQ-A (ซึมเศร้าในวัยรุ่น)</a> |
        <a href="#tmhi15">TMHI-15 (สุขภาพจิตคนไทย)</a> |
        <a href="#rq">RQ (พลังสุขภาพจิต)</a> |
        <a href="#assist">ASSIST (สารเสพติด)</a>
    </nav>

    <!-- ST-5 -->
    <section id="st5">
        <h2>แบบประเมินความเครียด (ST-5)</h2>
        <form id="st5Form">
            <p>ในช่วง 2-4 สัปดาห์ที่ผ่านมา รวมวันนี้ อาการเหล่านี้รบกวนท่านมากน้อยเพียงใด</p>
            <label>1. ท่านรู้สึกปวดศีรษะหรือปวดต้นคอ</label>
            <input type="radio" name="q1" value="0"> แทบไม่มี (0)
            <input type="radio" name="q1" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q1" value="3"> เกือบตลอด (3)<br>

            <label>2. ท่านรู้สึกหงุดหงิด โมโหง่าย</label>
            <input type="radio" name="q2" value="0"> แทบไม่มี (0)
            <input type="radio" name="q2" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q2" value="3"> เกือบตลอด (3)<br>

            <label>3. ท่านรู้สึกเบื่อ เซ็ง</label>
            <input type="radio" name="q3" value="0"> แทบไม่มี (0)
            <input type="radio" name="q3" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q3" value="3"> เกือบตลอด (3)<br>

            <label>4. ท่านรู้สึกเครียด กลุ้มใจ</label>
            <input type="radio" name="q4" value="0"> แทบไม่มี (0)
            <input type="radio" name="q4" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q4" value="3"> เกือบตลอด (3)<br>

            <label>5. ท่านรู้สึกท้อแท้ หมดหวัง</label>
            <input type="radio" name="q5" value="0"> แทบไม่มี (0)
            <input type="radio" name="q5" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q5" value="3"> เกือบตลอด (3)<br>

            <button type="button" onclick="calculateST5()">คำนวณผล</button>
            <button type="button" onclick="clearForm('st5Form', 'st5Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="st5Result" class="result"></div>
    </section>

    <!-- 2Q-9Q-8Q -->
    <section id="2q9q8q">
        <h2>แบบประเมินซึมเศร้า / ฆ่าตัวตาย (2Q-9Q-8Q)</h2>
        <form id="2q9q8qForm">
            <h3>2Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านรู้สึก...</h3>
            <label>1. หดหู่ เศร้า หรือท้อแท้สิ้นหวัง</label>
            <input type="radio" name="2q1" value="0"> ไม่มี
            <input type="radio" name="2q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="2q2" value="0"> ไม่มี
            <input type="radio" name="2q2" value="1"> มี<br>

            <h3>9Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้บ่อยแค่ไหน</h3>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="9q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q1" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q1" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q1" value="3"> เป็นทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="9q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q2" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q2" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q2" value="3"> เป็นทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="9q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q3" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q3" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q3" value="3"> เป็นทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="9q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q4" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q4" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q4" value="3"> เป็นทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="9q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q5" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q5" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q5" value="3"> เป็นทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="9q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q6" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q6" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q6" value="3"> เป็นทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือพิมพ์หรือดูโทรทัศน์</label>
            <input type="radio" name="9q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q7" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q7" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q7" value="3"> เป็นทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="9q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q8" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q8" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q8" value="3"> เป็นทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="9q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q9" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q9" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q9" value="3"> เป็นทุกวัน (3)<br>

            <h3>8Q: ใน 1 เดือนที่ผ่านมา รวมวันนี้ ท่านมี...</h3>
            <label>1. ความคิดอยากตาย หรือคิดว่าตายเสียจะดีกว่า</label>
            <input type="radio" name="8q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q1" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q1" value="3"> เกือบทุกวัน (3)<br>

            <label>2. อยากทำร้ายตัวเอง หรือทำให้ตัวเองบาดเจ็บ</label>
            <input type="radio" name="8q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q2" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q2" value="3"> เกือบทุกวัน (3)<br>

            <label>3. คิดเกี่ยวกับความตาย</label>
            <input type="radio" name="8q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q3" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q3" value="3"> เกือบทุกวัน (3)<br>

            <label>4. มีแผนการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q4" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q4" value="3"> เกือบทุกวัน (3)<br>

            <label>5. มีแผนการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q5" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q5" value="3"> เกือบทุกวัน (3)<br>

            <label>6. เตรียมการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q6" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q6" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q6" value="3"> เกือบทุกวัน (3)<br>

            <label>7. เตรียมการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q7" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q7" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q7" value="3"> เกือบทุกวัน (3)<br>

            <label>8. ท่านเคยพยายามฆ่าตัวตาย</label>
            <input type="radio" name="8q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q8" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q8" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q8" value="3"> เกือบทุกวัน (3)<br>

            <button type="button" onclick="calculate2Q9Q8Q()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2q9q8qForm', '2q9q8qResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2q9q8qResult" class="result"></div>
    </section>

    <!-- 2Q Plus -->
    <section id="2qplus">
        <h2>แบบประเมิน 2Q Plus (ฉบับปรับปรุง)</h2>
        <form id="2qplusForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้หรือไม่</p>
            <label>1. ไม่สบายใจ เซ็ง ทุกข์ใจ เศร้า ท้อแท้ ซึม หงอย</label>
            <input type="radio" name="q1" value="0"> ไม่มี
            <input type="radio" name="q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่อยากพูดไม่อยากทำอะไร หรือทำอะไรก็ไม่สนุกเพลิดเพลินเหมือนเดิม</label>
            <input type="radio" name="q2" value="0"> ไม่มี
            <input type="radio" name="q2" value="1"> มี<br>

            <p>ใน 1 เดือนที่ผ่านมา รวมวันนี้</p>
            <label>ท่านมีความรู้สึกทุกข์ใจจนไม่อยากมีชีวิตอยู่หรือไม่</label>
            <input type="radio" name="plus" value="0"> ไม่มี
            <input type="radio" name="plus" value="1"> มี<br>

            <button type="button" onclick="calculate2QPlus()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2qplusForm', '2qplusResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2qplusResult" class="result"></div>
    </section>

    <!-- PHQ-A -->
    <section id="phqa">
        <h2>แบบประเมินภาวะซึมเศร้าในวัยรุ่น (PHQ-A)</h2>
        <form id="phqaForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา ท่านมีอาการเหล่านี้บ่อยแค่ไหน (สำหรับวัยรุ่นอายุ 11-20 ปี)</p>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q1" value="1"> มีบางวัน (1)
            <input type="radio" name="q1" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q1" value="3"> แทบทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q2" value="1"> มีบางวัน (1)
            <input type="radio" name="q2" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q2" value="3"> แทบทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q3" value="1"> มีบางวัน (1)
            <input type="radio" name="q3" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q3" value="3"> แทบทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q4" value="1"> มีบางวัน (1)
            <input type="radio" name="q4" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q4" value="3"> แทบทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q5" value="1"> มีบางวัน (1)
            <input type="radio" name="q5" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q5" value="3"> แทบทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q6" value="1"> มีบางวัน (1)
            <input type="radio" name="q6" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q6" value="3"> แทบทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือหรือดูโทรทัศน์</label>
            <input type="radio" name="q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q7" value="1"> มีบางวัน (1)
            <input type="radio" name="q7" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q7" value="3"> แทบทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q8" value="1"> มีบางวัน (1)
            <input type="radio" name="q8" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q8" value="3"> แทบทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q9" value="1"> มีบางวัน (1)
            <input type="radio" name="q9" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q9" value="3"> แทบทุกวัน (3)<br>

            <p>คำถามเพิ่มเติม (ไม่คิดคะแนน):</p>
            <label>ในปีที่ผ่านมา ท่านเคยพยายามทำร้ายตัวเองหรือไม่?</label>
            <input type="radio" name="extra1" value="0"> ไม่มี
            <input type="radio" name="extra1" value="1"> มี<br>

            <label>ในปีที่ผ่านมา ท่านเคยคิดอยากตายหรือไม่?</label>
            <input type="radio" name="extra2" value="0"> ไม่มี
            <input type="radio" name="extra2" value="1"> มี<br>

            <button type="button" onclick="calculatePHQA()">คำนวณผล</button>
            <button type="button" onclick="clearForm('phqaForm', 'phqaResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="phqaResult" class="result"></div>
    </section>

    <!-- TMHI-15 -->
    <section id="tmhi15">
        <h2>ดัชนีชี้วัดสุขภาพจิตของคนไทย (TMHI-15)</h2>
        <form id="tmhi15Form">
            <p>กรุณาเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด สำหรับประสบการณ์ในช่วง 1 เดือนที่ผ่านมา</p>
            <label>1. ท่านรู้สึกพึงพอใจในชีวิต</label>
            <input type="radio" name="q1" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q1" value="1"> เล็กน้อย (1)
            <input type="radio" name="q1" value="2"> มาก (2)
            <input type="radio" name="q1" value="3"> มากที่สุด (3)<br>

            <label>2. ท่านรู้สึกสบายใจ</label>
            <input type="radio" name="q2" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q2" value="1"> เล็กน้อย (1)
            <input type="radio" name="q2" value="2"> มาก (2)
            <input type="radio" name="q2" value="3"> มากที่สุด (3)<br>

            <label>3. ท่านรู้สึกเบื่อหน่ายท้อแท้กับการดำเนินชีวิตประจำวัน</label>
            <input type="radio" name="q3" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q3" value="2"> เล็กน้อย (2)
            <input type="radio" name="q3" value="1"> มาก (1)
            <input type="radio" name="q3" value="0"> มากที่สุด (0)<br>

            <label>4. ท่านรู้สึกผิดหวังในตัวเอง</label>
            <input type="radio" name="q4" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q4" value="2"> เล็กน้อย (2)
            <input type="radio" name="q4" value="1"> มาก (1)
            <input type="radio" name="q4" value="0"> มากที่สุด (0)<br>

            <label>5. ท่านรู้สึกว่าชีวิตของท่านมีแต่ความทุกข์</label>
            <input type="radio" name="q5" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q5" value="2"> เล็กน้อย (2)
            <input type="radio" name="q5" value="1"> มาก (1)
            <input type="radio" name="q5" value="0"> มากที่สุด (0)<br>

            <label>6. ท่านสามารถทำใจยอมรับได้สำหรับปัญหาที่ยากจะแก้ไข (เมื่อมีปัญหา)</label>
            <input type="radio" name="q6" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q6" value="1"> เล็กน้อย (1)
            <input type="radio" name="q6" value="2"> มาก (2)
            <input type="radio" name="q6" value="3"> มากที่สุด (3)<br>

            <label>7. ท่านมั่นใจว่าจะสามารถควบคุมอารมณ์ได้เมื่อมีเหตุการณ์คับขันหรือร้ายแรงเกิดขึ้น</label>
            <input type="radio" name="q7" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q7" value="1"> เล็กน้อย (1)
            <input type="radio" name="q7" value="2"> มาก (2)
            <input type="radio" name="q7" value="3"> มากที่สุด (3)<br>

            <label>8. ท่านมั่นใจที่จะเผชิญกับเหตุการณ์ร้ายแรงที่เกิดขึ้นในชีวิต</label>
            <input type="radio" name="q8" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q8" value="1"> เล็กน้อย (1)
            <input type="radio" name="q8" value="2"> มาก (2)
            <input type="radio" name="q8" value="3"> มากที่สุด (3)<br>

            <label>9. ท่านรู้สึกเห็นอกเห็นใจเมื่อผู้อื่นมีทุกข์</label>
            <input type="radio" name="q9" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q9" value="1"> เล็กน้อย (1)
            <input type="radio" name="q9" value="2"> มาก (2)
            <input type="radio" name="q9" value="3"> มากที่สุด (3)<br>

            <label>10. ท่านรู้สึกเป็นสุขในการช่วยเหลือผู้อื่นที่มีปัญหา</label>
            <input type="radio" name="q10" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q10" value="1"> เล็กน้อย (1)
            <input type="radio" name="q10" value="2"> มาก (2)
            <input type="radio" name="q10" value="3"> มากที่สุด (3)<br>

            <label>11. ท่านให้ความช่วยเหลือแก่ผู้อื่นเมื่อมีโอกาส</label>
            <input type="radio" name="q11" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q11" value="1"> เล็กน้อย (1)
            <input type="radio" name="q11" value="2"> มาก (2)
            <input type="radio" name="q11" value="3"> มากที่สุด (3)<br>

            <label>12. ท่านรู้สึกภูมิใจในตนเอง</label>
            <input type="radio" name="q12" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q12" value="1"> เล็กน้อย (1)
            <input type="radio" name="q12" value="2"> มาก (2)
            <input type="radio" name="q12" value="3"> มากที่สุด (3)<br>

            <label>13. ท่านรู้สึกมั่นคง ปลอดภัย เมื่ออยู่ในครอบครัว</label>
            <input type="radio" name="q13" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q13" value="1"> เล็กน้อย (1)
            <input type="radio" name="q13" value="2"> มาก (2)
            <input type="radio" name="q13" value="3"> มากที่สุด (3)<br>

            <label>14. หากท่านป่วยหนัก ท่านเชื่อว่าครอบครัวจะดูแลท่านเป็นอย่างดี</label>
            <input type="radio" name="q14" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q14" value="1"> เล็กน้อย (1)
            <input type="radio" name="q14" value="2"> มาก (2)
            <input type="radio" name="q14" value="3"> มากที่สุด (3)<br>

            <label>15. สมาชิกในครอบครัวมีความรักและผูกพันต่อกัน</label>
            <input type="radio" name="q15" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q15" value="1"> เล็กน้อย (1)
            <input type="radio" name="q15" value="2"> มาก (2)
            <input type="radio" name="q15" value="3"> มากที่สุด (3)<br>

            <button type="button" onclick="calculateTMHI15()">คำนวณผล</button>
            <button type="button" onclick="clearForm('tmhi15Form', 'tmhi15Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="tmhi15Result" class="result"></div>
    </section>

    <!-- RQ -->
    <section id="rq">
        <h2>แบบประเมินพลังสุขภาพจิต (RQ) ฉบับ 20 ข้อ</h2>
        <form id="rqForm">
            <p>โปรดเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด (1=ไม่จริงเลย, 2=ไม่จริง, 3=ค่อนข้างจริง, 4=จริงมาก)</p>
            <label>1. ฉันสามารถทนต่อแรงกดดันได้ดี</label>
            <input type="radio" name="q1" value="1"> 1
            <input type="radio" name="q1" value="2"> 2
            <input type="radio" name="q1" value="3"> 3
            <input type="radio" name="q1" value="4"> 4<br>

            <label>2. ฉันมักจะยอมแพ้เมื่อเจอปัญหายากๆ</label>
            <input type="radio" name="q2" value="4"> 1 (reverse)
            <input type="radio" name="q2" value="3"> 2
            <input type="radio" name="q2" value="2"> 3
            <input type="radio" name="q2" value="1"> 4<br>

            <label>3. ฉันสามารถปรับตัวเข้ากับการเปลี่ยนแปลงได้</label>
            <input type="radio" name="q3" value="1"> 1
            <input type="radio" name="q3" value="2"> 2
            <input type="radio" name="q3" value="3"> 3
            <input type="radio" name="q3" value="4"> 4<br>

            <label>4. ฉันรู้สึกสิ้นหวังเมื่อล้มเหลว</label>
            <input type="radio" name="q4" value="4"> 1 (reverse)
            <input type="radio" name="q4" value="3"> 2
            <input type="radio" name="q4" value="2"> 3
            <input type="radio" name="q4" value="1"> 4<br>

            <label>5. ฉันมีกำลังใจที่จะต่อสู้กับอุปสรรค</label>
            <input type="radio" name="q5" value="1"> 1
            <input type="radio" name="q5" value="2"> 2
            <input type="radio" name="q5" value="3"> 3
            <input type="radio" name="q5" value="4"> 4<br>

            <label>6. ฉันมักจะหงุดหงิดง่ายเมื่อมีปัญหา</label>
            <input type="radio" name="q6" value="4"> 1 (reverse)
            <input type="radio" name="q6" value="3"> 2
            <input type="radio" name="q6" value="2"> 3
            <input type="radio" name="q6" value="1"> 4<br>

            <label>7. ฉันสามารถหาทางแก้ปัญหาได้เสมอ</label>
            <input type="radio" name="q7" value="1"> 1
            <input type="radio" name="q7" value="2"> 2
            <input type="radio" name="q7" value="3"> 3
            <input type="radio" name="q7" value="4"> 4<br>

            <label>8. ฉันรู้สึกว่าชีวิตไร้ค่าเมื่อเจอวิกฤต</label>
            <input type="radio" name="q8" value="4"> 1 (reverse)
            <input type="radio" name="q8" value="3"> 2
            <input type="radio" name="q8" value="2"> 3
            <input type="radio" name="q8" value="1"> 4<br>

            <label>9. ฉันสามารถเรียนรู้จากความผิดพลาด</label>
            <input type="radio" name="q9" value="1"> 1
            <input type="radio" name="q9" value="2"> 2
            <input type="radio" name="q9" value="3"> 3
            <input type="radio" name="q9" value="4"> 4<br>

            <label>10. ฉันมักจะโทษตัวเองเมื่อสิ่งต่างๆผิดพลาด</label>
            <input type="radio" name="q10" value="4"> 1 (reverse)
            <input type="radio" name="q10" value="3"> 2
            <input type="radio" name="q10" value="2"> 3
            <input type="radio" name="q10" value="1"> 4<br>

            <label>11. ฉันมีแรงบันดาลใจจากเป้าหมายในชีวิต</label>
            <input type="radio" name="q11" value="1"> 1
            <input type="radio" name="q11" value="2"> 2
            <input type="radio" name="q11" value="3"> 3
            <input type="radio" name="q11" value="4"> 4<br>

            <label>12. ฉันรู้สึกหมดหวังง่าย</label>
            <input type="radio" name="q12" value="4"> 1 (reverse)
            <input type="radio" name="q12" value="3"> 2
            <input type="radio" name="q12" value="2"> 3
            <input type="radio" name="q12" value="1"> 4<br>

            <label>13. ฉันสามารถขอความช่วยเหลือจากผู้อื่นได้</label>
            <input type="radio" name="q13" value="1"> 1
            <input type="radio" name="q13" value="2"> 2
            <input type="radio" name="q13" value="3"> 3
            <input type="radio" name="q13" value="4"> 4<br>

            <label>14. ฉันมักจะรู้สึกโดดเดี่ยวเมื่อมีปัญหา</label>
            <input type="radio" name="q14" value="4"> 1 (reverse)
            <input type="radio" name="q14" value="3"> 2
            <input type="radio" name="q14" value="2"> 3
            <input type="radio" name="q14" value="1"> 4<br>

            <label>15. ฉันสามารถควบคุมอารมณ์ได้ดี</label>
            <input type="radio" name="q15" value="1"> 1
            <input type="radio" name="q15" value="2"> 2
            <input type="radio" name="q15" value="3"> 3
            <input type="radio" name="q15" value="4"> 4<br>

            <label>16. ฉันมักจะตื่นตระหนกเมื่อเจอสถานการณ์ยากลำบาก</label>
            <input type="radio" name="q16" value="4"> 1 (reverse)
            <input type="radio" name="q16" value="3"> 2
            <input type="radio" name="q16" value="2"> 3
            <input type="radio" name="q16" value="1"> 4<br>

            <label>17. ฉันเชื่อว่าทุกปัญหามีทางออก</label>
            <input type="radio" name="q17" value="1"> 1
            <input type="radio" name="q17" value="2"> 2
            <input type="radio" name="q17" value="3"> 3
            <input type="radio" name="q17" value="4"> 4<br>

            <label>18. ฉันรู้สึกว่าตนเองอ่อนแอ</label>
            <input type="radio" name="q18" value="4"> 1 (reverse)
            <input type="radio" name="q18" value="3"> 2
            <input type="radio" name="q18" value="2"> 3
            <input type="radio" name="q18" value="1"> 4<br>

            <label>19. ฉันสามารถฟื้นตัวจากความล้มเหลวได้</label>
            <input type="radio" name="q19" value="1"> 1
            <input type="radio" name="q19" value="2"> 2
            <input type="radio" name="q19" value="3"> 3
            <input type="radio" name="q19" value="4"> 4<br>

            <label>20. ฉันมักจะยอมแพ้ก่อนที่จะพยายาม</label>
            <input type="radio" name="q20" value="4"> 1 (reverse)
            <input type="radio" name="q20" value="3"> 2
            <input type="radio" name="q20" value="2"> 3
            <input type="radio" name="q20" value="1"> 4<br>

            <button type="button" onclick="calculateRQ()">คำนวณผล</button>
            <button type="button" onclick="clearForm('rqForm', 'rqResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="rqResult" class="result"></div>
    </section>

    <!-- ASSIST -->
    <section id="assist">
        <h2>แบบประเมินความเสี่ยงต่อการใช้สารเสพติด (ASSIST)</h2>
        <form id="assistForm">
            <p>เลือกสารที่ต้องการประเมิน (สามารถเลือกหลายสารได้ แต่คำนวณทีละสารเพื่อความง่าย)</p>
            <select id="substance">
                <option value="tobacco">ยาสูบ</option>
                <option value="alcohol">สุรา</option>
                <option value="cannabis">กัญชา</option>
                <option value="cocaine">โคเคน</option>
                <option value="amphetamine">ยาบ้า/แอมเฟตามีน</option>
                <option value="inhalants">สารระเหย</option>
                <option value="sedatives">ยานอนหลับ</option>
                <option value="hallucinogens">ยาหลอนประสาท</option>
                <option value="opioids">ฝิ่น</option>
                <option value="other">อื่นๆ</option>
            </select><br>

            <label>Q1: ในชีวิตท่านเคยใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q1" value="0"> ไม่เคย
            <input type="radio" name="q1" value="1"> เคย (หากไม่เคย ข้ามไป)<br>

            <label>Q2: ใน 3 เดือนที่ผ่านมา ท่านใช้สารนี้บ่อยเพียงใด?</label>
            <input type="radio" name="q2" value="0"> ไม่เคย (0)
            <input type="radio" name="q2" value="2"> 1-2 ครั้ง (2)
            <input type="radio" name="q2" value="3"> ทุกเดือน (3)
            <input type="radio" name="q2" value="4"> ทุกสัปดาห์ (4)
            <input type="radio" name="q2" value="6"> เกือบทุกวัน (6)<br>

            <label>Q3: ใน 3 เดือนที่ผ่านมา ท่านรู้สึกอยากใช้สารนี้อย่างรุนแรงบ่อยเพียงใด?</label>
            <input type="radio" name="q3" value="0"> ไม่เคย (0)
            <input type="radio" name="q3" value="3"> 1-2 ครั้ง (3)
            <input type="radio" name="q3" value="4"> ทุกเดือน (4)
            <input type="radio" name="q3" value="5"> ทุกสัปดาห์ (5)
            <input type="radio" name="q3" value="6"> เกือบทุกวัน (6)<br>

            <label>Q4: ใน 3 เดือนที่ผ่านมา การใช้สารนี้ทำให้เกิดปัญหาสุขภาพ สังคม กฎหมาย การเงิน ต่อท่านบ่อยเพียงใด?</label>
            <input type="radio" name="q4" value="0"> ไม่เคย (0)
            <input type="radio" name="q4" value="4"> 1-2 ครั้ง (4)
            <input type="radio" name="q4" value="5"> ทุกเดือน (5)
            <input type="radio" name="q4" value="6"> ทุกสัปดาห์ (6)
            <input type="radio" name="q4" value="7"> เกือบทุกวัน (7)<br>

            <label>Q5: ใน 3 เดือนที่ผ่านมา ท่านไม่สามารถทำกิจกรรมปกติเพราะใช้สารนี้บ่อยเพียงใด? (ยกเว้นยาสูบ)</label>
            <input type="radio" name="q5" value="0"> ไม่เคย (0)
            <input type="radio" name="q5" value="5"> 1-2 ครั้ง (5)
            <input type="radio" name="q5" value="6"> ทุกเดือน (6)
            <input type="radio" name="q5" value="7"> ทุกสัปดาห์ (7)
            <input type="radio" name="q5" value="8"> เกือบทุกวัน (8)<br>

            <label>Q6: เพื่อน ญาติ หรือคนอื่นเคยแสดงความห่วงใยหรือตักเตือนท่านเกี่ยวกับการใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q6" value="0"> ไม่เคย (0)
            <input type="radio" name="q6" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q6" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q7: ท่านเคยพยายามหยุดหรือลดการใช้สารนี้แต่ไม่สำเร็จหรือไม่?</label>
            <input type="radio" name="q7" value="0"> ไม่เคย (0)
            <input type="radio" name="q7" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q7" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q8: ท่านเคยใช้สารนี้โดยการฉีดหรือไม่?</label>
            <input type="radio" name="q8" value="0"> ไม่เคย (0)
            <input type="radio" name="q8" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q8" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <button type="button" onclick="calculateASSIST()">คำนวณผล</button>
            <button type="button" onclick="clearForm('assistForm', 'assistResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="assistResult" class="result"></div>
    </section>

    <script>
        function validateForm(formId) {
            const form = document.getElementById(formId);
            const radioGroups = {};
            form.querySelectorAll('input[type="radio"]').forEach(radio => {
                if (!radioGroups[radio.name]) {
                    radioGroups[radio.name] = [];
                }
                radioGroups[radio.name].push(radio);
            });

            for (const groupName in radioGroups) {
                const group = radioGroups[groupName];
                const isChecked = group.some(radio => radio.checked);
                if (!isChecked) {
                    alert('กรุณาตอบคำถามทุกข้อในแบบประเมินนี้');
                    return false;
                }
            }
            return true;
        }

        function clearForm(formId, resultId) {
            document.getElementById(formId).reset();
            document.getElementById(resultId).innerHTML = '';
            document.getElementById(resultId).style.display = 'none';
        }

        function calculateST5() {
            if (!validateForm('st5Form')) return;
            let form = document.getElementById('st5Form');
            let score = 0;
            for (let i = 1; i <= 5; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            let result = '';
            if (score <= 4) result = 'ความเครียดระดับปกติ';
            else if (score <= 7) result = 'ความเครียดระดับน้อย';
            else if (score <= 9) result = 'ความเครียดระดับปานกลาง';
            else result = 'ความเครียดระดับรุนแรง';
            document.getElementById('st5Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('st5Result').style.display = 'block';
        }

        function calculate2Q9Q8Q() {
            if (!validateForm('2q9q8qForm')) return;
            let form = document.getElementById('2q9q8qForm');
            let score2Q = 0, score9Q = 0, score8Q = 0;
            let result2Q = '', result9Q = '', result8Q = '';

            // 2Q
            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="2q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            // 9Q
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="9q${i}"]:checked`);
                if (q) score9Q += parseInt(q.value);
            }
            if (score9Q <= 6) result9Q = 'ไม่เป็นโรคซึมเศร้า';
            else if (score9Q <= 12) result9Q = 'ซึมเศร้าระดับน้อย';
            else if (score9Q <= 18) result9Q = 'ซึมเศร้าระดับปานกลาง';
            else result9Q = 'ซึมเศร้าระดับรุนแรง';

            // 8Q
            for (let i = 1; i <= 8; i++) {
                let q = form.querySelector(`input[name="8q${i}"]:checked`);
                if (q) score8Q += parseInt(q.value);
            }
            if (score8Q === 0) result8Q = 'ไม่มีความเสี่ยง';
            else if (score8Q <= 8) result8Q = 'เสี่ยงต่ำ';
            else if (score8Q <= 16) result8Q = 'เสี่ยงปานกลาง';
            else result8Q = 'เสี่ยงสูง';

            document.getElementById('2q9q8qResult').innerHTML = `2Q: คะแนน ${score2Q} - ${result2Q}<br>9Q: คะแนน ${score9Q} - ${result9Q}<br>8Q: คะแนน ${score8Q} - ${result8Q}`;
            document.getElementById('2q9q8qResult').style.display = 'block';
        }

        function calculate2QPlus() {
            if (!validateForm('2qplusForm')) return;
            let form = document.getElementById('2qplusForm');
            let score2Q = 0, plus = 0;
            let result2Q = '', resultPlus = '';

            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            let p = form.querySelector(`input[name="plus"]:checked`);
            if (p) plus = parseInt(p.value);
            if (plus === 1) resultPlus = 'เสี่ยงฆ่าตัวตาย';
            else resultPlus = 'ไม่เสี่ยงฆ่าตัวตาย';

            document.getElementById('2qplusResult').innerHTML = `2Q: ${result2Q}<br>Plus: ${resultPlus}`;
            document.getElementById('2qplusResult').style.display = 'block';
        }

        function calculatePHQA() {
            if (!validateForm('phqaForm')) return;
            let form = document.getElementById('phqaForm');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score <= 4) result = 'ไม่มีภาวะซึมเศร้า';
            else if (score <= 9) result = 'ซึมเศร้าเล็กน้อย';
            else if (score <= 14) result = 'ซึมเศร้าปานกลาง';
            else if (score <= 19) result = 'ซึมเศร้ามาก';
            else result = 'ซึมเศร้ารุนแรง';

            let extra1 = form.querySelector(`input[name="extra1"]:checked`) ? form.querySelector(`input[name="extra1"]:checked`).value : 'ไม่ตอบ';
            let extra2 = form.querySelector(`input[name="extra2"]:checked`) ? form.querySelector(`input[name="extra2"]:checked`).value : 'ไม่ตอบ';

            document.getElementById('phqaResult').innerHTML = `คะแนนรวม: ${score} - ${result}<br>เคยพยายามทำร้ายตัวเอง: ${extra1 === '1' ? 'มี' : 'ไม่มี'}<br>เคยคิดอยากตาย: ${extra2 === '1' ? 'มี' : 'ไม่มี'}`;
            document.getElementById('phqaResult').style.display = 'block';
        }

        function calculateTMHI15() {
            if (!validateForm('tmhi15Form')) return;
            let form = document.getElementById('tmhi15Form');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 15; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score >= 33) result = 'สุขภาพจิตดีกว่าคนทั่วไป';
            else if (score >= 27) result = 'สุขภาพจิตเท่าคนทั่วไป';
            else result = 'สุขภาพจิตต่ำกว่าคนทั่วไป';
            document.getElementById('tmhi15Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('tmhi15Result').style.display = 'block';
        }

        function calculateRQ() {
            if (!validateForm('rqForm')) return;
            let form = document.getElementById('rqForm');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 20; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score < 60) result = 'พลังใจต่ำ (แนะนำพัฒนา)';
            else result = 'พลังใจดี';
            document.getElementById('rqResult').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('rqResult').style.display = 'block';
        }

        function calculateASSIST() {
            if (!validateForm('assistForm')) return;
            let form = document.getElementById('assistForm');
            let substance = document.getElementById('substance').value;
            let score = 0;
            let result = '';
            let isTobacco = substance === 'tobacco';

            let q1 = form.querySelector(`input[name="q1"]:checked`) ? parseInt(form.querySelector(`input[name="q1"]:checked`).value) : 0;
            if (q1 === 0) {
                result = 'ไม่เคยใช้สารนี้';
            } else {
                for (let i = 2; i <= 7; i++) {
                    let q = form.querySelector(`input[name="q${i}"]:checked`);
                    if (q && !(isTobacco && i === 5)) score += parseInt(q.value);
                }
                let q8 = form.querySelector(`input[name="q8"]:checked`) ? parseInt(form.querySelector(`input[name="q8"]:checked`).value) : 0;

                if (substance === 'alcohol') {
                    if (score <= 10) result = 'เสี่ยงต่ำ';
                    else if (score <= 26) result = 'เสี่ยงปานกลาง';
                    else result = 'เสี่ยงสูง';
                } else {
                    if (score <= 3) result = 'เสี่ยงต่ำ';
                    else if (score <= 26) result = 'เสี่ยงปานกลาง';
                    else result = 'เสี่ยงสูง';
                }
                if (q8 === 6) result += ' (มีการฉีดใน 3 เดือนที่แล้ว - เสี่ยงสูง)';
            }
            document.getElementById('assistResult').innerHTML = `สาร: ${substance}<br>คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('assistResult').style.display = 'block';
        }
    </script>
</body>
</html>
'''

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="th">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
#     <style>
#         body { font-family: Arial, sans-serif; margin: 20px; }
#         h1, h2 { text-align: center; }
#         section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
#         form { margin: 0 auto; max-width: 800px; }
#         label { display: block; margin: 10px 0; }
#         input[type="radio"] { margin-right: 10px; }
#         button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
#         button:hover { background-color: #45a049; }
#         .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
#         nav { text-align: center; margin-bottom: 30px; }
# ...

# %% [markdown]
# ## Implement Conditional Validation for ASSIST
#
# ### Subtask:
# Add a new JavaScript function `validateASSISTForm()` to handle the specific conditional validation logic for the ASSIST form. This function will check Q1 first and only require answers for Q2-Q8 if Q1 indicates prior substance use. The `calculateASSIST()` function will be updated to use this new validation.

# %% [markdown]
# **Reasoning**:
# The subtask requires implementing a new JavaScript function for conditional validation in the ASSIST form and integrating it into the `calculateASSIST` function. I will update the `html_content` by defining `validateASSISTForm` and modifying `calculateASSIST` to call it.

# %%
from IPython.display import HTML

html_content = '''
<!DOCTYPE html>
<html lang="th">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
    <style>
        body { font-family: Arial, sans-serif; margin: 20px; }
        h1, h2 { text-align: center; }
        section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
        form { margin: 0 auto; max-width: 800px; }
        label { display: block; margin: 10px 0; }
        input[type="radio"] { margin-right: 10px; }
        button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
        button:hover { background-color: #45a049; }
        .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
        nav { text-align: center; margin-bottom: 30px; }
        nav a { margin: 10px; text-decoration: none; color: #007BFF; }
        nav a:hover { text-decoration: underline; }
        select { margin: 10px 0; }
    </style>
</head>
<body>
    <h1>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</h1>
    <p style="text-align: center;">ยินดีต้อนรับสู่แพลตฟอร์มประเมินสุขภาพจิตเบื้องต้น กรุณาเลือกแบบประเมินที่ต้องการจากเมนูด้านล่าง โปรดตอบตามความรู้สึกจริงเพื่อผลลัพธ์ที่แม่นยำที่สุด ผลลัพธ์นี้ไม่ใช่การวินิจฉัยทางการแพทย์ ควรปรึกษาแพทย์หากมีอาการรุนแรง</p>

    <nav>
        <a href="#st5">ST-5 (ความเครียด)</a> |
        <a href="#2q9q8q">2Q-9Q-8Q (ซึมเศร้า/ฆ่าตัวตาย)</a> |
        <a href="#2qplus">2Q Plus</a> |
        <a href="#phqa">PHQ-A (ซึมเศร้าในวัยรุ่น)</a> |
        <a href="#tmhi15">TMHI-15 (สุขภาพจิตคนไทย)</a> |
        <a href="#rq">RQ (พลังสุขภาพจิต)</a> |
        <a href="#assist">ASSIST (สารเสพติด)</a>
    </nav>

    <!-- ST-5 -->
    <section id="st5">
        <h2>แบบประเมินความเครียด (ST-5)</h2>
        <form id="st5Form">
            <p>ในช่วง 2-4 สัปดาห์ที่ผ่านมา รวมวันนี้ อาการเหล่านี้รบกวนท่านมากน้อยเพียงใด</p>
            <label>1. ท่านรู้สึกปวดศีรษะหรือปวดต้นคอ</label>
            <input type="radio" name="q1" value="0"> แทบไม่มี (0)
            <input type="radio" name="q1" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q1" value="3"> เกือบตลอด (3)<br>

            <label>2. ท่านรู้สึกหงุดหงิด โมโหง่าย</label>
            <input type="radio" name="q2" value="0"> แทบไม่มี (0)
            <input type="radio" name="q2" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q2" value="3"> เกือบตลอด (3)<br>

            <label>3. ท่านรู้สึกเบื่อ เซ็ง</label>
            <input type="radio" name="q3" value="0"> แทบไม่มี (0)
            <input type="radio" name="q3" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q3" value="3"> เกือบตลอด (3)<br>

            <label>4. ท่านรู้สึกเครียด กลุ้มใจ</label>
            <input type="radio" name="q4" value="0"> แทบไม่มี (0)
            <input type="radio" name="q4" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q4" value="3"> เกือบตลอด (3)<br>

            <label>5. ท่านรู้สึกท้อแท้ หมดหวัง</label>
            <input type="radio" name="q5" value="0"> แทบไม่มี (0)
            <input type="radio" name="q5" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q5" value="3"> เกือบตลอด (3)<br>

            <button type="button" onclick="calculateST5()">คำนวณผล</button>
            <button type="button" onclick="clearForm('st5Form', 'st5Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="st5Result" class="result"></div>
    </section>

    <!-- 2Q-9Q-8Q -->
    <section id="2q9q8q">
        <h2>แบบประเมินซึมเศร้า / ฆ่าตัวตาย (2Q-9Q-8Q)</h2>
        <form id="2q9q8qForm">
            <h3>2Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านรู้สึก...</h3>
            <label>1. หดหู่ เศร้า หรือท้อแท้สิ้นหวัง</label>
            <input type="radio" name="2q1" value="0"> ไม่มี
            <input type="radio" name="2q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="2q2" value="0"> ไม่มี
            <input type="radio" name="2q2" value="1"> มี<br>

            <h3>9Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้บ่อยแค่ไหน</h3>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="9q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q1" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q1" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q1" value="3"> เป็นทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="9q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q2" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q2" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q2" value="3"> เป็นทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="9q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q3" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q3" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q3" value="3"> เป็นทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="9q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q4" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q4" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q4" value="3"> เป็นทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="9q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q5" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q5" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q5" value="3"> เป็นทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="9q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q6" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q6" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q6" value="3"> เป็นทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือพิมพ์หรือดูโทรทัศน์</label>
            <input type="radio" name="9q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q7" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q7" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q7" value="3"> เป็นทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="9q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q8" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q8" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q8" value="3"> เป็นทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="9q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q9" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q9" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q9" value="3"> เป็นทุกวัน (3)<br>

            <h3>8Q: ใน 1 เดือนที่ผ่านมา รวมวันนี้ ท่านมี...</h3>
            <label>1. ความคิดอยากตาย หรือคิดว่าตายเสียจะดีกว่า</label>
            <input type="radio" name="8q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q1" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q1" value="3"> เกือบทุกวัน (3)<br>

            <label>2. อยากทำร้ายตัวเอง หรือทำให้ตัวเองบาดเจ็บ</label>
            <input type="radio" name="8q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q2" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q2" value="3"> เกือบทุกวัน (3)<br>

            <label>3. คิดเกี่ยวกับความตาย</label>
            <input type="radio" name="8q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q3" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q3" value="3"> เกือบทุกวัน (3)<br>

            <label>4. มีแผนการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q4" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q4" value="3"> เกือบทุกวัน (3)<br>

            <label>5. มีแผนการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q5" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q5" value="3"> เกือบทุกวัน (3)<br>

            <label>6. เตรียมการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q6" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q6" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q6" value="3"> เกือบทุกวัน (3)<br>

            <label>7. เตรียมการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q7" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q7" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q7" value="3"> เกือบทุกวัน (3)<br>

            <label>8. ท่านเคยพยายามฆ่าตัวตาย</label>
            <input type="radio" name="8q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q8" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q8" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q8" value="3"> เกือบทุกวัน (3)<br>

            <button type="button" onclick="calculate2Q9Q8Q()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2q9q8qForm', '2q9q8qResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2q9q8qResult" class="result"></div>
    </section>

    <!-- 2Q Plus -->
    <section id="2qplus">
        <h2>แบบประเมิน 2Q Plus (ฉบับปรับปรุง)</h2>
        <form id="2qplusForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้หรือไม่</p>
            <label>1. ไม่สบายใจ เซ็ง ทุกข์ใจ เศร้า ท้อแท้ ซึม หงอย</label>
            <input type="radio" name="q1" value="0"> ไม่มี
            <input type="radio" name="q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่อยากพูดไม่อยากทำอะไร หรือทำอะไรก็ไม่สนุกเพลิดเพลินเหมือนเดิม</label>
            <input type="radio" name="q2" value="0"> ไม่มี
            <input type="radio" name="q2" value="1"> มี<br>

            <p>ใน 1 เดือนที่ผ่านมา รวมวันนี้</p>
            <label>ท่านมีความรู้สึกทุกข์ใจจนไม่อยากมีชีวิตอยู่หรือไม่</label>
            <input type="radio" name="plus" value="0"> ไม่มี
            <input type="radio" name="plus" value="1"> มี<br>

            <button type="button" onclick="calculate2QPlus()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2qplusForm', '2qplusResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2qplusResult" class="result"></div>
    </section>

    <!-- PHQ-A -->
    <section id="phqa">
        <h2>แบบประเมินภาวะซึมเศร้าในวัยรุ่น (PHQ-A)</h2>
        <form id="phqaForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา ท่านมีอาการเหล่านี้บ่อยแค่ไหน (สำหรับวัยรุ่นอายุ 11-20 ปี)</p>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q1" value="1"> มีบางวัน (1)
            <input type="radio" name="q1" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q1" value="3"> แทบทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q2" value="1"> มีบางวัน (1)
            <input type="radio" name="q2" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q2" value="3"> แทบทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q3" value="1"> มีบางวัน (1)
            <input type="radio" name="q3" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q3" value="3"> แทบทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q4" value="1"> มีบางวัน (1)
            <input type="radio" name="q4" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q4" value="3"> แทบทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q5" value="1"> มีบางวัน (1)
            <input type="radio" name="q5" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q5" value="3"> แทบทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q6" value="1"> มีบางวัน (1)
            <input type="radio" name="q6" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q6" value="3"> แทบทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือหรือดูโทรทัศน์</label>
            <input type="radio" name="q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q7" value="1"> มีบางวัน (1)
            <input type="radio" name="q7" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q7" value="3"> แทบทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q8" value="1"> มีบางวัน (1)
            <input type="radio" name="q8" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q8" value="3"> แทบทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q9" value="1"> มีบางวัน (1)
            <input type="radio" name="q9" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q9" value="3"> แทบทุกวัน (3)<br>

            <p>คำถามเพิ่มเติม (ไม่คิดคะแนน):</p>
            <label>ในปีที่ผ่านมา ท่านเคยพยายามทำร้ายตัวเองหรือไม่?</label>
            <input type="radio" name="extra1" value="0"> ไม่มี
            <input type="radio" name="extra1" value="1"> มี<br>

            <label>ในปีที่ผ่านมา ท่านเคยคิดอยากตายหรือไม่?</label>
            <input type="radio" name="extra2" value="0"> ไม่มี
            <input type="radio" name="extra2" value="1"> มี<br>

            <button type="button" onclick="calculatePHQA()">คำนวณผล</button>
            <button type="button" onclick="clearForm('phqaForm', 'phqaResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="phqaResult" class="result"></div>
    </section>

    <!-- TMHI-15 -->
    <section id="tmhi15">
        <h2>ดัชนีชี้วัดสุขภาพจิตของคนไทย (TMHI-15)</h2>
        <form id="tmhi15Form">
            <p>กรุณาเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด สำหรับประสบการณ์ในช่วง 1 เดือนที่ผ่านมา</p>
            <label>1. ท่านรู้สึกพึงพอใจในชีวิต</label>
            <input type="radio" name="q1" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q1" value="1"> เล็กน้อย (1)
            <input type="radio" name="q1" value="2"> มาก (2)
            <input type="radio" name="q1" value="3"> มากที่สุด (3)<br>

            <label>2. ท่านรู้สึกสบายใจ</label>
            <input type="radio" name="q2" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q2" value="1"> เล็กน้อย (1)
            <input type="radio" name="q2" value="2"> มาก (2)
            <input type="radio" name="q2" value="3"> มากที่สุด (3)<br>

            <label>3. ท่านรู้สึกเบื่อหน่ายท้อแท้กับการดำเนินชีวิตประจำวัน</label>
            <input type="radio" name="q3" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q3" value="2"> เล็กน้อย (2)
            <input type="radio" name="q3" value="1"> มาก (1)
            <input type="radio" name="q3" value="0"> มากที่สุด (0)<br>

            <label>4. ท่านรู้สึกผิดหวังในตัวเอง</label>
            <input type="radio" name="q4" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q4" value="2"> เล็กน้อย (2)
            <input type="radio" name="q4" value="1"> มาก (1)
            <input type="radio" name="q4" value="0"> มากที่สุด (0)<br>

            <label>5. ท่านรู้สึกว่าชีวิตของท่านมีแต่ความทุกข์</label>
            <input type="radio" name="q5" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q5" value="2"> เล็กน้อย (2)
            <input type="radio" name="q5" value="1"> มาก (1)
            <input type="radio" name="q5" value="0"> มากที่สุด (0)<br>

            <label>6. ท่านสามารถทำใจยอมรับได้สำหรับปัญหาที่ยากจะแก้ไข (เมื่อมีปัญหา)</label>
            <input type="radio" name="q6" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q6" value="1"> เล็กน้อย (1)
            <input type="radio" name="q6" value="2"> มาก (2)
            <input type="radio" name="q6" value="3"> มากที่สุด (3)<br>

            <label>7. ท่านมั่นใจว่าจะสามารถควบคุมอารมณ์ได้เมื่อมีเหตุการณ์คับขันหรือร้ายแรงเกิดขึ้น</label>
            <input type="radio" name="q7" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q7" value="1"> เล็กน้อย (1)
            <input type="radio" name="q7" value="2"> มาก (2)
            <input type="radio" name="q7" value="3"> มากที่สุด (3)<br>

            <label>8. ท่านมั่นใจที่จะเผชิญกับเหตุการณ์ร้ายแรงที่เกิดขึ้นในชีวิต</label>
            <input type="radio" name="q8" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q8" value="1"> เล็กน้อย (1)
            <input type="radio" name="q8" value="2"> มาก (2)
            <input type="radio" name="q8" value="3"> มากที่สุด (3)<br>

            <label>9. ท่านรู้สึกเห็นอกเห็นใจเมื่อผู้อื่นมีทุกข์</label>
            <input type="radio" name="q9" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q9" value="1"> เล็กน้อย (1)
            <input type="radio" name="q9" value="2"> มาก (2)
            <input type="radio" name="q9" value="3"> มากที่สุด (3)<br>

            <label>10. ท่านรู้สึกเป็นสุขในการช่วยเหลือผู้อื่นที่มีปัญหา</label>
            <input type="radio" name="q10" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q10" value="1"> เล็กน้อย (1)
            <input type="radio" name="q10" value="2"> มาก (2)
            <input type="radio" name="q10" value="3"> มากที่สุด (3)<br>

            <label>11. ท่านให้ความช่วยเหลือแก่ผู้อื่นเมื่อมีโอกาส</label>
            <input type="radio" name="q11" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q11" value="1"> เล็กน้อย (1)
            <input type="radio" name="q11" value="2"> มาก (2)
            <input type="radio" name="q11" value="3"> มากที่สุด (3)<br>

            <label>12. ท่านรู้สึกภูมิใจในตนเอง</label>
            <input type="radio" name="q12" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q12" value="1"> เล็กน้อย (1)
            <input type="radio" name="q12" value="2"> มาก (2)
            <input type="radio" name="q12" value="3"> มากที่สุด (3)<br>

            <label>13. ท่านรู้สึกมั่นคง ปลอดภัย เมื่ออยู่ในครอบครัว</label>
            <input type="radio" name="q13" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q13" value="1"> เล็กน้อย (1)
            <input type="radio" name="q13" value="2"> มาก (2)
            <input type="radio" name="q13" value="3"> มากที่สุด (3)<br>

            <label>14. หากท่านป่วยหนัก ท่านเชื่อว่าครอบครัวจะดูแลท่านเป็นอย่างดี</label>
            <input type="radio" name="q14" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q14" value="1"> เล็กน้อย (1)
            <input type="radio" name="q14" value="2"> มาก (2)
            <input type="radio" name="q14" value="3"> มากที่สุด (3)<br>

            <label>15. สมาชิกในครอบครัวมีความรักและผูกพันต่อกัน</label>
            <input type="radio" name="q15" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q15" value="1"> เล็กน้อย (1)
            <input type="radio" name="q15" value="2"> มาก (2)
            <input type="radio" name="q15" value="3"> มากที่สุด (3)<br>

            <button type="button" onclick="calculateTMHI15()">คำนวณผล</button>
            <button type="button" onclick="clearForm('tmhi15Form', 'tmhi15Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="tmhi15Result" class="result"></div>
    </section>

    <!-- RQ -->
    <section id="rq">
        <h2>แบบประเมินพลังสุขภาพจิต (RQ) ฉบับ 20 ข้อ</h2>
        <form id="rqForm">
            <p>โปรดเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด (1=ไม่จริงเลย, 2=ไม่จริง, 3=ค่อนข้างจริง, 4=จริงมาก)</p>
            <label>1. ฉันสามารถทนต่อแรงกดดันได้ดี</label>
            <input type="radio" name="q1" value="1"> 1
            <input type="radio" name="q1" value="2"> 2
            <input type="radio" name="q1" value="3"> 3
            <input type="radio" name="q1" value="4"> 4<br>

            <label>2. ฉันมักจะยอมแพ้เมื่อเจอปัญหายากๆ</label>
            <input type="radio" name="q2" value="4"> 1 (reverse)
            <input type="radio" name="q2" value="3"> 2
            <input type="radio" name="q2" value="2"> 3
            <input type="radio" name="q2" value="1"> 4<br>

            <label>3. ฉันสามารถปรับตัวเข้ากับการเปลี่ยนแปลงได้</label>
            <input type="radio" name="q3" value="1"> 1
            <input type="radio" name="q3" value="2"> 2
            <input type="radio" name="q3" value="3"> 3
            <input type="radio" name="q3" value="4"> 4<br>

            <label>4. ฉันรู้สึกสิ้นหวังเมื่อล้มเหลว</label>
            <input type="radio" name="q4" value="4"> 1 (reverse)
            <input type="radio" name="q4" value="3"> 2
            <input type="radio" name="q4" value="2"> 3
            <input type="radio" name="q4" value="1"> 4<br>

            <label>5. ฉันมีกำลังใจที่จะต่อสู้กับอุปสรรค</label>
            <input type="radio" name="q5" value="1"> 1
            <input type="radio" name="q5" value="2"> 2
            <input type="radio" name="q5" value="3"> 3
            <input type="radio" name="q5" value="4"> 4<br>

            <label>6. ฉันมักจะหงุดหงิดง่ายเมื่อมีปัญหา</label>
            <input type="radio" name="q6" value="4"> 1 (reverse)
            <input type="radio" name="q6" value="3"> 2
            <input type="radio" name="q6" value="2"> 3
            <input type="radio" name="q6" value="1"> 4<br>

            <label>7. ฉันสามารถหาทางแก้ปัญหาได้เสมอ</label>
            <input type="radio" name="q7" value="1"> 1
            <input type="radio" name="q7" value="2"> 2
            <input type="radio" name="q7" value="3"> 3
            <input type="radio" name="q7" value="4"> 4<br>

            <label>8. ฉันรู้สึกว่าชีวิตไร้ค่าเมื่อเจอวิกฤต</label>
            <input type="radio" name="q8" value="4"> 1 (reverse)
            <input type="radio" name="q8" value="3"> 2
            <input type="radio" name="q8" value="2"> 3
            <input type="radio" name="q8" value="1"> 4<br>

            <label>9. ฉันสามารถเรียนรู้จากความผิดพลาด</label>
            <input type="radio" name="q9" value="1"> 1
            <input type="radio" name="q9" value="2"> 2
            <input type="radio" name="q9" value="3"> 3
            <input type="radio" name="q9" value="4"> 4<br>

            <label>10. ฉันมักจะโทษตัวเองเมื่อสิ่งต่างๆผิดพลาด</label>
            <input type="radio" name="q10" value="4"> 1 (reverse)
            <input type="radio" name="q10" value="3"> 2
            <input type="radio" name="q10" value="2"> 3
            <input type="radio" name="q10" value="1"> 4<br>

            <label>11. ฉันมีแรงบันดาลใจจากเป้าหมายในชีวิต</label>
            <input type="radio" name="q11" value="1"> 1
            <input type="radio" name="q11" value="2"> 2
            <input type="radio" name="q11" value="3"> 3
            <input type="radio" name="q11" value="4"> 4<br>

            <label>12. ฉันรู้สึกหมดหวังง่าย</label>
            <input type="radio" name="q12" value="4"> 1 (reverse)
            <input type="radio" name="q12" value="3"> 2
            <input type="radio" name="q12" value="2"> 3
            <input type="radio" name="q12" value="1"> 4<br>

            <label>13. ฉันสามารถขอความช่วยเหลือจากผู้อื่นได้</label>
            <input type="radio" name="q13" value="1"> 1
            <input type="radio" name="q13" value="2"> 2
            <input type="radio" name="q13" value="3"> 3
            <input type="radio" name="q13" value="4"> 4<br>

            <label>14. ฉันมักจะรู้สึกโดดเดี่ยวเมื่อมีปัญหา</label>
            <input type="radio" name="q14" value="4"> 1 (reverse)
            <input type="radio" name="q14" value="3"> 2
            <input type="radio" name="q14" value="2"> 3
            <input type="radio" name="q14" value="1"> 4<br>

            <label>15. ฉันสามารถควบคุมอารมณ์ได้ดี</label>
            <input type="radio" name="q15" value="1"> 1
            <input type="radio" name="q15" value="2"> 2
            <input type="radio" name="q15" value="3"> 3
            <input type="radio" name="q15" value="4"> 4<br>

            <label>16. ฉันมักจะตื่นตระหนกเมื่อเจอสถานการณ์ยากลำบาก</label>
            <input type="radio" name="q16" value="4"> 1 (reverse)
            <input type="radio" name="q16" value="3"> 2
            <input type="radio" name="q16" value="2"> 3
            <input type="radio" name="q16" value="1"> 4<br>

            <label>17. ฉันเชื่อว่าทุกปัญหามีทางออก</label>
            <input type="radio" name="q17" value="1"> 1
            <input type="radio" name="q17" value="2"> 2
            <input type="radio" name="q17" value="3"> 3
            <input type="radio" name="q17" value="4"> 4<br>

            <label>18. ฉันรู้สึกว่าตนเองอ่อนแอ</label>
            <input type="radio" name="q18" value="4"> 1 (reverse)
            <input type="radio" name="q18" value="3"> 2
            <input type="radio" name="q18" value="2"> 3
            <input type="radio" name="q18" value="1"> 4<br>

            <label>19. ฉันสามารถฟื้นตัวจากความล้มเหลวได้</label>
            <input type="radio" name="q19" value="1"> 1
            <input type="radio" name="q19" value="2"> 2
            <input type="radio" name="q19" value="3"> 3
            <input type="radio" name="q19" value="4"> 4<br>

            <label>20. ฉันมักจะยอมแพ้ก่อนที่จะพยายาม</label>
            <input type="radio" name="q20" value="4"> 1 (reverse)
            <input type="radio" name="q20" value="3"> 2
            <input type="radio" name="q20" value="2"> 3
            <input type="radio" name="q20" value="1"> 4<br>

            <button type="button" onclick="calculateRQ()">คำนวณผล</button>
            <button type="button" onclick="clearForm('rqForm', 'rqResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="rqResult" class="result"></div>
    </section>

    <!-- ASSIST -->
    <section id="assist">
        <h2>แบบประเมินความเสี่ยงต่อการใช้สารเสพติด (ASSIST)</h2>
        <form id="assistForm">
            <p>เลือกสารที่ต้องการประเมิน (สามารถเลือกหลายสารได้ แต่คำนวณทีละสารเพื่อความง่าย)</p>
            <select id="substance">
                <option value="tobacco">ยาสูบ</option>
                <option value="alcohol">สุรา</option>
                <option value="cannabis">กัญชา</option>
                <option value="cocaine">โคเคน</option>
                <option value="amphetamine">ยาบ้า/แอมเฟตามีน</option>
                <option value="inhalants">สารระเหย</option>
                <option value="sedatives">ยานอนหลับ</option>
                <option value="hallucinogens">ยาหลอนประสาท</option>
                <option value="opioids">ฝิ่น</option>
                <option value="other">อื่นๆ</option>
            </select><br>

            <label>Q1: ในชีวิตท่านเคยใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q1" value="0"> ไม่เคย
            <input type="radio" name="q1" value="1"> เคย (หากไม่เคย ข้ามไป)<br>

            <label>Q2: ใน 3 เดือนที่ผ่านมา ท่านใช้สารนี้บ่อยเพียงใด?</label>
            <input type="radio" name="q2" value="0"> ไม่เคย (0)
            <input type="radio" name="q2" value="2"> 1-2 ครั้ง (2)
            <input type="radio" name="q2" value="3"> ทุกเดือน (3)
            <input type="radio" name="q2" value="4"> ทุกสัปดาห์ (4)
            <input type="radio" name="q2" value="6"> เกือบทุกวัน (6)<br>

            <label>Q3: ใน 3 เดือนที่ผ่านมา ท่านรู้สึกอยากใช้สารนี้อย่างรุนแรงบ่อยเพียงใด?</label>
            <input type="radio" name="q3" value="0"> ไม่เคย (0)
            <input type="radio" name="q3" value="3"> 1-2 ครั้ง (3)
            <input type="radio" name="q3" value="4"> ทุกเดือน (4)
            <input type="radio" name="q3" value="5"> ทุกสัปดาห์ (5)
            <input type="radio" name="q3" value="6"> เกือบทุกวัน (6)<br>

            <label>Q4: ใน 3 เดือนที่ผ่านมา การใช้สารนี้ทำให้เกิดปัญหาสุขภาพ สังคม กฎหมาย การเงิน ต่อท่านบ่อยเพียงใด?</label>
            <input type="radio" name="q4" value="0"> ไม่เคย (0)
            <input type="radio" name="q4" value="4"> 1-2 ครั้ง (4)
            <input type="radio" name="q4" value="5"> ทุกเดือน (5)
            <input type="radio" name="q4" value="6"> ทุกสัปดาห์ (6)
            <input type="radio" name="q4" value="7"> เกือบทุกวัน (7)<br>

            <label>Q5: ใน 3 เดือนที่ผ่านมา ท่านไม่สามารถทำกิจกรรมปกติเพราะใช้สารนี้บ่อยเพียงใด? (ยกเว้นยาสูบ)</label>
            <input type="radio" name="q5" value="0"> ไม่เคย (0)
            <input type="radio" name="q5" value="5"> 1-2 ครั้ง (5)
            <input type="radio" name="q5" value="6"> ทุกเดือน (6)
            <input type="radio" name="q5" value="7"> ทุกสัปดาห์ (7)
            <input type="radio" name="q5" value="8"> เกือบทุกวัน (8)<br>

            <label>Q6: เพื่อน ญาติ หรือคนอื่นเคยแสดงความห่วงใยหรือตักเตือนท่านเกี่ยวกับการใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q6" value="0"> ไม่เคย (0)
            <input type="radio" name="q6" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q6" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q7: ท่านเคยพยายามหยุดหรือลดการใช้สารนี้แต่ไม่สำเร็จหรือไม่?</label>
            <input type="radio" name="q7" value="0"> ไม่เคย (0)
            <input type="radio" name="q7" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q7" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q8: ท่านเคยใช้สารนี้โดยการฉีดหรือไม่?</label>
            <input type="radio" name="q8" value="0"> ไม่เคย (0)
            <input type="radio" name="q8" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q8" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <button type="button" onclick="calculateASSIST()">คำนวณผล</button>
            <button type="button" onclick="clearForm('assistForm', 'assistResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="assistResult" class="result"></div>
    </section>

    <script>
        function validateForm(formId) {
            const form = document.getElementById(formId);
            const radioGroups = {};
            form.querySelectorAll('input[type="radio"]').forEach(radio => {
                if (!radioGroups[radio.name]) {
                    radioGroups[radio.name] = [];
                }
                radioGroups[radio.name].push(radio);
            });

            for (const groupName in radioGroups) {
                const group = radioGroups[groupName];
                const isChecked = group.some(radio => radio.checked);
                if (!isChecked) {
                    alert('กรุณาตอบคำถามทุกข้อในแบบประเมินนี้');
                    return false;
                }
            }
            return true;
        }

        function validateASSISTForm(formId) {
            const form = document.getElementById(formId);
            const q1Radios = form.querySelectorAll('input[name="q1"]');
            let q1Value = null;

            let q1Answered = false;
            for (const radio of q1Radios) {
                if (radio.checked) {
                    q1Value = parseInt(radio.value);
                    q1Answered = true;
                    break;
                }
            }

            if (!q1Answered) {
                alert('กรุณาตอบคำถาม Q1 ก่อน');
                return false;
            }

            if (q1Value === 0) {
                // If Q1 is 'ไม่เคย', no need to validate other questions.
                return true;
            }

            // If Q1 is 'เคย', validate Q2-Q8
            for (let i = 2; i <= 8; i++) {
                const qRadios = form.querySelectorAll(`input[name="q${i}"]`);
                let qAnswered = false;
                for (const radio of qRadios) {
                    if (radio.checked) {
                        qAnswered = true;
                        break;
                    }
                }
                if (!qAnswered) {
                    alert('กรุณาตอบคำถามทุกข้อในแบบประเมิน ASSIST');
                    return false;
                }
            }
            return true;
        }

        function clearForm(formId, resultId) {
            document.getElementById(formId).reset();
            document.getElementById(resultId).innerHTML = '';
            document.getElementById(resultId).style.display = 'none';
        }

        function calculateST5() {
            if (!validateForm('st5Form')) return;
            let form = document.getElementById('st5Form');
            let score = 0;
            for (let i = 1; i <= 5; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            let result = '';
            if (score <= 4) result = 'ความเครียดระดับปกติ';
            else if (score <= 7) result = 'ความเครียดระดับน้อย';
            else if (score <= 9) result = 'ความเครียดระดับปานกลาง';
            else result = 'ความเครียดระดับรุนแรง';
            document.getElementById('st5Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('st5Result').style.display = 'block';
        }

        function calculate2Q9Q8Q() {
            if (!validateForm('2q9q8qForm')) return;
            let form = document.getElementById('2q9q8qForm');
            let score2Q = 0, score9Q = 0, score8Q = 0;
            let result2Q = '', result9Q = '', result8Q = '';

            // 2Q
            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="2q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            // 9Q
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="9q${i}"]:checked`);
                if (q) score9Q += parseInt(q.value);
            }
            if (score9Q <= 6) result9Q = 'ไม่เป็นโรคซึมเศร้า';
            else if (score9Q <= 12) result9Q = 'ซึมเศร้าระดับน้อย';
            else if (score9Q <= 18) result9Q = 'ซึมเศร้าระดับปานกลาง';
            else result9Q = 'ซึมเศร้าระดับรุนแรง';

            // 8Q
            for (let i = 1; i <= 8; i++) {
                let q = form.querySelector(`input[name="8q${i}"]:checked`);
                if (q) score8Q += parseInt(q.value);
            }
            if (score8Q === 0) result8Q = 'ไม่มีความเสี่ยง';
            else if (score8Q <= 8) result8Q = 'เสี่ยงต่ำ';
            else if (score8Q <= 16) result8Q = 'เสี่ยงปานกลาง';
            else result8Q = 'เสี่ยงสูง';

            document.getElementById('2q9q8qResult').innerHTML = `2Q: คะแนน ${score2Q} - ${result2Q}<br>9Q: คะแนน ${score9Q} - ${result9Q}<br>8Q: คะแนน ${score8Q} - ${result8Q}`;
            document.getElementById('2q9q8qResult').style.display = 'block';
        }

        function calculate2QPlus() {
            if (!validateForm('2qplusForm')) return;
            let form = document.getElementById('2qplusForm');
            let score2Q = 0, plus = 0;
            let result2Q = '', resultPlus = '';

            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            let p = form.querySelector(`input[name="plus"]:checked`);
            if (p) plus = parseInt(p.value);
            if (plus === 1) resultPlus = 'เสี่ยงฆ่าตัวตาย';
            else resultPlus = 'ไม่เสี่ยงฆ่าตัวตาย';

            document.getElementById('2qplusResult').innerHTML = `2Q: ${result2Q}<br>Plus: ${resultPlus}`;
            document.getElementById('2qplusResult').style.display = 'block';
        }

        function calculatePHQA() {
            if (!validateForm('phqaForm')) return;
            let form = document.getElementById('phqaForm');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score <= 4) result = 'ไม่มีภาวะซึมเศร้า';
            else if (score <= 9) result = 'ซึมเศร้าเล็กน้อย';
            else if (score <= 14) result = 'ซึมเศร้าปานกลาง';
            else if (score <= 19) result = 'ซึมเศร้ามาก';
            else result = 'ซึมเศร้ารุนแรง';

            let extra1 = form.querySelector(`input[name="extra1"]:checked`) ? form.querySelector(`input[name="extra1"]:checked`).value : 'ไม่ตอบ';
            let extra2 = form.querySelector(`input[name="extra2"]:checked`) ? form.querySelector(`input[name="extra2"]:checked`).value : 'ไม่ตอบ';

            document.getElementById('phqaResult').innerHTML = `คะแนนรวม: ${score} - ${result}<br>เคยพยายามทำร้ายตัวเอง: ${extra1 === '1' ? 'มี' : 'ไม่มี'}<br>เคยคิดอยากตาย: ${extra2 === '1' ? 'มี' : 'ไม่มี'}`;
            document.getElementById('phqaResult').style.display = 'block';
        }

        function calculateTMHI15() {
            if (!validateForm('tmhi15Form')) return;
            let form = document.getElementById('tmhi15Form');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 15; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score >= 33) result = 'สุขภาพจิตดีกว่าคนทั่วไป';
            else if (score >= 27) result = 'สุขภาพจิตเท่าคนทั่วไป';
            else result = 'สุขภาพจิตต่ำกว่าคนทั่วไป';
            document.getElementById('tmhi15Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('tmhi15Result').style.display = 'block';
        }

        function calculateRQ() {
            if (!validateForm('rqForm')) return;
            let form = document.getElementById('rqForm');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 20; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score < 60) result = 'พลังใจต่ำ (แนะนำพัฒนา)';
            else result = 'พลังใจดี';
            document.getElementById('rqResult').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('rqResult').style.display = 'block';
        }

        function calculateASSIST() {
            if (!validateASSISTForm('assistForm')) return; // Use the new validation function

            let form = document.getElementById('assistForm');
            let substance = document.getElementById('substance').value;
            let score = 0;
            let result = '';
            let isTobacco = substance === 'tobacco';

            let q1 = form.querySelector(`input[name="q1"]:checked`) ? parseInt(form.querySelector(`input[name="q1"]:checked`).value) : 0;

            if (q1 === 0) {
                result = 'ไม่เคยใช้สารนี้';
            } else {
                // Calculate score for Q2-Q7
                for (let i = 2; i <= 7; i++) {
                    let q = form.querySelector(`input[name="q${i}"]:checked`);
                    if (q && !(isTobacco && i === 5)) { // Q5 is skipped for tobacco
                        score += parseInt(q.value);
                    }
                }

                let q8 = form.querySelector(`input[name="q8"]:checked`) ? parseInt(form.querySelector(`input[name="q8"]:checked`).value) : 0;

                if (substance === 'alcohol') {
                    if (score <= 10) result = 'เสี่ยงต่ำ';
                    else if (score <= 26) result = 'เสี่ยงปานกลาง';
                    else result = 'เสี่ยงสูง';
                } else { // All other substances
                    if (score <= 3) result = 'เสี่ยงต่ำ';
                    else if (score <= 26) result = 'เสี่ยงปานกลาง';
                    else result = 'เสี่ยงสูง';
                }

                // Q8 is a separate high-risk indicator, not part of the score
                if (q8 === 6) {
                    result += '<br><b>มีการฉีดสารนี้ใน 3 เดือนที่แล้ว - เสี่ยงสูงมาก (โปรดปรึกษาผู้เชี่ยวชาญทันที)</b>';
                }
            }
            document.getElementById('assistResult').innerHTML = `สาร: ${substance}<br>คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('assistResult').style.display = 'block';
        }
    </script>
</body>
</html>
'''

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="th">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
#     <style>
#         body { font-family: Arial, sans-serif; margin: 20px; }
#         h1, h2 { text-align: center; }
#         section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
#         form { margin: 0 auto; max-width: 800px; }
#         label { display: block; margin: 10px 0; }
#         input[type="radio"] { margin-right: 10px; }
#         button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
#         button:hover { background-color: #45a049; }
#         .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
#         nav { text-align: center; margin-bottom: 30px; }
# ...

# %% [markdown]
# **Reasoning**:
# The subtask is to embed emergency contact numbers (1669 and 1323) prominently within the HTML, especially near relevant assessment sections, to provide immediate support. I will modify the `html_content` by adding these numbers within `div` elements near the respective sections.

# %%
from IPython.display import HTML

html_content = '''
<!DOCTYPE html>
<html lang="th">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
    <style>
        body { font-family: Arial, sans-serif; margin: 20px; }
        h1, h2 { text-align: center; }
        section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
        form { margin: 0 auto; max-width: 800px; }
        label { display: block; margin: 10px 0; }
        input[type="radio"] { margin-right: 10px; }
        button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
        button:hover { background-color: #45a049; }
        .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
        nav { text-align: center; margin-bottom: 30px; }
        nav a { margin: 10px; text-decoration: none; color: #007BFF; }
        nav a:hover { text-decoration: underline; }
        select { margin: 10px 0; }
        .emergency-contacts { margin-top: 20px; padding: 10px; border: 1px solid #f00; background-color: #ffe0e0; color: #f00; text-align: center; font-weight: bold; }
    </style>
</head>
<body>
    <h1>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</h1>
    <p style="text-align: center;">ยินดีต้อนรับสู่แพลตฟอร์มประเมินสุขภาพจิตเบื้องต้น กรุณาเลือกแบบประเมินที่ต้องการจากเมนูด้านล่าง โปรดตอบตามความรู้สึกจริงเพื่อผลลัพธ์ที่แม่นยำที่สุด ผลลัพธ์นี้ไม่ใช่การวินิจฉัยทางการแพทย์ ควรปรึกษาแพทย์หากมีอาการรุนแรง</p>

    <nav>
        <a href="#st5">ST-5 (ความเครียด)</a> |
        <a href="#2q9q8q">2Q-9Q-8Q (ซึมเศร้า/ฆ่าตัวตาย)</a> |
        <a href="#2qplus">2Q Plus</a> |
        <a href="#phqa">PHQ-A (ซึมเศร้าในวัยรุ่น)</a> |
        <a href="#tmhi15">TMHI-15 (สุขภาพจิตคนไทย)</a> |
        <a href="#rq">RQ (พลังสุขภาพจิต)</a> |
        <a href="#assist">ASSIST (สารเสพติด)</a>
    </nav>

    <!-- ST-5 -->
    <section id="st5">
        <h2>แบบประเมินความเครียด (ST-5)</h2>
        <form id="st5Form">
            <p>ในช่วง 2-4 สัปดาห์ที่ผ่านมา รวมวันนี้ อาการเหล่านี้รบกวนท่านมากน้อยเพียงใด</p>
            <label>1. ท่านรู้สึกปวดศีรษะหรือปวดต้นคอ</label>
            <input type="radio" name="q1" value="0"> แทบไม่มี (0)
            <input type="radio" name="q1" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q1" value="3"> เกือบตลอด (3)<br>

            <label>2. ท่านรู้สึกหงุดหงิด โมโหง่าย</label>
            <input type="radio" name="q2" value="0"> แทบไม่มี (0)
            <input type="radio" name="q2" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q2" value="3"> เกือบตลอด (3)<br>

            <label>3. ท่านรู้สึกเบื่อ เซ็ง</label>
            <input type="radio" name="q3" value="0"> แทบไม่มี (0)
            <input type="radio" name="q3" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q3" value="3"> เกือบตลอด (3)<br>

            <label>4. ท่านรู้สึกเครียด กลุ้มใจ</label>
            <input type="radio" name="q4" value="0"> แทบไม่มี (0)
            <input type="radio" name="q4" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q4" value="3"> เกือบตลอด (3)<br>

            <label>5. ท่านรู้สึกท้อแท้ หมดหวัง</label>
            <input type="radio" name="q5" value="0"> แทบไม่มี (0)
            <input type="radio" name="q5" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q5" value="3"> เกือบตลอด (3)<br>

            <button type="button" onclick="calculateST5()">คำนวณผล</button>
            <button type="button" onclick="clearForm('st5Form', 'st5Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="st5Result" class="result"></div>
    </section>

    <!-- 2Q-9Q-8Q -->
    <section id="2q9q8q">
        <h2>แบบประเมินซึมเศร้า / ฆ่าตัวตาย (2Q-9Q-8Q)</h2>
        <div class="emergency-contacts">
            หากรู้สึกแย่มาก ต้องการความช่วยเหลือฉุกเฉิน โทร 1669 หรือ สายด่วนสุขภาพจิต 1323
        </div>
        <form id="2q9q8qForm">
            <h3>2Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านรู้สึก...</h3>
            <label>1. หดหู่ เศร้า หรือท้อแท้สิ้นหวัง</label>
            <input type="radio" name="2q1" value="0"> ไม่มี
            <input type="radio" name="2q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="2q2" value="0"> ไม่มี
            <input type="radio" name="2q2" value="1"> มี<br>

            <h3>9Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้บ่อยแค่ไหน</h3>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="9q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q1" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q1" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q1" value="3"> เป็นทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="9q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q2" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q2" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q2" value="3"> เป็นทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="9q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q3" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q3" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q3" value="3"> เป็นทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="9q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q4" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q4" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q4" value="3"> เป็นทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="9q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q5" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q5" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q5" value="3"> เป็นทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="9q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q6" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q6" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q6" value="3"> เป็นทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือพิมพ์หรือดูโทรทัศน์</label>
            <input type="radio" name="9q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q7" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q7" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q7" value="3"> เป็นทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="9q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q8" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q8" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q8" value="3"> เป็นทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="9q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q9" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q9" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q9" value="3"> เป็นทุกวัน (3)<br>

            <h3>8Q: ใน 1 เดือนที่ผ่านมา รวมวันนี้ ท่านมี...</h3>
            <label>1. ความคิดอยากตาย หรือคิดว่าตายเสียจะดีกว่า</label>
            <input type="radio" name="8q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q1" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q1" value="3"> เกือบทุกวัน (3)<br>

            <label>2. อยากทำร้ายตัวเอง หรือทำให้ตัวเองบาดเจ็บ</label>
            <input type="radio" name="8q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q2" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q2" value="3"> เกือบทุกวัน (3)<br>

            <label>3. คิดเกี่ยวกับความตาย</label>
            <input type="radio" name="8q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q3" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q3" value="3"> เกือบทุกวัน (3)<br>

            <label>4. มีแผนการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q4" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q4" value="3"> เกือบทุกวัน (3)<br>

            <label>5. มีแผนการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q5" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q5" value="3"> เกือบทุกวัน (3)<br>

            <label>6. เตรียมการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q6" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q6" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q6" value="3"> เกือบทุกวัน (3)<br>

            <label>7. เตรียมการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q7" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q7" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q7" value="3"> เกือบทุกวัน (3)<br>

            <label>8. ท่านเคยพยายามฆ่าตัวตาย</label>
            <input type="radio" name="8q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q8" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q8" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q8" value="3"> เกือบทุกวัน (3)<br>

            <button type="button" onclick="calculate2Q9Q8Q()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2q9q8qForm', '2q9q8qResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2q9q8qResult" class="result"></div>
    </section>

    <!-- 2Q Plus -->
    <section id="2qplus">
        <h2>แบบประเมิน 2Q Plus (ฉบับปรับปรุง)</h2>
        <div class="emergency-contacts">
            หากรู้สึกแย่มาก ต้องการความช่วยเหลือฉุกเฉิน โทร 1669 หรือ สายด่วนสุขภาพจิต 1323
        </div>
        <form id="2qplusForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้หรือไม่</p>
            <label>1. ไม่สบายใจ เซ็ง ทุกข์ใจ เศร้า ท้อแท้ ซึม หงอย</label>
            <input type="radio" name="q1" value="0"> ไม่มี
            <input type="radio" name="q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่อยากพูดไม่อยากทำอะไร หรือทำอะไรก็ไม่สนุกเพลิดเพลินเหมือนเดิม</label>
            <input type="radio" name="q2" value="0"> ไม่มี
            <input type="radio" name="q2" value="1"> มี<br>

            <p>ใน 1 เดือนที่ผ่านมา รวมวันนี้</p>
            <label>ท่านมีความรู้สึกทุกข์ใจจนไม่อยากมีชีวิตอยู่หรือไม่</label>
            <input type="radio" name="plus" value="0"> ไม่มี
            <input type="radio" name="plus" value="1"> มี<br>

            <button type="button" onclick="calculate2QPlus()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2qplusForm', '2qplusResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2qplusResult" class="result"></div>
    </section>

    <!-- PHQ-A -->
    <section id="phqa">
        <h2>แบบประเมินภาวะซึมเศร้าในวัยรุ่น (PHQ-A)</h2>
        <div class="emergency-contacts">
            หากรู้สึกแย่มาก ต้องการความช่วยเหลือฉุกเฉิน โทร 1669 หรือ สายด่วนสุขภาพจิต 1323
        </div>
        <form id="phqaForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา ท่านมีอาการเหล่านี้บ่อยแค่ไหน (สำหรับวัยรุ่นอายุ 11-20 ปี)</p>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q1" value="1"> มีบางวัน (1)
            <input type="radio" name="q1" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q1" value="3"> แทบทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q2" value="1"> มีบางวัน (1)
            <input type="radio" name="q2" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q2" value="3"> แทบทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q3" value="1"> มีบางวัน (1)
            <input type="radio" name="q3" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q3" value="3"> แทบทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q4" value="1"> มีบางวัน (1)
            <input type="radio" name="q4" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q4" value="3"> แทบทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q5" value="1"> มีบางวัน (1)
            <input type="radio" name="q5" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q5" value="3"> แทบทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q6" value="1"> มีบางวัน (1)
            <input type="radio" name="q6" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q6" value="3"> แทบทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือหรือดูโทรทัศน์</label>
            <input type="radio" name="q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q7" value="1"> มีบางวัน (1)
            <input type="radio" name="q7" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q7" value="3"> แทบทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q8" value="1"> มีบางวัน (1)
            <input type="radio" name="q8" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q8" value="3"> แทบทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q9" value="1"> มีบางวัน (1)
            <input type="radio" name="q9" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q9" value="3"> แทบทุกวัน (3)<br>

            <p>คำถามเพิ่มเติม (ไม่คิดคะแนน):</p>
            <label>ในปีที่ผ่านมา ท่านเคยพยายามทำร้ายตัวเองหรือไม่?</label>
            <input type="radio" name="extra1" value="0"> ไม่มี
            <input type="radio" name="extra1" value="1"> มี<br>

            <label>ในปีที่ผ่านมา ท่านเคยคิดอยากตายหรือไม่?</label>
            <input type="radio" name="extra2" value="0"> ไม่มี
            <input type="radio" name="extra2" value="1"> มี<br>

            <button type="button" onclick="calculatePHQA()">คำนวณผล</button>
            <button type="button" onclick="clearForm('phqaForm', 'phqaResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="phqaResult" class="result"></div>
    </section>

    <!-- TMHI-15 -->
    <section id="tmhi15">
        <h2>ดัชนีชี้วัดสุขภาพจิตของคนไทย (TMHI-15)</h2>
        <form id="tmhi15Form">
            <p>กรุณาเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด สำหรับประสบการณ์ในช่วง 1 เดือนที่ผ่านมา</p>
            <label>1. ท่านรู้สึกพึงพอใจในชีวิต</label>
            <input type="radio" name="q1" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q1" value="1"> เล็กน้อย (1)
            <input type="radio" name="q1" value="2"> มาก (2)
            <input type="radio" name="q1" value="3"> มากที่สุด (3)<br>

            <label>2. ท่านรู้สึกสบายใจ</label>
            <input type="radio" name="q2" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q2" value="1"> เล็กน้อย (1)
            <input type="radio" name="q2" value="2"> มาก (2)
            <input type="radio" name="q2" value="3"> มากที่สุด (3)<br>

            <label>3. ท่านรู้สึกเบื่อหน่ายท้อแท้กับการดำเนินชีวิตประจำวัน</label>
            <input type="radio" name="q3" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q3" value="2"> เล็กน้อย (2)
            <input type="radio" name="q3" value="1"> มาก (1)
            <input type="radio" name="q3" value="0"> มากที่สุด (0)<br>

            <label>4. ท่านรู้สึกผิดหวังในตัวเอง</label>
            <input type="radio" name="q4" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q4" value="2"> เล็กน้อย (2)
            <input type="radio" name="q4" value="1"> มาก (1)
            <input type="radio" name="q4" value="0"> มากที่สุด (0)<br>

            <label>5. ท่านรู้สึกว่าชีวิตของท่านมีแต่ความทุกข์</label>
            <input type="radio" name="q5" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q5" value="2"> เล็กน้อย (2)
            <input type="radio" name="q5" value="1"> มาก (1)
            <input type="radio" name="q5" value="0"> มากที่สุด (0)<br>

            <label>6. ท่านสามารถทำใจยอมรับได้สำหรับปัญหาที่ยากจะแก้ไข (เมื่อมีปัญหา)</label>
            <input type="radio" name="q6" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q6" value="1"> เล็กน้อย (1)
            <input type="radio" name="q6" value="2"> มาก (2)
            <input type="radio" name="q6" value="3"> มากที่สุด (3)<br>

            <label>7. ท่านมั่นใจว่าจะสามารถควบคุมอารมณ์ได้เมื่อมีเหตุการณ์คับขันหรือร้ายแรงเกิดขึ้น</label>
            <input type="radio" name="q7" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q7" value="1"> เล็กน้อย (1)
            <input type="radio" name="q7" value="2"> มาก (2)
            <input type="radio" name="q7" value="3"> มากที่สุด (3)<br>

            <label>8. ท่านมั่นใจที่จะเผชิญกับเหตุการณ์ร้ายแรงที่เกิดขึ้นในชีวิต</label>
            <input type="radio" name="q8" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q8" value="1"> เล็กน้อย (1)
            <input type="radio" name="q8" value="2"> มาก (2)
            <input type="radio" name="q8" value="3"> มากที่สุด (3)<br>

            <label>9. ท่านรู้สึกเห็นอกเห็นใจเมื่อผู้อื่นมีทุกข์</label>
            <input type="radio" name="q9" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q9" value="1"> เล็กน้อย (1)
            <input type="radio" name="q9" value="2"> มาก (2)
            <input type="radio" name="q9" value="3"> มากที่สุด (3)<br>

            <label>10. ท่านรู้สึกเป็นสุขในการช่วยเหลือผู้อื่นที่มีปัญหา</label>
            <input type="radio" name="q10" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q10" value="1"> เล็กน้อย (1)
            <input type="radio" name="q10" value="2"> มาก (2)
            <input type="radio" name="q10" value="3"> มากที่สุด (3)<br>

            <label>11. ท่านให้ความช่วยเหลือแก่ผู้อื่นเมื่อมีโอกาส</label>
            <input type="radio" name="q11" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q11" value="1"> เล็กน้อย (1)
            <input type="radio" name="q11" value="2"> มาก (2)
            <input type="radio" name="q11" value="3"> มากที่สุด (3)<br>

            <label>12. ท่านรู้สึกภูมิใจในตนเอง</label>
            <input type="radio" name="q12" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q12" value="1"> เล็กน้อย (1)
            <input type="radio" name="q12" value="2"> มาก (2)
            <input type="radio" name="q12" value="3"> มากที่สุด (3)<br>

            <label>13. ท่านรู้สึกมั่นคง ปลอดภัย เมื่ออยู่ในครอบครัว</label>
            <input type="radio" name="q13" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q13" value="1"> เล็กน้อย (1)
            <input type="radio" name="q13" value="2"> มาก (2)
            <input type="radio" name="q13" value="3"> มากที่สุด (3)<br>

            <label>14. หากท่านป่วยหนัก ท่านเชื่อว่าครอบครัวจะดูแลท่านเป็นอย่างดี</label>
            <input type="radio" name="q14" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q14" value="1"> เล็กน้อย (1)
            <input type="radio" name="q14" value="2"> มาก (2)
            <input type="radio" name="q14" value="3"> มากที่สุด (3)<br>

            <label>15. สมาชิกในครอบครัวมีความรักและผูกพันต่อกัน</label>
            <input type="radio" name="q15" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q15" value="1"> เล็กน้อย (1)
            <input type="radio" name="q15" value="2"> มาก (2)
            <input type="radio" name="q15" value="3"> มากที่สุด (3)<br>

            <button type="button" onclick="calculateTMHI15()">คำนวณผล</button>
            <button type="button" onclick="clearForm('tmhi15Form', 'tmhi15Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="tmhi15Result" class="result"></div>
    </section>

    <!-- RQ -->
    <section id="rq">
        <h2>แบบประเมินพลังสุขภาพจิต (RQ) ฉบับ 20 ข้อ</h2>
        <form id="rqForm">
            <p>โปรดเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด (1=ไม่จริงเลย, 2=ไม่จริง, 3=ค่อนข้างจริง, 4=จริงมาก)</p>
            <label>1. ฉันสามารถทนต่อแรงกดดันได้ดี</label>
            <input type="radio" name="q1" value="1"> 1
            <input type="radio" name="q1" value="2"> 2
            <input type="radio" name="q1" value="3"> 3
            <input type="radio" name="q1" value="4"> 4<br>

            <label>2. ฉันมักจะยอมแพ้เมื่อเจอปัญหายากๆ</label>
            <input type="radio" name="q2" value="4"> 1 (reverse)
            <input type="radio" name="q2" value="3"> 2
            <input type="radio" name="q2" value="2"> 3
            <input type="radio" name="q2" value="1"> 4<br>

            <label>3. ฉันสามารถปรับตัวเข้ากับการเปลี่ยนแปลงได้</label>
            <input type="radio" name="q3" value="1"> 1
            <input type="radio" name="q3" value="2"> 2
            <input type="radio" name="q3" value="3"> 3
            <input type="radio" name="q3" value="4"> 4<br>

            <label>4. ฉันรู้สึกสิ้นหวังเมื่อล้มเหลว</label>
            <input type="radio" name="q4" value="4"> 1 (reverse)
            <input type="radio" name="q4" value="3"> 2
            <input type="radio" name="q4" value="2"> 3
            <input type="radio" name="q4" value="1"> 4<br>

            <label>5. ฉันมีกำลังใจที่จะต่อสู้กับอุปสรรค</label>
            <input type="radio" name="q5" value="1"> 1
            <input type="radio" name="q5" value="2"> 2
            <input type="radio" name="q5" value="3"> 3
            <input type="radio" name="q5" value="4"> 4<br>

            <label>6. ฉันมักจะหงุดหงิดง่ายเมื่อมีปัญหา</label>
            <input type="radio" name="q6" value="4"> 1 (reverse)
            <input type="radio" name="q6" value="3"> 2
            <input type="radio" name="q6" value="2"> 3
            <input type="radio" name="q6" value="1"> 4<br>

            <label>7. ฉันสามารถหาทางแก้ปัญหาได้เสมอ</label>
            <input type="radio" name="q7" value="1"> 1
            <input type="radio" name="q7" value="2"> 2
            <input type="radio" name="q7" value="3"> 3
            <input type="radio" name="q7" value="4"> 4<br>

            <label>8. ฉันรู้สึกว่าชีวิตไร้ค่าเมื่อเจอวิกฤต</label>
            <input type="radio" name="q8" value="4"> 1 (reverse)
            <input type="radio" name="q8" value="3"> 2
            <input type="radio" name="q8" value="2"> 3
            <input type="radio" name="q8" value="1"> 4<br>

            <label>9. ฉันสามารถเรียนรู้จากความผิดพลาด</label>
            <input type="radio" name="q9" value="1"> 1
            <input type="radio" name="q9" value="2"> 2
            <input type="radio" name="q9" value="3"> 3
            <input type="radio" name="q9" value="4"> 4<br>

            <label>10. ฉันมักจะโทษตัวเองเมื่อสิ่งต่างๆผิดพลาด</label>
            <input type="radio" name="q10" value="4"> 1 (reverse)
            <input type="radio" name="q10" value="3"> 2
            <input type="radio" name="q10" value="2"> 3
            <input type="radio" name="q10" value="1"> 4<br>

            <label>11. ฉันมีแรงบันดาลใจจากเป้าหมายในชีวิต</label>
            <input type="radio" name="q11" value="1"> 1
            <input type="radio" name="q11" value="2"> 2
            <input type="radio" name="q11" value="3"> 3
            <input type="radio" name="q11" value="4"> 4<br>

            <label>12. ฉันรู้สึกหมดหวังง่าย</label>
            <input type="radio" name="q12" value="4"> 1 (reverse)
            <input type="radio" name="q12" value="3"> 2
            <input type="radio" name="q12" value="2"> 3
            <input type="radio" name="q12" value="1"> 4<br>

            <label>13. ฉันสามารถขอความช่วยเหลือจากผู้อื่นได้</label>
            <input type="radio" name="q13" value="1"> 1
            <input type="radio" name="q13" value="2"> 2
            <input type="radio" name="q13" value="3"> 3
            <input type="radio" name="q13" value="4"> 4<br>

            <label>14. ฉันมักจะรู้สึกโดดเดี่ยวเมื่อมีปัญหา</label>
            <input type="radio" name="q14" value="4"> 1 (reverse)
            <input type="radio" name="q14" value="3"> 2
            <input type="radio" name="q14" value="2"> 3
            <input type="radio" name="q14" value="1"> 4<br>

            <label>15. ฉันสามารถควบคุมอารมณ์ได้ดี</label>
            <input type="radio" name="q15" value="1"> 1
            <input type="radio" name="q15" value="2"> 2
            <input type="radio" name="q15" value="3"> 3
            <input type="radio" name="q15" value="4"> 4<br>

            <label>16. ฉันมักจะตื่นตระหนกเมื่อเจอสถานการณ์ยากลำบาก</label>
            <input type="radio" name="q16" value="4"> 1 (reverse)
            <input type="radio" name="q16" value="3"> 2
            <input type="radio" name="q16" value="2"> 3
            <input type="radio" name="q16" value="1"> 4<br>

            <label>17. ฉันเชื่อว่าทุกปัญหามีทางออก</label>
            <input type="radio" name="q17" value="1"> 1
            <input type="radio" name="q17" value="2"> 2
            <input type="radio" name="q17" value="3"> 3
            <input type="radio" name="q17" value="4"> 4<br>

            <label>18. ฉันรู้สึกว่าตนเองอ่อนแอ</label>
            <input type="radio" name="q18" value="4"> 1 (reverse)
            <input type="radio" name="q18" value="3"> 2
            <input type="radio" name="q18" value="2"> 3
            <input type="radio" name="q18" value="1"> 4<br>

            <label>19. ฉันสามารถฟื้นตัวจากความล้มเหลวได้</label>
            <input type="radio" name="q19" value="1"> 1
            <input type="radio" name="q19" value="2"> 2
            <input type="radio" name="q19" value="3"> 3
            <input type="radio" name="q19" value="4"> 4<br>

            <label>20. ฉันมักจะยอมแพ้ก่อนที่จะพยายาม</label>
            <input type="radio" name="q20" value="4"> 1 (reverse)
            <input type="radio" name="q20" value="3"> 2
            <input type="radio" name="q20" value="2"> 3
            <input type="radio" name="q20" value="1"> 4<br>

            <button type="button" onclick="calculateRQ()">คำนวณผล</button>
            <button type="button" onclick="clearForm('rqForm', 'rqResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="rqResult" class="result"></div>
    </section>

    <!-- ASSIST -->
    <section id="assist">
        <h2>แบบประเมินความเสี่ยงต่อการใช้สารเสพติด (ASSIST)</h2>
        <div class="emergency-contacts">
            หากรู้สึกแย่มาก ต้องการความช่วยเหลือฉุกเฉิน โทร 1669 หรือ สายด่วนยาเสพติด 1165
        </div>
        <form id="assistForm">
            <p>เลือกสารที่ต้องการประเมิน (สามารถเลือกหลายสารได้ แต่คำนวณทีละสารเพื่อความง่าย)</p>
            <select id="substance">
                <option value="tobacco">ยาสูบ</option>
                <option value="alcohol">สุรา</option>
                <option value="cannabis">กัญชา</option>
                <option value="cocaine">โคเคน</option>
                <option value="amphetamine">ยาบ้า/แอมเฟตามีน</option>
                <option value="inhalants">สารระเหย</option>
                <option value="sedatives">ยานอนหลับ</option>
                <option value="hallucinogens">ยาหลอนประสาท</option>
                <option value="opioids">ฝิ่น</option>
                <option value="other">อื่นๆ</option>
            </select><br>

            <label>Q1: ในชีวิตท่านเคยใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q1" value="0"> ไม่เคย
            <input type="radio" name="q1" value="1"> เคย (หากไม่เคย ข้ามไป)<br>

            <label>Q2: ใน 3 เดือนที่ผ่านมา ท่านใช้สารนี้บ่อยเพียงใด?</label>
            <input type="radio" name="q2" value="0"> ไม่เคย (0)
            <input type="radio" name="q2" value="2"> 1-2 ครั้ง (2)
            <input type="radio" name="q2" value="3"> ทุกเดือน (3)
            <input type="radio" name="q2" value="4"> ทุกสัปดาห์ (4)
            <input type="radio" name="q2" value="6"> เกือบทุกวัน (6)<br>

            <label>Q3: ใน 3 เดือนที่ผ่านมา ท่านรู้สึกอยากใช้สารนี้อย่างรุนแรงบ่อยเพียงใด?</label>
            <input type="radio" name="q3" value="0"> ไม่เคย (0)
            <input type="radio" name="q3" value="3"> 1-2 ครั้ง (3)
            <input type="radio" name="q3" value="4"> ทุกเดือน (4)
            <input type="radio" name="q3" value="5"> ทุกสัปดาห์ (5)
            <input type="radio" name="q3" value="6"> เกือบทุกวัน (6)<br>

            <label>Q4: ใน 3 เดือนที่ผ่านมา การใช้สารนี้ทำให้เกิดปัญหาสุขภาพ สังคม กฎหมาย การเงิน ต่อท่านบ่อยเพียงใด?</label>
            <input type="radio" name="q4" value="0"> ไม่เคย (0)
            <input type="radio" name="q4" value="4"> 1-2 ครั้ง (4)
            <input type="radio" name="q4" value="5"> ทุกเดือน (5)
            <input type="radio" name="q4" value="6"> ทุกสัปดาห์ (6)
            <input type="radio" name="q4" value="7"> เกือบทุกวัน (7)<br>

            <label>Q5: ใน 3 เดือนที่ผ่านมา ท่านไม่สามารถทำกิจกรรมปกติเพราะใช้สารนี้บ่อยเพียงใด? (ยกเว้นยาสูบ)</label>
            <input type="radio" name="q5" value="0"> ไม่เคย (0)
            <input type="radio" name="q5" value="5"> 1-2 ครั้ง (5)
            <input type="radio" name="q5" value="6"> ทุกเดือน (6)
            <input type="radio" name="q5" value="7"> ทุกสัปดาห์ (7)
            <input type="radio" name="q5" value="8"> เกือบทุกวัน (8)<br>

            <label>Q6: เพื่อน ญาติ หรือคนอื่นเคยแสดงความห่วงใยหรือตักเตือนท่านเกี่ยวกับการใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q6" value="0"> ไม่เคย (0)
            <input type="radio" name="q6" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q6" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q7: ท่านเคยพยายามหยุดหรือลดการใช้สารนี้แต่ไม่สำเร็จหรือไม่?</label>
            <input type="radio" name="q7" value="0"> ไม่เคย (0)
            <input type="radio" name="q7" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q7" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q8: ท่านเคยใช้สารนี้โดยการฉีดหรือไม่?</label>
            <input type="radio" name="q8" value="0"> ไม่เคย (0)
            <input type="radio" name="q8" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q8" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <button type="button" onclick="calculateASSIST()">คำนวณผล</button>
            <button type="button" onclick="clearForm('assistForm', 'assistResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="assistResult" class="result"></div>
    </section>

    <script>
        function validateForm(formId) {
            const form = document.getElementById(formId);
            const radioGroups = {};
            form.querySelectorAll('input[type="radio"]').forEach(radio => {
                if (!radioGroups[radio.name]) {
                    radioGroups[radio.name] = [];
                }
                radioGroups[radio.name].push(radio);
            });

            for (const groupName in radioGroups) {
                const group = radioGroups[groupName];
                const isChecked = group.some(radio => radio.checked);
                if (!isChecked) {
                    alert('กรุณาตอบคำถามทุกข้อในแบบประเมินนี้');
                    return false;
                }
            }
            return true;
        }

        function validateASSISTForm(formId) {
            const form = document.getElementById(formId);
            const q1Radios = form.querySelectorAll('input[name="q1"]');
            let q1Value = null;

            let q1Answered = false;
            for (const radio of q1Radios) {
                if (radio.checked) {
                    q1Value = parseInt(radio.value);
                    q1Answered = true;
                    break;
                }
            }

            if (!q1Answered) {
                alert('กรุณาตอบคำถาม Q1 ก่อน');
                return false;
            }

            if (q1Value === 0) {
                // If Q1 is 'ไม่เคย', no need to validate other questions.
                return true;
            }

            // If Q1 is 'เคย', validate Q2-Q8
            for (let i = 2; i <= 8; i++) {
                const qRadios = form.querySelectorAll(`input[name="q${i}"]`);
                let qAnswered = false;
                for (const radio of qRadios) {
                    if (radio.checked) {
                        qAnswered = true;
                        break;
                    }
                }
                if (!qAnswered) {
                    alert('กรุณาตอบคำถามทุกข้อในแบบประเมิน ASSIST');
                    return false;
                }
            }
            return true;
        }

        function clearForm(formId, resultId) {
            document.getElementById(formId).reset();
            document.getElementById(resultId).innerHTML = '';
            document.getElementById(resultId).style.display = 'none';
        }

        function calculateST5() {
            if (!validateForm('st5Form')) return;
            let form = document.getElementById('st5Form');
            let score = 0;
            for (let i = 1; i <= 5; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            let result = '';
            if (score <= 4) result = 'ความเครียดระดับปกติ';
            else if (score <= 7) result = 'ความเครียดระดับน้อย';
            else if (score <= 9) result = 'ความเครียดระดับปานกลาง';
            else result = 'ความเครียดระดับรุนแรง';
            document.getElementById('st5Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('st5Result').style.display = 'block';
        }

        function calculate2Q9Q8Q() {
            if (!validateForm('2q9q8qForm')) return;
            let form = document.getElementById('2q9q8qForm');
            let score2Q = 0, score9Q = 0, score8Q = 0;
            let result2Q = '', result9Q = '', result8Q = '';

            // 2Q
            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="2q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            // 9Q
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="9q${i}"]:checked`);
                if (q) score9Q += parseInt(q.value);
            }
            if (score9Q <= 6) result9Q = 'ไม่เป็นโรคซึมเศร้า';
            else if (score9Q <= 12) result9Q = 'ซึมเศร้าระดับน้อย';
            else if (score9Q <= 18) result9Q = 'ซึมเศร้าระดับปานกลาง';
            else result9Q = 'ซึมเศร้าระดับรุนแรง';

            // 8Q
            for (let i = 1; i <= 8; i++) {
                let q = form.querySelector(`input[name="8q${i}"]:checked`);
                if (q) score8Q += parseInt(q.value);
            }
            if (score8Q === 0) result8Q = 'ไม่มีความเสี่ยง';
            else if (score8Q <= 8) result8Q = 'เสี่ยงต่ำ';
            else if (score8Q <= 16) result8Q = 'เสี่ยงปานกลาง';
            else result8Q = 'เสี่ยงสูง';

            document.getElementById('2q9q8qResult').innerHTML = `2Q: คะแนน ${score2Q} - ${result2Q}<br>9Q: คะแนน ${score9Q} - ${result9Q}<br>8Q: คะแนน ${score8Q} - ${result8Q}`;
            document.getElementById('2q9q8qResult').style.display = 'block';
        }

        function calculate2QPlus() {
            if (!validateForm('2qplusForm')) return;
            let form = document.getElementById('2qplusForm');
            let score2Q = 0, plus = 0;
            let result2Q = '', resultPlus = '';

            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            let p = form.querySelector(`input[name="plus"]:checked`);
            if (p) plus = parseInt(p.value);
            if (plus === 1) resultPlus = 'เสี่ยงฆ่าตัวตาย';
            else resultPlus = 'ไม่เสี่ยงฆ่าตัวตาย';

            document.getElementById('2qplusResult').innerHTML = `2Q: ${result2Q}<br>Plus: ${resultPlus}`;
            document.getElementById('2qplusResult').style.display = 'block';
        }

        function calculatePHQA() {
            if (!validateForm('phqaForm')) return;
            let form = document.getElementById('phqaForm');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score <= 4) result = 'ไม่มีภาวะซึมเศร้า';
            else if (score <= 9) result = 'ซึมเศร้าเล็กน้อย';
            else if (score <= 14) result = 'ซึมเศร้าปานกลาง';
            else if (score <= 19) result = 'ซึมเศร้ามาก';
            else result = 'ซึมเศร้ารุนแรง';

            let extra1 = form.querySelector(`input[name="extra1"]:checked`) ? form.querySelector(`input[name="extra1"]:checked`).value : 'ไม่ตอบ';
            let extra2 = form.querySelector(`input[name="extra2"]:checked`) ? form.querySelector(`input[name="extra2"]:checked`).value : 'ไม่ตอบ';

            document.getElementById('phqaResult').innerHTML = `คะแนนรวม: ${score} - ${result}<br>เคยพยายามทำร้ายตัวเอง: ${extra1 === '1' ? 'มี' : 'ไม่มี'}<br>เคยคิดอยากตาย: ${extra2 === '1' ? 'มี' : 'ไม่มี'}`;
            document.getElementById('phqaResult').style.display = 'block';
        }

        function calculateTMHI15() {
            if (!validateForm('tmhi15Form')) return;
            let form = document.getElementById('tmhi15Form');
            let score = 0;
            for (let i = 1; i <= 15; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            let result = '';
            if (score >= 33) result = 'สุขภาพจิตดีกว่าคนทั่วไป';
            else if (score >= 27) result = 'สุขภาพจิตเท่าคนทั่วไป';
            else result = 'สุขภาพจิตต่ำกว่าคนทั่วไป';
            document.getElementById('tmhi15Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('tmhi15Result').style.display = 'block';
        }

        function calculateRQ() {
            if (!validateForm('rqForm')) return;
            let form = document.getElementById('rqForm');
            let score = 0;
            for (let i = 1; i <= 20; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score < 60) result = 'พลังใจต่ำ (แนะนำพัฒนา)';
            else result = 'พลังใจดี';
            document.getElementById('rqResult').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('rqResult').style.display = 'block';
        }

        function calculateASSIST() {
            if (!validateASSISTForm('assistForm')) return; // Use the new validation function

            let form = document.getElementById('assistForm');
            let substance = document.getElementById('substance').value;
            let score = 0;
            let result = '';
            let isTobacco = substance === 'tobacco';

            let q1 = form.querySelector(`input[name="q1"]:checked`) ? parseInt(form.querySelector(`input[name="q1"]:checked`).value) : 0;

            if (q1 === 0) {
                result = 'ไม่เคยใช้สารนี้';
            } else {
                // Calculate score for Q2-Q7
                for (let i = 2; i <= 7; i++) {
                    let q = form.querySelector(`input[name="q${i}"]:checked`);
                    if (q && !(isTobacco && i === 5)) { // Q5 is skipped for tobacco
                        score += parseInt(q.value);
                    }
                }

                let q8 = form.querySelector(`input[name="q8"]:checked`) ? parseInt(form.querySelector(`input[name="q8"]:checked`).value) : 0;

                if (substance === 'alcohol') {
                    if (score <= 10) result = 'เสี่ยงต่ำ';
                    else if (score <= 26) result = 'เสี่ยงปานกลาง';
                    else result = 'เสี่ยงสูง';
                } else { // All other substances
                    if (score <= 3) result = 'เสี่ยงต่ำ';
                    else if (score <= 26) result = 'เสี่ยงปานกลาง';
                    else result = 'เสี่ยงสูง';
                }

                // Q8 is a separate high-risk indicator, not part of the score
                if (q8 === 6) {
                    result += '<br><b>มีการฉีดสารนี้ใน 3 เดือนที่แล้ว - เสี่ยงสูงมาก (โปรดปรึกษาผู้เชี่ยวชาญทันที)</b>';
                }
            }
            document.getElementById('assistResult').innerHTML = `สาร: ${substance}<br>คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('assistResult').style.display = 'block';
        }
    </script>
</body>
</html>
'''

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="th">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
#     <style>
#         body { font-family: Arial, sans-serif; margin: 20px; }
#         h1, h2 { text-align: center; }
#         section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
#         form { margin: 0 auto; max-width: 800px; }
#         label { display: block; margin: 10px 0; }
#         input[type="radio"] { margin-right: 10px; }
#         button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
#         button:hover { background-color: #45a049; }
#         .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
#         nav { text-align: center; margin-bottom: 30px; }
# ...

# %% [markdown]
# ## Clarify ASSIST Q8 Scoring Display
#
# ### Subtask:
# Modify the `calculateASSIST()` function to explicitly state that Q8 is a separate high-risk indicator and not part of the numerical score, making the output clearer to the user.

# %% [markdown]
# **Reasoning**:
# The subtask requires modifying the `calculateASSIST()` JavaScript function to clarify how Q8 is treated in the scoring and ensure the warning message is distinct. I will update the `html_content` to reflect these changes in the JavaScript section.

# %%
from IPython.display import HTML

html_content = '''
<!DOCTYPE html>
<html lang="th">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
    <style>
        body { font-family: Arial, sans-serif; margin: 20px; }
        h1, h2 { text-align: center; }
        section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
        form { margin: 0 auto; max-width: 800px; }
        label { display: block; margin: 10px 0; }
        input[type="radio"] { margin-right: 10px; }
        button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
        button:hover { background-color: #45a049; }
        .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
        nav { text-align: center; margin-bottom: 30px; }
        nav a { margin: 10px; text-decoration: none; color: #007BFF; }
        nav a:hover { text-decoration: underline; }
        select { margin: 10px 0; }
        .emergency-contacts { margin-top: 20px; padding: 10px; border: 1px solid #f00; background-color: #ffe0e0; color: #f00; text-align: center; font-weight: bold; }
    </style>
</head>
<body>
    <h1>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</h1>
    <p style="text-align: center;">ยินดีต้อนรับสู่แพลตฟอร์มประเมินสุขภาพจิตเบื้องต้น กรุณาเลือกแบบประเมินที่ต้องการจากเมนูด้านล่าง โปรดตอบตามความรู้สึกจริงเพื่อผลลัพธ์ที่แม่นยำที่สุด ผลลัพธ์นี้ไม่ใช่การวินิจฉัยทางการแพทย์ ควรปรึกษาแพทย์หากมีอาการรุนแรง</p>

    <nav>
        <a href="#st5">ST-5 (ความเครียด)</a> |
        <a href="#2q9q8q">2Q-9Q-8Q (ซึมเศร้า/ฆ่าตัวตาย)</a> |
        <a href="#2qplus">2Q Plus</a> |
        <a href="#phqa">PHQ-A (ซึมเศร้าในวัยรุ่น)</a> |
        <a href="#tmhi15">TMHI-15 (สุขภาพจิตคนไทย)</a> |
        <a href="#rq">RQ (พลังสุขภาพจิต)</a> |
        <a href="#assist">ASSIST (สารเสพติด)</a>
    </nav>

    <!-- ST-5 -->
    <section id="st5">
        <h2>แบบประเมินความเครียด (ST-5)</h2>
        <form id="st5Form">
            <p>ในช่วง 2-4 สัปดาห์ที่ผ่านมา รวมวันนี้ อาการเหล่านี้รบกวนท่านมากน้อยเพียงใด</p>
            <label>1. ท่านรู้สึกปวดศีรษะหรือปวดต้นคอ</label>
            <input type="radio" name="q1" value="0"> แทบไม่มี (0)
            <input type="radio" name="q1" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q1" value="3"> เกือบตลอด (3)<br>

            <label>2. ท่านรู้สึกหงุดหงิด โมโหง่าย</label>
            <input type="radio" name="q2" value="0"> แทบไม่มี (0)
            <input type="radio" name="q2" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q2" value="3"> เกือบตลอด (3)<br>

            <label>3. ท่านรู้สึกเบื่อ เซ็ง</label>
            <input type="radio" name="q3" value="0"> แทบไม่มี (0)
            <input type="radio" name="q3" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q3" value="3"> เกือบตลอด (3)<br>

            <label>4. ท่านรู้สึกเครียด กลุ้มใจ</label>
            <input type="radio" name="q4" value="0"> แทบไม่มี (0)
            <input type="radio" name="q4" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q4" value="3"> เกือบตลอด (3)<br>

            <label>5. ท่านรู้สึกท้อแท้ หมดหวัง</label>
            <input type="radio" name="q5" value="0"> แทบไม่มี (0)
            <input type="radio" name="q5" value="1"> เป็นบางครั้ง (1)
            <input type="radio" name="q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="q5" value="3"> เกือบตลอด (3)<br>

            <button type="button" onclick="calculateST5()">คำนวณผล</button>
            <button type="button" onclick="clearForm('st5Form', 'st5Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="st5Result" class="result"></div>
    </section>

    <!-- 2Q-9Q-8Q -->
    <section id="2q9q8q">
        <h2>แบบประเมินซึมเศร้า / ฆ่าตัวตาย (2Q-9Q-8Q)</h2>
        <div class="emergency-contacts">
            หากรู้สึกแย่มาก ต้องการความช่วยเหลือฉุกเฉิน โทร 1669 หรือ สายด่วนสุขภาพจิต 1323
        </div>
        <form id="2q9q8qForm">
            <h3>2Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านรู้สึก...</h3>
            <label>1. หดหู่ เศร้า หรือท้อแท้สิ้นหวัง</label>
            <input type="radio" name="2q1" value="0"> ไม่มี
            <input type="radio" name="2q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="2q2" value="0"> ไม่มี
            <input type="radio" name="2q2" value="1"> มี<br>

            <h3>9Q: ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้บ่อยแค่ไหน</h3>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="9q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q1" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q1" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q1" value="3"> เป็นทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="9q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q2" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q2" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q2" value="3"> เป็นทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="9q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q3" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q3" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q3" value="3"> เป็นทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="9q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q4" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q4" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q4" value="3"> เป็นทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="9q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q5" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q5" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q5" value="3"> เป็นทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="9q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q6" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q6" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q6" value="3"> เป็นทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือพิมพ์หรือดูโทรทัศน์</label>
            <input type="radio" name="9q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q7" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q7" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q7" value="3"> เป็นทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="9q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q8" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q8" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q8" value="3"> เป็นทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="9q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="9q9" value="1"> เป็นบางวัน (1)
            <input type="radio" name="9q9" value="2"> เป็นบ่อย >7 วัน (2)
            <input type="radio" name="9q9" value="3"> เป็นทุกวัน (3)<br>

            <h3>8Q: ใน 1 เดือนที่ผ่านมา รวมวันนี้ ท่านมี...</h3>
            <label>1. ความคิดอยากตาย หรือคิดว่าตายเสียจะดีกว่า</label>
            <input type="radio" name="8q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q1" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q1" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q1" value="3"> เกือบทุกวัน (3)<br>

            <label>2. อยากทำร้ายตัวเอง หรือทำให้ตัวเองบาดเจ็บ</label>
            <input type="radio" name="8q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q2" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q2" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q2" value="3"> เกือบทุกวัน (3)<br>

            <label>3. คิดเกี่ยวกับความตาย</label>
            <input type="radio" name="8q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q3" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q3" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q3" value="3"> เกือบทุกวัน (3)<br>

            <label>4. มีแผนการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q4" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q4" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q4" value="3"> เกือบทุกวัน (3)<br>

            <label>5. มีแผนการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q5" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q5" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q5" value="3"> เกือบทุกวัน (3)<br>

            <label>6. เตรียมการที่จะทำร้ายตัวเอง</label>
            <input type="radio" name="8q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q6" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q6" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q6" value="3"> เกือบทุกวัน (3)<br>

            <label>7. เตรียมการที่จะฆ่าตัวตาย</label>
            <input type="radio" name="8q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q7" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q7" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q7" value="3"> เกือบทุกวัน (3)<br>

            <label>8. ท่านเคยพยายามฆ่าตัวตาย</label>
            <input type="radio" name="8q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="8q8" value="1"> น้อยครั้ง (1)
            <input type="radio" name="8q8" value="2"> บ่อยครั้ง (2)
            <input type="radio" name="8q8" value="3"> เกือบทุกวัน (3)<br>

            <button type="button" onclick="calculate2Q9Q8Q()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2q9q8qForm', '2q9q8qResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2q9q8qResult" class="result"></div>
    </section>

    <!-- 2Q Plus -->
    <section id="2qplus">
        <h2>แบบประเมิน 2Q Plus (ฉบับปรับปรุง)</h2>
        <div class="emergency-contacts">
            หากรู้สึกแย่มาก ต้องการความช่วยเหลือฉุกเฉิน โทร 1669 หรือ สายด่วนสุขภาพจิต 1323
        </div>
        <form id="2qplusForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา รวมวันนี้ ท่านมีอาการเหล่านี้หรือไม่</p>
            <label>1. ไม่สบายใจ เซ็ง ทุกข์ใจ เศร้า ท้อแท้ ซึม หงอย</label>
            <input type="radio" name="q1" value="0"> ไม่มี
            <input type="radio" name="q1" value="1"> มี<br>

            <label>2. เบื่อ ไม่อยากพูดไม่อยากทำอะไร หรือทำอะไรก็ไม่สนุกเพลิดเพลินเหมือนเดิม</label>
            <input type="radio" name="q2" value="0"> ไม่มี
            <input type="radio" name="q2" value="1"> มี<br>

            <p>ใน 1 เดือนที่ผ่านมา รวมวันนี้</p>
            <label>ท่านมีความรู้สึกทุกข์ใจจนไม่อยากมีชีวิตอยู่หรือไม่</label>
            <input type="radio" name="plus" value="0"> ไม่มี
            <input type="radio" name="plus" value="1"> มี<br>

            <button type="button" onclick="calculate2QPlus()">คำนวณผล</button>
            <button type="button" onclick="clearForm('2qplusForm', '2qplusResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="2qplusResult" class="result"></div>
    </section>

    <!-- PHQ-A -->
    <section id="phqa">
        <h2>แบบประเมินภาวะซึมเศร้าในวัยรุ่น (PHQ-A)</h2>
        <div class="emergency-contacts">
            หากรู้สึกแย่มาก ต้องการความช่วยเหลือฉุกเฉิน โทร 1669 หรือ สายด่วนสุขภาพจิต 1323
        </div>
        <form id="phqaForm">
            <p>ใน 2 สัปดาห์ที่ผ่านมา ท่านมีอาการเหล่านี้บ่อยแค่ไหน (สำหรับวัยรุ่นอายุ 11-20 ปี)</p>
            <label>1. เบื่อ ไม่สนใจอยากทำอะไร</label>
            <input type="radio" name="q1" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q1" value="1"> มีบางวัน (1)
            <input type="radio" name="q1" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q1" value="3"> แทบทุกวัน (3)<br>

            <label>2. ไม่สบายใจ ซึมเศร้า ท้อแท้</label>
            <input type="radio" name="q2" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q2" value="1"> มีบางวัน (1)
            <input type="radio" name="q2" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q2" value="3"> แทบทุกวัน (3)<br>

            <label>3. หลับยาก หรือหลับๆ ตื่นๆ หรือหลับมากเกินไป</label>
            <input type="radio" name="q3" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q3" value="1"> มีบางวัน (1)
            <input type="radio" name="q3" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q3" value="3"> แทบทุกวัน (3)<br>

            <label>4. เหนื่อยง่าย หรือไม่ค่อยมีแรง</label>
            <input type="radio" name="q4" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q4" value="1"> มีบางวัน (1)
            <input type="radio" name="q4" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q4" value="3"> แทบทุกวัน (3)<br>

            <label>5. เบื่ออาหาร หรือกินมากเกินไป</label>
            <input type="radio" name="q5" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q5" value="1"> มีบางวัน (1)
            <input type="radio" name="q5" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q5" value="3"> แทบทุกวัน (3)<br>

            <label>6. รู้สึกไม่ดีกับตัวเอง รู้สึกตนเองล้มเหลว หรือทำให้ตนเอง/ครอบครัวผิดหวัง</label>
            <input type="radio" name="q6" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q6" value="1"> มีบางวัน (1)
            <input type="radio" name="q6" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q6" value="3"> แทบทุกวัน (3)<br>

            <label>7. ไม่มีสมาธิ เช่นตอนอ่านหนังสือหรือดูโทรทัศน์</label>
            <input type="radio" name="q7" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q7" value="1"> มีบางวัน (1)
            <input type="radio" name="q7" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q7" value="3"> แทบทุกวัน (3)<br>

            <label>8. พูดหรือทำอะไรช้าลง จนคนอื่นสังเกตเห็น หรือกระสับกระส่ายไม่สามารถอยู่นิ่งได้เหมือนเคย</label>
            <input type="radio" name="q8" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q8" value="1"> มีบางวัน (1)
            <input type="radio" name="q8" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q8" value="3"> แทบทุกวัน (3)<br>

            <label>9. คิดทำร้ายตนเอง คิดว่าตายเสียดีกว่า หรือคิดฆ่าตัวตาย</label>
            <input type="radio" name="q9" value="0"> ไม่มีเลย (0)
            <input type="radio" name="q9" value="1"> มีบางวัน (1)
            <input type="radio" name="q9" value="2"> มากกว่า 7 วัน (2)
            <input type="radio" name="q9" value="3"> แทบทุกวัน (3)<br>

            <p>คำถามเพิ่มเติม (ไม่คิดคะแนน):</p>
            <label>ในปีที่ผ่านมา ท่านเคยพยายามทำร้ายตัวเองหรือไม่?</label>
            <input type="radio" name="extra1" value="0"> ไม่มี
            <input type="radio" name="extra1" value="1"> มี<br>

            <label>ในปีที่ผ่านมา ท่านเคยคิดอยากตายหรือไม่?</label>
            <input type="radio" name="extra2" value="0"> ไม่มี
            <input type="radio" name="extra2" value="1"> มี<br>

            <button type="button" onclick="calculatePHQA()">คำนวณผล</button>
            <button type="button" onclick="clearForm('phqaForm', 'phqaResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="phqaResult" class="result"></div>
    </section>

    <!-- TMHI-15 -->
    <section id="tmhi15">
        <h2>ดัชนีชี้วัดสุขภาพจิตของคนไทย (TMHI-15)</h2>
        <form id="tmhi15Form">
            <p>กรุณาเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด สำหรับประสบการณ์ในช่วง 1 เดือนที่ผ่านมา</p>
            <label>1. ท่านรู้สึกพึงพอใจในชีวิต</label>
            <input type="radio" name="q1" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q1" value="1"> เล็กน้อย (1)
            <input type="radio" name="q1" value="2"> มาก (2)
            <input type="radio" name="q1" value="3"> มากที่สุด (3)<br>

            <label>2. ท่านรู้สึกสบายใจ</label>
            <input type="radio" name="q2" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q2" value="1"> เล็กน้อย (1)
            <input type="radio" name="q2" value="2"> มาก (2)
            <input type="radio" name="q2" value="3"> มากที่สุด (3)<br>

            <label>3. ท่านรู้สึกเบื่อหน่ายท้อแท้กับการดำเนินชีวิตประจำวัน</label>
            <input type="radio" name="q3" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q3" value="2"> เล็กน้อย (2)
            <input type="radio" name="q3" value="1"> มาก (1)
            <input type="radio" name="q3" value="0"> มากที่สุด (0)<br>

            <label>4. ท่านรู้สึกผิดหวังในตัวเอง</label>
            <input type="radio" name="q4" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q4" value="2"> เล็กน้อย (2)
            <input type="radio" name="q4" value="1"> มาก (1)
            <input type="radio" name="q4" value="0"> มากที่สุด (0)<br>

            <label>5. ท่านรู้สึกว่าชีวิตของท่านมีแต่ความทุกข์</label>
            <input type="radio" name="q5" value="3"> ไม่อย่างเลย (3)
            <input type="radio" name="q5" value="2"> เล็กน้อย (2)
            <input type="radio" name="q5" value="1"> มาก (1)
            <input type="radio" name="q5" value="0"> มากที่สุด (0)<br>

            <label>6. ท่านสามารถทำใจยอมรับได้สำหรับปัญหาที่ยากจะแก้ไข (เมื่อมีปัญหา)</label>
            <input type="radio" name="q6" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q6" value="1"> เล็กน้อย (1)
            <input type="radio" name="q6" value="2"> มาก (2)
            <input type="radio" name="q6" value="3"> มากที่สุด (3)<br>

            <label>7. ท่านมั่นใจว่าจะสามารถควบคุมอารมณ์ได้เมื่อมีเหตุการณ์คับขันหรือร้ายแรงเกิดขึ้น</label>
            <input type="radio" name="q7" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q7" value="1"> เล็กน้อย (1)
            <input type="radio" name="q7" value="2"> มาก (2)
            <input type="radio" name="q7" value="3"> มากที่สุด (3)<br>

            <label>8. ท่านมั่นใจที่จะเผชิญกับเหตุการณ์ร้ายแรงที่เกิดขึ้นในชีวิต</label>
            <input type="radio" name="q8" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q8" value="1"> เล็กน้อย (1)
            <input type="radio" name="q8" value="2"> มาก (2)
            <input type="radio" name="q8" value="3"> มากที่สุด (3)<br>

            <label>9. ท่านรู้สึกเห็นอกเห็นใจเมื่อผู้อื่นมีทุกข์</label>
            <input type="radio" name="q9" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q9" value="1"> เล็กน้อย (1)
            <input type="radio" name="q9" value="2"> มาก (2)
            <input type="radio" name="q9" value="3"> มากที่สุด (3)<br>

            <label>10. ท่านรู้สึกเป็นสุขในการช่วยเหลือผู้อื่นที่มีปัญหา</label>
            <input type="radio" name="q10" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q10" value="1"> เล็กน้อย (1)
            <input type="radio" name="q10" value="2"> มาก (2)
            <input type="radio" name="q10" value="3"> มากที่สุด (3)<br>

            <label>11. ท่านให้ความช่วยเหลือแก่ผู้อื่นเมื่อมีโอกาส</label>
            <input type="radio" name="q11" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q11" value="1"> เล็กน้อย (1)
            <input type="radio" name="q11" value="2"> มาก (2)
            <input type="radio" name="q11" value="3"> มากที่สุด (3)<br>

            <label>12. ท่านรู้สึกภูมิใจในตนเอง</label>
            <input type="radio" name="q12" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q12" value="1"> เล็กน้อย (1)
            <input type="radio" name="q12" value="2"> มาก (2)
            <input type="radio" name="q12" value="3"> มากที่สุด (3)<br>

            <label>13. ท่านรู้สึกมั่นคง ปลอดภัย เมื่ออยู่ในครอบครัว</label>
            <input type="radio" name="q13" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q13" value="1"> เล็กน้อย (1)
            <input type="radio" name="q13" value="2"> มาก (2)
            <input type="radio" name="q13" value="3"> มากที่สุด (3)<br>

            <label>14. หากท่านป่วยหนัก ท่านเชื่อว่าครอบครัวจะดูแลท่านเป็นอย่างดี</label>
            <input type="radio" name="q14" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q14" value="1"> เล็กน้อย (1)
            <input type="radio" name="q14" value="2"> มาก (2)
            <input type="radio" name="q14" value="3"> มากที่สุด (3)<br>

            <label>15. สมาชิกในครอบครัวมีความรักและผูกพันต่อกัน</label>
            <input type="radio" name="q15" value="0"> ไม่อย่างเลย (0)
            <input type="radio" name="q15" value="1"> เล็กน้อย (1)
            <input type="radio" name="q15" value="2"> มาก (2)
            <input type="radio" name="q15" value="3"> มากที่สุด (3)<br>

            <button type="button" onclick="calculateTMHI15()">คำนวณผล</button>
            <button type="button" onclick="clearForm('tmhi15Form', 'tmhi15Result')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="tmhi15Result" class="result"></div>
    </section>

    <!-- RQ -->
    <section id="rq">
        <h2>แบบประเมินพลังสุขภาพจิต (RQ) ฉบับ 20 ข้อ</h2>
        <form id="rqForm">
            <p>โปรดเลือกคำตอบที่ตรงกับตัวท่านมากที่สุด (1=ไม่จริงเลย, 2=ไม่จริง, 3=ค่อนข้างจริง, 4=จริงมาก)</p>
            <label>1. ฉันสามารถทนต่อแรงกดดันได้ดี</label>
            <input type="radio" name="q1" value="1"> 1
            <input type="radio" name="q1" value="2"> 2
            <input type="radio" name="q1" value="3"> 3
            <input type="radio" name="q1" value="4"> 4<br>

            <label>2. ฉันมักจะยอมแพ้เมื่อเจอปัญหายากๆ</label>
            <input type="radio" name="q2" value="4"> 1 (reverse)
            <input type="radio" name="q2" value="3"> 2
            <input type="radio" name="q2" value="2"> 3
            <input type="radio" name="q2" value="1"> 4<br>

            <label>3. ฉันสามารถปรับตัวเข้ากับการเปลี่ยนแปลงได้</label>
            <input type="radio" name="q3" value="1"> 1
            <input type="radio" name="q3" value="2"> 2
            <input type="radio" name="q3" value="3"> 3
            <input type="radio" name="q3" value="4"> 4<br>

            <label>4. ฉันรู้สึกสิ้นหวังเมื่อล้มเหลว</label>
            <input type="radio" name="q4" value="4"> 1 (reverse)
            <input type="radio" name="q4" value="3"> 2
            <input type="radio" name="q4" value="2"> 3
            <input type="radio" name="q4" value="1"> 4<br>

            <label>5. ฉันมีกำลังใจที่จะต่อสู้กับอุปสรรค</label>
            <input type="radio" name="q5" value="1"> 1
            <input type="radio" name="q5" value="2"> 2
            <input type="radio" name="q5" value="3"> 3
            <input type="radio" name="q5" value="4"> 4<br>

            <label>6. ฉันมักจะหงุดหงิดง่ายเมื่อมีปัญหา</label>
            <input type="radio" name="q6" value="4"> 1 (reverse)
            <input type="radio" name="q6" value="3"> 2
            <input type="radio" name="q6" value="2"> 3
            <input type="radio" name="q6" value="1"> 4<br>

            <label>7. ฉันสามารถหาทางแก้ปัญหาได้เสมอ</label>
            <input type="radio" name="q7" value="1"> 1
            <input type="radio" name="q7" value="2"> 2
            <input type="radio" name="q7" value="3"> 3
            <input type="radio" name="q7" value="4"> 4<br>

            <label>8. ฉันรู้สึกว่าชีวิตไร้ค่าเมื่อเจอวิกฤต</label>
            <input type="radio" name="q8" value="4"> 1 (reverse)
            <input type="radio" name="q8" value="3"> 2
            <input type="radio" name="q8" value="2"> 3
            <input type="radio" name="q8" value="1"> 4<br>

            <label>9. ฉันสามารถเรียนรู้จากความผิดพลาด</label>
            <input type="radio" name="q9" value="1"> 1
            <input type="radio" name="q9" value="2"> 2
            <input type="radio" name="q9" value="3"> 3
            <input type="radio" name="q9" value="4"> 4<br>

            <label>10. ฉันมักจะโทษตัวเองเมื่อสิ่งต่างๆผิดพลาด</label>
            <input type="radio" name="q10" value="4"> 1 (reverse)
            <input type="radio" name="q10" value="3"> 2
            <input type="radio" name="q10" value="2"> 3
            <input type="radio" name="q10" value="1"> 4<br>

            <label>11. ฉันมีแรงบันดาลใจจากเป้าหมายในชีวิต</label>
            <input type="radio" name="q11" value="1"> 1
            <input type="radio" name="q11" value="2"> 2
            <input type="radio" name="q11" value="3"> 3
            <input type="radio" name="q11" value="4"> 4<br>

            <label>12. ฉันรู้สึกหมดหวังง่าย</label>
            <input type="radio" name="q12" value="4"> 1 (reverse)
            <input type="radio" name="q12" value="3"> 2
            <input type="radio" name="q12" value="2"> 3
            <input type="radio" name="q12" value="1"> 4<br>

            <label>13. ฉันสามารถขอความช่วยเหลือจากผู้อื่นได้</label>
            <input type="radio" name="q13" value="1"> 1
            <input type="radio" name="q13" value="2"> 2
            <input type="radio" name="q13" value="3"> 3
            <input type="radio" name="q13" value="4"> 4<br>

            <label>14. ฉันมักจะรู้สึกโดดเดี่ยวเมื่อมีปัญหา</label>
            <input type="radio" name="q14" value="4"> 1 (reverse)
            <input type="radio" name="q14" value="3"> 2
            <input type="radio" name="q14" value="2"> 3
            <input type="radio" name="q14" value="1"> 4<br>

            <label>15. ฉันสามารถควบคุมอารมณ์ได้ดี</label>
            <input type="radio" name="q15" value="1"> 1
            <input type="radio" name="q15" value="2"> 2
            <input type="radio" name="q15" value="3"> 3
            <input type="radio" name="q15" value="4"> 4<br>

            <label>16. ฉันมักจะตื่นตระหนกเมื่อเจอสถานการณ์ยากลำบาก</label>
            <input type="radio" name="q16" value="4"> 1 (reverse)
            <input type="radio" name="q16" value="3"> 2
            <input type="radio" name="q16" value="2"> 3
            <input type="radio" name="q16" value="1"> 4<br>

            <label>17. ฉันเชื่อว่าทุกปัญหามีทางออก</label>
            <input type="radio" name="q17" value="1"> 1
            <input type="radio" name="q17" value="2"> 2
            <input type="radio" name="q17" value="3"> 3
            <input type="radio" name="q17" value="4"> 4<br>

            <label>18. ฉันรู้สึกว่าตนเองอ่อนแอ</label>
            <input type="radio" name="q18" value="4"> 1 (reverse)
            <input type="radio" name="q18" value="3"> 2
            <input type="radio" name="q18" value="2"> 3
            <input type="radio" name="q18" value="1"> 4<br>

            <label>19. ฉันสามารถฟื้นตัวจากความล้มเหลวได้</label>
            <input type="radio" name="q19" value="1"> 1
            <input type="radio" name="q19" value="2"> 2
            <input type="radio" name="q19" value="3"> 3
            <input type="radio" name="q19" value="4"> 4<br>

            <label>20. ฉันมักจะยอมแพ้ก่อนที่จะพยายาม</label>
            <input type="radio" name="q20" value="4"> 1 (reverse)
            <input type="radio" name="q20" value="3"> 2
            <input type="radio" name="q20" value="2"> 3
            <input type="radio" name="q20" value="1"> 4<br>

            <button type="button" onclick="calculateRQ()">คำนวณผล</button>
            <button type="button" onclick="clearForm('rqForm', 'rqResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="rqResult" class="result"></div>
    </section>

    <!-- ASSIST -->
    <section id="assist">
        <h2>แบบประเมินความเสี่ยงต่อการใช้สารเสพติด (ASSIST)</h2>
        <div class="emergency-contacts">
            หากรู้สึกแย่มาก ต้องการความช่วยเหลือฉุกเฉิน โทร 1669 หรือ สายด่วนยาเสพติด 1165
        </div>
        <form id="assistForm">
            <p>เลือกสารที่ต้องการประเมิน (สามารถเลือกหลายสารได้ แต่คำนวณทีละสารเพื่อความง่าย)</p>
            <select id="substance">
                <option value="tobacco">ยาสูบ</option>
                <option value="alcohol">สุรา</option>
                <option value="cannabis">กัญชา</option>
                <option value="cocaine">โคเคน</option>
                <option value="amphetamine">ยาบ้า/แอมเฟตามีน</option>
                <option value="inhalants">สารระเหย</option>
                <option value="sedatives">ยานอนหลับ</option>
                <option value="hallucinogens">ยาหลอนประสาท</option>
                <option value="opioids">ฝิ่น</option>
                <option value="other">อื่นๆ</option>
            </select><br>

            <label>Q1: ในชีวิตท่านเคยใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q1" value="0"> ไม่เคย
            <input type="radio" name="q1" value="1"> เคย (หากไม่เคย ข้ามไป)<br>

            <label>Q2: ใน 3 เดือนที่ผ่านมา ท่านใช้สารนี้บ่อยเพียงใด?</label>
            <input type="radio" name="q2" value="0"> ไม่เคย (0)
            <input type="radio" name="q2" value="2"> 1-2 ครั้ง (2)
            <input type="radio" name="q2" value="3"> ทุกเดือน (3)
            <input type="radio" name="q2" value="4"> ทุกสัปดาห์ (4)
            <input type="radio" name="q2" value="6"> เกือบทุกวัน (6)<br>

            <label>Q3: ใน 3 เดือนที่ผ่านมา ท่านรู้สึกอยากใช้สารนี้อย่างรุนแรงบ่อยเพียงใด?</label>
            <input type="radio" name="q3" value="0"> ไม่เคย (0)
            <input type="radio" name="q3" value="3"> 1-2 ครั้ง (3)
            <input type="radio" name="q3" value="4"> ทุกเดือน (4)
            <input type="radio" name="q3" value="5"> ทุกสัปดาห์ (5)
            <input type="radio" name="q3" value="6"> เกือบทุกวัน (6)<br>

            <label>Q4: ใน 3 เดือนที่ผ่านมา การใช้สารนี้ทำให้เกิดปัญหาสุขภาพ สังคม กฎหมาย การเงิน ต่อท่านบ่อยเพียงใด?</label>
            <input type="radio" name="q4" value="0"> ไม่เคย (0)
            <input type="radio" name="q4" value="4"> 1-2 ครั้ง (4)
            <input type="radio" name="q4" value="5"> ทุกเดือน (5)
            <input type="radio" name="q4" value="6"> ทุกสัปดาห์ (6)
            <input type="radio" name="q4" value="7"> เกือบทุกวัน (7)<br>

            <label>Q5: ใน 3 เดือนที่ผ่านมา ท่านไม่สามารถทำกิจกรรมปกติเพราะใช้สารนี้บ่อยเพียงใด? (ยกเว้นยาสูบ)</label>
            <input type="radio" name="q5" value="0"> ไม่เคย (0)
            <input type="radio" name="q5" value="5"> 1-2 ครั้ง (5)
            <input type="radio" name="q5" value="6"> ทุกเดือน (6)
            <input type="radio" name="q5" value="7"> ทุกสัปดาห์ (7)
            <input type="radio" name="q5" value="8"> เกือบทุกวัน (8)<br>

            <label>Q6: เพื่อน ญาติ หรือคนอื่นเคยแสดงความห่วงใยหรือตักเตือนท่านเกี่ยวกับการใช้สารนี้หรือไม่?</label>
            <input type="radio" name="q6" value="0"> ไม่เคย (0)
            <input type="radio" name="q6" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q6" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q7: ท่านเคยพยายามหยุดหรือลดการใช้สารนี้แต่ไม่สำเร็จหรือไม่?</label>
            <input type="radio" name="q7" value="0"> ไม่เคย (0)
            <input type="radio" name="q7" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q7" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <label>Q8: ท่านเคยใช้สารนี้โดยการฉีดหรือไม่?</label>
            <input type="radio" name="q8" value="0"> ไม่เคย (0)
            <input type="radio" name="q8" value="3"> เคยแต่ >3 เดือนที่แล้ว (3)
            <input type="radio" name="q8" value="6"> เคยใน 3 เดือนที่แล้ว (6)<br>

            <button type="button" onclick="calculateASSIST()">คำนวณผล</button>
            <button type="button" onclick="clearForm('assistForm', 'assistResult')">ล้างแบบฟอร์ม</button>
        </form>
        <div id="assistResult" class="result"></div>
    </section>

    <script>
        function validateForm(formId) {
            const form = document.getElementById(formId);
            const radioGroups = {};
            form.querySelectorAll('input[type="radio"]').forEach(radio => {
                if (!radioGroups[radio.name]) {
                    radioGroups[radio.name] = [];
                }
                radioGroups[radio.name].push(radio);
            });

            for (const groupName in radioGroups) {
                const group = radioGroups[groupName];
                const isChecked = group.some(radio => radio.checked);
                if (!isChecked) {
                    alert('กรุณาตอบคำถามทุกข้อในแบบประเมินนี้');
                    return false;
                }
            }
            return true;
        }

        function validateASSISTForm(formId) {
            const form = document.getElementById(formId);
            const q1Radios = form.querySelectorAll('input[name="q1"]');
            let q1Value = null;

            let q1Answered = false;
            for (const radio of q1Radios) {
                if (radio.checked) {
                    q1Value = parseInt(radio.value);
                    q1Answered = true;
                    break;
                }
            }

            if (!q1Answered) {
                alert('กรุณาตอบคำถาม Q1 ก่อน');
                return false;
            }

            if (q1Value === 0) {
                // If Q1 is 'ไม่เคย', no need to validate other questions.
                return true;
            }

            // If Q1 is 'เคย', validate Q2-Q8
            for (let i = 2; i <= 8; i++) {
                const qRadios = form.querySelectorAll(`input[name="q${i}"]`);
                let qAnswered = false;
                for (const radio of qRadios) {
                    if (radio.checked) {
                        qAnswered = true;
                        break;
                    }
                }
                if (!qAnswered) {
                    alert('กรุณาตอบคำถามทุกข้อในแบบประเมิน ASSIST');
                    return false;
                }
            }
            return true;
        }

        function clearForm(formId, resultId) {
            document.getElementById(formId).reset();
            document.getElementById(resultId).innerHTML = '';
            document.getElementById(resultId).style.display = 'none';
        }

        function calculateST5() {
            if (!validateForm('st5Form')) return;
            let form = document.getElementById('st5Form');
            let score = 0;
            for (let i = 1; i <= 5; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            let result = '';
            if (score <= 4) result = 'ความเครียดระดับปกติ';
            else if (score <= 7) result = 'ความเครียดระดับน้อย';
            else if (score <= 9) result = 'ความเครียดระดับปานกลาง';
            else result = 'ความเครียดระดับรุนแรง';
            document.getElementById('st5Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('st5Result').style.display = 'block';
        }

        function calculate2Q9Q8Q() {
            if (!validateForm('2q9q8qForm')) return;
            let form = document.getElementById('2q9q8qForm');
            let score2Q = 0, score9Q = 0, score8Q = 0;
            let result2Q = '', result9Q = '', result8Q = '';

            // 2Q
            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="2q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            // 9Q
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="9q${i}"]:checked`);
                if (q) score9Q += parseInt(q.value);
            }
            if (score9Q <= 6) result9Q = 'ไม่เป็นโรคซึมเศร้า';
            else if (score9Q <= 12) result9Q = 'ซึมเศร้าระดับน้อย';
            else if (score9Q <= 18) result9Q = 'ซึมเศร้าระดับปานกลาง';
            else result9Q = 'ซึมเศร้าระดับรุนแรง';

            // 8Q
            for (let i = 1; i <= 8; i++) {
                let q = form.querySelector(`input[name="8q${i}"]:checked`);
                if (q) score8Q += parseInt(q.value);
            }
            if (score8Q === 0) result8Q = 'ไม่มีความเสี่ยง';
            else if (score8Q <= 8) result8Q = 'เสี่ยงต่ำ';
            else if (score8Q <= 16) result8Q = 'เสี่ยงปานกลาง';
            else result8Q = 'เสี่ยงสูง';

            document.getElementById('2q9q8qResult').innerHTML = `2Q: คะแนน ${score2Q} - ${result2Q}<br>9Q: คะแนน ${score9Q} - ${result9Q}<br>8Q: คะแนน ${score8Q} - ${result8Q}`;
            document.getElementById('2q9q8qResult').style.display = 'block';
        }

        function calculate2QPlus() {
            if (!validateForm('2qplusForm')) return;
            let form = document.getElementById('2qplusForm');
            let score2Q = 0, plus = 0;
            let result2Q = '', resultPlus = '';

            for (let i = 1; i <= 2; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score2Q += parseInt(q.value);
            }
            if (score2Q >= 1) result2Q = 'เสี่ยงซึมเศร้า';
            else result2Q = 'ไม่เสี่ยงซึมเศร้า';

            let p = form.querySelector(`input[name="plus"]:checked`);
            if (p) plus = parseInt(p.value);
            if (plus === 1) resultPlus = 'เสี่ยงฆ่าตัวตาย';
            else resultPlus = 'ไม่เสี่ยงฆ่าตัวตาย';

            document.getElementById('2qplusResult').innerHTML = `2Q: ${result2Q}<br>Plus: ${resultPlus}`;
            document.getElementById('2qplusResult').style.display = 'block';
        }

        function calculatePHQA() {
            if (!validateForm('phqaForm')) return;
            let form = document.getElementById('phqaForm');
            let score = 0;
            let result = '';
            for (let i = 1; i <= 9; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score <= 4) result = 'ไม่มีภาวะซึมเศร้า';
            else if (score <= 9) result = 'ซึมเศร้าเล็กน้อย';
            else if (score <= 14) result = 'ซึมเศร้าปานกลาง';
            else if (score <= 19) result = 'ซึมเศร้ามาก';
            else result = 'ซึมเศร้ารุนแรง';

            let extra1 = form.querySelector(`input[name="extra1"]:checked`) ? form.querySelector(`input[name="extra1"]:checked`).value : 'ไม่ตอบ';
            let extra2 = form.querySelector(`input[name="extra2"]:checked`) ? form.querySelector(`input[name="extra2"]:checked`).value : 'ไม่ตอบ';

            document.getElementById('phqaResult').innerHTML = `คะแนนรวม: ${score} - ${result}<br>เคยพยายามทำร้ายตัวเอง: ${extra1 === '1' ? 'มี' : 'ไม่มี'}<br>เคยคิดอยากตาย: ${extra2 === '1' ? 'มี' : 'ไม่มี'}`;
            document.getElementById('phqaResult').style.display = 'block';
        }

        function calculateTMHI15() {
            if (!validateForm('tmhi15Form')) return;
            let form = document.getElementById('tmhi15Form');
            let score = 0;
            for (let i = 1; i <= 15; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            let result = '';
            if (score >= 33) result = 'สุขภาพจิตดีกว่าคนทั่วไป';
            else if (score >= 27) result = 'สุขภาพจิตเท่าคนทั่วไป';
            else result = 'สุขภาพจิตต่ำกว่าคนทั่วไป';
            document.getElementById('tmhi15Result').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('tmhi15Result').style.display = 'block';
        }

        function calculateRQ() {
            if (!validateForm('rqForm')) return;
            let form = document.getElementById('rqForm');
            let score = 0;
            for (let i = 1; i <= 20; i++) {
                let q = form.querySelector(`input[name="q${i}"]:checked`);
                if (q) score += parseInt(q.value);
            }
            if (score < 60) result = 'พลังใจต่ำ (แนะนำพัฒนา)';
            else result = 'พลังใจดี';
            document.getElementById('rqResult').innerHTML = `คะแนนรวม: ${score}<br>ผลลัพธ์: ${result}`;
            document.getElementById('rqResult').style.display = 'block';
        }

        function calculateASSIST() {
            if (!validateASSISTForm('assistForm')) return; // Use the new validation function

            let form = document.getElementById('assistForm');
            let substance = document.getElementById('substance').value;
            let score = 0;
            let resultHtml = '';
            let isTobacco = substance === 'tobacco';

            let q1 = form.querySelector(`input[name="q1"]:checked`) ? parseInt(form.querySelector(`input[name="q1"]:checked`).value) : 0;

            resultHtml += `สาร: ${substance}<br>`;

            if (q1 === 0) {
                resultHtml += 'ผลลัพธ์: ไม่เคยใช้สารนี้';
            } else {
                // Calculate score for Q2-Q7
                for (let i = 2; i <= 7; i++) {
                    let q = form.querySelector(`input[name="q${i}"]:checked`);
                    if (q && !(isTobacco && i === 5)) { // Q5 is skipped for tobacco
                        score += parseInt(q.value);
                    }
                }

                let q8 = form.querySelector(`input[name="q8"]:checked`) ? parseInt(form.querySelector(`input[name="q8"]:checked`).value) : 0;

                resultHtml += `คะแนนรวม (Q2-Q7): ${score}<br>`;
                resultHtml += `<b>*หมายเหตุ: คำถาม Q8 (การฉีดสาร) เป็นตัวชี้วัดความเสี่ยงสูงแยกต่างหาก และไม่ได้นำมารวมในการคำนวณคะแนนรวม</b><br>`;

                let riskLevel = '';
                if (substance === 'alcohol') {
                    if (score >= 27) riskLevel = 'เสี่ยงสูง';
                    else if (score >= 11) riskLevel = 'เสี่ยงปานกลาง';
                    else riskLevel = 'เสี่ยงต่ำ';
                } else { // All other substances
                    if (score >= 27) riskLevel = 'เสี่ยงสูง';
                    else if (score >= 4) riskLevel = 'เสี่ยงปานกลาง';
                    else riskLevel = 'เสี่ยงต่ำ';
                }
                resultHtml += `ระดับความเสี่ยง: ${riskLevel}<br>`;

                // Q8 is a separate high-risk indicator, not part of the score
                if (q8 === 6) {
                    resultHtml += '<br><span style="color: red; font-weight: bold;">มีการฉีดสารนี้ใน 3 เดือนที่แล้ว - เสี่ยงสูงมาก (โปรดปรึกษาผู้เชี่ยวชาญทันที)</span>';
                }
            }
            document.getElementById('assistResult').innerHTML = resultHtml;
            document.getElementById('assistResult').style.display = 'block';
        }
    </script>
</body>
</html>
'''

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="th">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>แพลตฟอร์มประเมินสุขภาพจิตออนไลน์</title>
#     <style>
#         body { font-family: Arial, sans-serif; margin: 20px; }
#         h1, h2 { text-align: center; }
#         section { margin-bottom: 40px; border: 1px solid #ccc; padding: 20px; border-radius: 8px; }
#         form { margin: 0 auto; max-width: 800px; }
#         label { display: block; margin: 10px 0; }
#         input[type="radio"] { margin-right: 10px; }
#         button { display: block; margin: 20px auto; padding: 10px 20px; background-color: #4CAF50; color: white; border: none; cursor: pointer; }
#         button:hover { background-color: #45a049; }
#         .result { margin-top: 20px; padding: 15px; background-color: #f9f9f9; border: 1px solid #ddd; display: none; }
#         nav { text-align: center; margin-bottom: 30px; }
# ...

# %% [markdown]
# ## Add Emergency Contact Information
#
# ### Subtask:
# Integrate emergency contact numbers (1669, 1323) into the HTML, placing them prominently near assessment sections related to self-harm or suicidal thoughts.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm that all specified fixes and improvements have been implemented and address the user's feedback comprehensively.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **ASSIST Q5 HTML Corrected**: The radio buttons for Question 5 in the ASSIST form were successfully updated. The 'ทุกสัปดาห์' option now correctly has `value="7"`, and the 'เกือบทุกวัน' option has `value="8"`.
# *   **Conditional Validation for ASSIST Implemented**: A new JavaScript function `validateASSISTForm()` was introduced. This function ensures that if a user indicates they have previously used a substance (Q1 = 'เคย'), they must answer all subsequent questions (Q2-Q8) before the score is calculated. If Q1 indicates no prior use, questions Q2-Q8 are not required.
# *   **ASSIST Q8 Scoring Clarification**: The `calculateASSIST()` function was updated to explicitly inform the user that Question 8 (regarding injection use) is a separate high-risk indicator and its value is not included in the main numerical score calculation. This clarification is prominently displayed in the results, along with a distinct warning for recent injection use.
# *   **Emergency Contact Numbers Embedded**: Emergency contact numbers (1669, 1323 for mental health support, and 1165 for substance abuse) were added to the HTML. These contacts are prominently displayed in dedicated `div` elements with a distinct red styling, specifically within the `2Q-9Q-8Q`, `2Q Plus`, `PHQ-A`, and `ASSIST` assessment sections, which are relevant to self-harm, suicidal thoughts, and substance abuse.
#
# ### Insights or Next Steps
#
# *   **Enhanced User Guidance and Safety**: The implemented conditional validation and explicit clarification for ASSIST Q8 significantly improve the user experience by providing clear instructions and ensuring critical safety information is highlighted. The prominent emergency contacts offer immediate support for high-risk situations.
# *   **Continuous Improvement**: Consider implementing dynamic form elements where questions (Q2-Q8) are only revealed/enabled if Q1 is answered with "เคย" to further streamline the user experience and prevent premature validation errors.
